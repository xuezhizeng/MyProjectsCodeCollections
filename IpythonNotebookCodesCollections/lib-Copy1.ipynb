# %%
# !pip install mahotas

# %%
import mahotas
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# print dir(mahotas)

# %%
from pylab import imshow, show
import mahotas
import mahotas.demos
wally = mahotas.demos.load('Wally')

plt.figure(figsize=(10,8))
imshow(wally)
show()

# %%
wfloat = wally.astype(float)
print len(wfloat)
r,g,b = wfloat.transpose((2,0,1))
# Out:
# 768

# %%
type(wfloat), wfloat.shape
# Out:
# (numpy.ndarray, (768, 1024, 3))

# %%
r.shape, g.shape, b.shape
# Out:
# ((768, 1024), (768, 1024), (768, 1024))

# %%
import numpy as np

# %%
np.concatenate((r,g,b)).shape
# Out:
# (2304, 1024)

# %%
np.concatenate((r,g,b)).reshape(-1,1024,3).shape
# Out:
# (768, 1024, 3)

# %%
plt.figure(figsize=(10,8))
plt.imshow(np.concatenate((r,g,b)).reshape(-1,1024,3))

# %%
r.shape, g.shape, b.shape
# Out:
# ((768, 1024), (768, 1024), (768, 1024))

# %%
np.hstack((r,g,b)).shape
# Out:
# (768, 3072)

# %%
np.vstack((r,g,b)).shape
# Out:
# (2304, 1024)

# %%
np.stack((r,g,b)).shape
# Out:
# (3, 768, 1024)

# %%
np.stack((r,g,b),2).shape
# Out:
# (768, 1024, 3)

# %%
np.stack((r,g,b),1).shape
# Out:
# (768, 3, 1024)

# %%
np.stack((r,g,b),0).shape
# Out:
# (3, 768, 1024)

# %%
wally.shape
# Out:
# (768, 1024, 3)

# %%
np.stack((r,g,b),2)==wally
# Out:
# array([[[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        ...,
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
# ...

# %%
plt.figure(figsize=(10,8))
plt.imshow(np.stack((r,g,b),2))

# %%
plt.figure(figsize=(10,8))
plt.imshow(np.stack((b,g,r),2))

# %%
wally
