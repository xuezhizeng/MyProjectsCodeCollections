# %% [markdown]
# conda install -c bioconda p7zip

# %% [markdown]
# conda install -c conda-forge librosa

# %%
# !ls
# Out:
# archive					   explore_1.ipynb
# build					   GCommandsPytorch
# build.tar.gz				   prepared_data
# data					   resnet-tf-speech
# download_install_test_model_pytorch.ipynb  voice data explore.ipynb

# %%
# !ls -lh data
# Out:
# total 3.6G
# drwxr-xr-x 3 shj16110 Domain_Users 4.0K Nov 13 21:17 test
# -rw-r--r-- 1 shj16110 Domain_Users 2.5G Jan  5 10:32 test.7z
# -rw-r--r-- 1 shj16110 Domain_Users 1.1G Jan  5 10:41 train.7z

# %%
# !ls -l data
# Out:
# total 3673664
# drwxr-xr-x 3 shj16110 Domain_Users       4096 Nov 13 21:17 test
# -rw-r--r-- 1 shj16110 Domain_Users 2640679130 Jan  5 10:32 test.7z
# -rw-r--r-- 1 shj16110 Domain_Users 1121103842 Jan  5 10:41 train.7z

# %%
# !7z x data/train.7z -o./data/train/

# %%
# !pwd
# Out:
# /home/shj16110/notebook/2018/kaggle

# %%
!7z x Model_Data_latest/data/test.7z -o./data
# Out:
# 7-Zip [64] 15.09 beta : Copyright (c) 1999-2015 Igor Pavlov : 2015-10-16
# p7zip Version 15.09 beta (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,24 CPUs x64)
#
# Scanning the drive for archives:
#   0M Sca        1 file, 2640679130 bytes (2519 MiB)
#
# Extracting archive: Model_Data_latest/data/test.7z
# --
# Path = Model_Data_latest/data/test.7z
# Type = 7z
# Physical Size = 2640679130
# Headers Size = 1345163
# Method = Delta LZMA2:24
# Solid = +
# Blocks = 3
# ...

# %%
# !7z x Model_Data_latest/data/train.7z -o./data

# %%
# !ls voice/train/
# Out:
# audio  LICENSE	README.md  testing_list.txt  validation_list.txt

# %%
import os

# %%
path1 = 'voice/train/audio/cat/'
cat = os.listdir(path1)
len(cat)
# Out:
# 1733

# %%
import IPython.display as ipd

# %%
ipd.Audio(path1+cat[10])
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
