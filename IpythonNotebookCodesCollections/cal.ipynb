# %%
import scipy
from scipy import stats
from scipy.stats import norm, poisson, bernoulli

import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
np.percentile([1,2,3,4], [50])
# Out:
# array([2.5])

# %%
df1 = pd.read_csv('./Blended_out_2.csv')
print df1.shape

df2 = pd.read_csv('./Blended_out_1.csv')
df2.shape
# Out:
# (153164, 7)
# (153164, 7)

# %%
df.head()
# Out:
#                  id     toxic  severe_toxic   obscene    threat    insult  \
# 0  00001cee341fdb12  0.957881      0.188534  0.933546  0.036393  0.875429
# 1  0000247867823ef7  0.001969      0.000777  0.001350  0.000104  0.001348
# 2  00013b17ad220c46  0.008052      0.001559  0.004123  0.000250  0.002181
# 3  00017563c3f7919a  0.001369      0.000240  0.000654  0.000167  0.000792
# 4  00017695ad8997eb  0.008214      0.000343  0.001606  0.000172  0.002275
#
#    identity_hate
# 0       0.258726
# 1       0.000527
# 2       0.000729
# 3       0.000137
# 4       0.000338

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
for i in df.columns[1:]:
    df[i] = MinMaxScaler().fit_transform(df['toxic'].values.reshape(-1,1))

# %%
df.to_csv('submit_3.csv', index=False)

# %%
# Out:
# (153164, 7)

# %%
df = df1.copy()

# %%
for i in df.columns[1:]:
    df[i] = df1[i]*0.987+df2[i]*0.012

# %%
df
# Out:
#                       id     toxic  severe_toxic   obscene    threat  \
# 0       00001cee341fdb12  0.956469      0.187349  0.932102  0.036089
# 1       0000247867823ef7  0.001968      0.000778  0.001352  0.000104
# 2       00013b17ad220c46  0.008018      0.001558  0.004115  0.000249
# 3       00017563c3f7919a  0.001366      0.000240  0.000653  0.000166
# 4       00017695ad8997eb  0.008145      0.000341  0.001596  0.000171
# 5       0001ea8717f6de06  0.001904      0.000210  0.000764  0.000406
# 6       00024115d4cbde0f  0.002479      0.000114  0.001058  0.000059
# 7       000247e83dcc1211  0.404007      0.001579  0.034406  0.001954
# 8       00025358d4737918  0.111119      0.000338  0.044170  0.000170
# 9       00026d1092fe71cc  0.001658      0.000133  0.001078  0.000078
# 10      0002eadc3b301559  0.376127      0.000901  0.140903  0.000671
# 11      0002f87b16116a7f  0.183280      0.000471  0.055364  0.000306
# 12      0003806b11932181  0.003676      0.000148  0.000809  0.000062
# ...
