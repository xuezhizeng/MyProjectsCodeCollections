# %%
import IPython.display as ipd
from numpy import random
import os

import librosa
import seaborn # optional
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !ls voice/train/audio
# Out:
# _background_noise_  dog    four   left	  off	 seven	 three	wow
# bed		    down   go	  marvin  on	 sheila  tree	yes
# bird		    eight  happy  nine	  one	 six	 two	zero
# cat		    five   house  no	  right  stop	 up

# %%
path1 = 'voice/train/audio/cat/'
cat = os.listdir(path1)
print 'all: ', len(cat)

for i in [random.randint(0,len(cat)) for i in range(5)]:
    print i
    cat_path = path1+cat[i]
    
    x, sr = librosa.load(cat_path)
    
#     plt.figure()
    librosa.display.waveplot(x, sr=sr)
    ipd.display(ipd.Audio(cat_path))
#     plt.show()
# Out:
# all:  1733
# 490
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 1521
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 123
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 124
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 995
# ...
