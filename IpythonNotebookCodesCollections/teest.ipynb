# %%
import pandas as pd


# In[30]:

df1=pd.read_csv('labels.csv', names=['name'])
df1=df1.reset_index(drop=True)
df1.shape
# Out:
# (42421, 1)

# %%
df1
# Out:
#                                                     name
# 0      chopped_face1/face1_set_4_V96/face1_sub_33/3ac...
# 1      chopped_face1/face1_set_4_V96/face1_sub_31/338...
# 2      chopped_face1/face1_set_4_V96/face1_sub_34/461...
# 3      chopped_face1/face1_set_4_V96/face1_sub_33/421...
# 4      chopped_face1/face1_set_4_V96/face1_sub_32/345...
# 5      chopped_face1/face1_set_4_V96/face1_sub_34/455...
# 6      chopped_face1/face1_set_4_V96/face1_sub_33/39_...
# 7      chopped_face1/face1_set_4_V96/face1_sub_33/425...
# 8      chopped_face1/face1_set_4_V96/face1_sub_34/485...
# 9      chopped_face1/face1_set_4_V96/face1_sub_33/42a...
# 10     chopped_face1/face1_set_4_V96/face1_sub_34/448...
# 11     chopped_face1/face1_set_4_V96/face1_sub_32/357...
# 12     chopped_face1/face1_set_4_V96/face1_sub_31/330...
# 13     chopped_face1/face1_set_4_V96/face1_sub_34/44F...
# 14     chopped_face1/face1_set_4_V96/face1_sub_33/3_b...
# ...

# %%
df1['name'].apply(lambda x: '/'.join(x.split('/')[2:])[:-3]+'.jpg')
# Out:
# 0        face1_sub_33/3ac79f3df8dcd1007e8c38d2788b4710b...
# 1                    face1_sub_31/3382201534726308180..jpg
# 2        face1_sub_34/4610b912c8fcc3ce313f2b1d9345d688d...
# 3        face1_sub_33/42166d224f4a20a4384ebb349a5298227...
# 4                      face1_sub_32/345-1512241630580..jpg
# 5                    face1_sub_34/4559894622729723147..jpg
# 6                      face1_sub_33/39_141105135834_2..jpg
# 7                              face1_sub_33/4250594-1..jpg
# 8        face1_sub_34/48540923dd54564eb961bfcdb9de9c82d...
# 9        face1_sub_33/42a98226cffc1e17ed04291b4090f6037...
# 10                face1_sub_34/448a5bb32da01584bc1a3e..jpg
# 11              face1_sub_32/3575b0008cc9f08be950cdf0..jpg
# 12                 face1_sub_31/330629-14021621460645..jpg
# 13       face1_sub_34/44F2DA6308EC89C25EE43CA2DA5EED1F....
# 14       face1_sub_33/3_b731f39b81217fd1d90f68ea354b143...
# 15                 face1_sub_34/492E332J54UF_1000x500..jpg
# ...
