# %% [markdown]
# https://github.com/dpressel/rude-carnie

# %% [markdown]
# https://github.com/coursera-dl/coursera-dl/issues/554

# %% [markdown]
# https://github.com/tensorflow/models/issues/729

# %%
import os
import cv2
from IPython.core.display import Image  
import matplotlib.pyplot as plt


def showpic(lists):
    n=len(lists)
    print 'viewing ',n, 'pics'
    
    f=0
    for i in lists:
        f+=1
        name=path+i
        if f%2==1:
            print f, '-', f+1
            plt.figure(figsize=((10,7)))
            plt.subplot(1,2,1)
            plt.imshow(plt.imread(name))
        else:

            plt.subplot(1,2,2)
            plt.imshow(plt.imread(name))
            plt.show()

# %% [markdown]
# https://github.com/floydhub/dl-docker

# %% [markdown]
# https://github.com/NVIDIA/nvidia-docker/wiki/Installation

# %%
# !ls
# Out:
# 21936  22801  control-Copy1.ipynb  control.ipynb  rude-carnie  test.ipynb

# %%
# !pwd
# Out:
# /home/soyoung/face/Freelancer/Tensorflow

# %%
path='/home/soyoung/face/Freelancer/headPics/bidderPics/'

# %%
names = os.listdir(path)
len(names)
# Out:
# 10456

# %%
showpic(names[152:154])
# Out:
# viewing  2 pics
# 1 - 2

# %%
names[152:154]
# Out:
# ['220406_profile.png', '1444258_profile.png']

# %%
# !python rude-carnie/guess.py --model_type inception --model_dir 22801 --filename /home/soyoung/face/Freelancer/bidderPics/1573462_profile.jpg

# %%
# %%time
# !python rude-carnie/guess.py --class_type gender --model_type inception --model_dir 21936 \
--filename /home/soyoung/face/Freelancer/bidderPics/220406_profile.jpg
# Out:
# 2017-09-30 00:44:33.147636: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-09-30 00:44:33.147656: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-09-30 00:44:33.147672: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2017-09-30 00:44:33.147676: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
# %%time
# !python rude-carnie/guess.py --class_type gender --model_type inception --model_dir 21936 \
--filename /home/soyoung/face/Freelancer/bidderPics/1444258_profile.jpg
# Out:
# 2017-09-30 00:44:57.700650: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-09-30 00:44:57.700671: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-09-30 00:44:57.700678: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2017-09-30 00:44:57.700692: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
100000*8/60/60
# Out:
# 222

# %%
# !pwd
# Out:
# /home/soyoung/face/Freelancer/Tensorflow

# %%
# %%time
# !python rude-carnie/guess.py --class_type gender --model_type inception --model_dir 21936 \
--filename /home/soyoung/face/Freelancer/Tensorflow/list.txt --target /home/soyoung/face/Freelancer/Tensorflow/testResults.csv
# Out:
# 2017-09-30 01:02:13.041796: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-09-30 01:02:13.041819: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-09-30 01:02:13.041825: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2017-09-30 01:02:13.041831: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
# !ls
# Out:
# 21936  control.ipynb		    list.txt	 test.ipynb
# 22801  control-Multiple_pics.ipynb  rude-carnie  testResults.csv

# %%
# !cat testResults.csv
# Out:
# file,label,score
# /home/soyoung/face/Freelancer/bidderPics/220406_profile.jpg,M,0.91
# /home/soyoung/face/Freelancer/bidderPics/1444258_profile.jpg,F,1.00
