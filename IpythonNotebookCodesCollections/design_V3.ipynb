# %%
# -*- coding:utf-8 -*-
import sys
# try:
#     reload(sys)
#     sys.setdefaultencoding("utf-8")
# except:
#     print('python3')
    
import pandas as pd
import json
import requests
import os
from time import time

# %%
link = "http://y.soyoung.com/yuehui/shop?district_id={}&menu1_id={}&sort=13&index={}"
cat = [10020, 10021, 10010, 10001, 10003, 10006, 10019, 10008, 10009, 10011, 10013, \
       10023, 10022, 10015, 10012, 10007, 10017, 10018]

# %% [markdown]
# the totals are incremented by sum of all categories, if retrieved by "all", the actual number will be less (if total < 2000) else will be more (if total >2000)

# %%
df = pd.read_excel('./province_stat.xlsx')
df.head()
# Out:
#    place_id Place  total_products
# 0        19   广东省            8579
# 1         1    北京            6781
# 2        17   湖北省            4406
# 3         9    上海            3995
# 4        10   江苏省            3942

# %%
df.tail()
# Out:
#     place_id    Place  total_products
# 31        33  香港特别行政区             150
# 32        29      青海省              99
# 33       561       日本              30
# 34       560       泰国              22
# 35        34  澳门特别行政区              21

# %%
df1 = df[df['total_products']>1500]
df2 = df[df['total_products']<1500]

# %%
link
# Out:
# 'http://y.soyoung.com/yuehui/shop?district_id={}&menu1_id={}&sort=13&index={}'

# %%
class Collect(object):
    
    def __init__(self, link, place_id, cat_id):
        
        
        self.link =  link.format(place_id, cat_id, '{}')

        self.place_id = place_id
        self.cat_id = cat_id
        self.collect = []
        self.df = None
        self.flag = 0 
        
        
    def __scrape(self, index):
        
        try:
            products = json.loads(requests.get(self.link.format(index), timeout=3).text)['responseData']['product_info']
            print 'O',
            
            if len(products)==0:
                try: 
                    if 0==len(json.loads(requests.get(self.link.format(index), timeout=3).text)['responseData']['product_info']):
                        print 'E',
                        self.flag = 1
                        return
                except:
                    print '?',
                    self.__scrape(index)
            

            for product in products:
                self.collect.append(product)
                
        except Exception as e:
            print e
            print 'X',
            self.__scrape(index)  
            
    def main(self):
        
            
        for i in range(180):
            if not self.flag:
                self.__scrape(i)
                    
                                    
        print(len(self.collect))

        self.df = pd.DataFrame(self.collect) 
        
        try:
            col = list(test.df.columns)
            col = [col.pop(col.index('pid')), col.pop(col.index('title'))]+col
            self.df = self.df[col]
        except:
            print 'U'
        
        return self.df     
    def save(self):
        try:
            name = "{}_{}.xlsx".format(self.place_id, self.cat_id)
            self.df.to_excel(name, encoding="utf-8", index=False)
            print "Save Success! for "+name
        except:
            print "Save Error"
    def __repr__(self):
        return "place: "+ str(self.place_id)+ " category: "+ str(self.cat_id)+ " scraped: "+ str(self.flag==1)

# %%
test = Collect(link, 34, 0)
test
# Out:
# place: 34 category: 0 scraped: False

# %%
test.main()
# Out:
# O O O E 16
#       pid                        title avg_score bao_xian_yn calendar_cnt  \
# 0   57262   【激光祛斑】E-Toning激光，专业祛斑，祛黑色素       0.0           0            0
# 1   57257          【激光祛斑】IPL激光，有效祛斑/嫩肤       0.0           0            0
# 2   57255   【激光美肤】fraxel激光局部治疗，祛疤痕，缩毛孔       0.0           0            0
# 3   57252     【激光美肤】fraxel激光全脸，祛疤痕，缩毛孔       0.0           0            0
# 4   57191    【激光美肤】Genesis Lifting激光美肤       0.0           0            0
# 5   57006     【PRP嫩肤】PRP自血清美肤，让肌肤健康有活力       0.0           0            0
# 6   56926            【水光针】伊婉原装正品，高级水光针       0.0           0            0
# 7   56925            【水光针】伊婉原装正品，中级水光针       0.0           0            0
# 8   56922           【水光针】伊婉原装正品，普通级水光针       0.0           0            0
# 9   56833     【其他】正品Sculptra童颜针，皮肤重获新生       0.0           0            0
# 10  56534   【埋线提升】全脸埋线提升，去皱、紧致、抗衰、改善肤质       0.0           0            0
# 11  56529    【超声刀】美国正品Ulthera超声刀改善全脸皮肤       0.0           0            0
# 12  56339    【乔雅登玻尿酸】乔雅登玻尿酸（美国）1ML原装正品       0.0           0            0
# 13  56292     【保妥适BOTOX】保妥适（botox）原装正品       0.0           0            0
# 14  56290  【保妥适BOTOX】保妥适（botox）肉毒素原装正品       0.0           0            0
# 15  56289     【保妥适BOTOX】保妥适（botox）原装正品       0.0           0            0
#
#                                                doctor doctor_name each_cnt  \
# 0   [{u'doctor_id': u'50921', u'name_cn': u'许孝珍', ...         许孝珍        0
# 1   [{u'doctor_id': u'50921', u'name_cn': u'许孝珍', ...         许孝珍        0
# 2   [{u'doctor_id': u'50921', u'name_cn': u'许孝珍', ...         许孝珍        0
# 3   [{u'doctor_id': u'50921', u'name_cn': u'许孝珍', ...         许孝珍        0
# 4   [{u'doctor_id': u'50921', u'name_cn': u'许孝珍', ...         许孝珍        0
# 5   [{u'doctor_id': u'50921', u'name_cn': u'许孝珍', ...         许孝珍        0
# 6   [{u'doctor_id': u'50921', u'name_cn': u'许孝珍', ...         许孝珍        0
# 7   [{u'doctor_id': u'50921', u'name_cn': u'许孝珍', ...         许孝珍        0
# 8   [{u'doctor_id': u'50921', u'name_cn': u'许孝珍', ...         许孝珍        0
# 9   [{u'doctor_id': u'50921', u'name_cn': u'许孝珍', ...         许孝珍        0
# 10  [{u'doctor_id': u'50921', u'name_cn': u'许孝珍', ...         许孝珍        0
# 11  [{u'doctor_id': u'50921', u'name_cn': u'许孝珍', ...         许孝珍        0
# 12  [{u'doctor_id': u'50921', u'name_cn': u'许孝珍', ...         许孝珍        0
# 13  [{u'doctor_id': u'50921', u'name_cn': u'许孝珍', ...         许孝珍        0
# 14  [{u'doctor_id': u'50921', u'name_cn': u'许孝珍', ...         许孝珍        0
# 15  [{u'doctor_id': u'50921', u'name_cn': u'许孝珍', ...         许孝珍        0
#
#    gong_yn hospital_id     ...     security show_calendar_cnt  sold_cnt sole  \
# 0        0       22328     ...            0                 0         0    0
# 1        0       22328     ...            0                 0         0    0
# 2        0       22328     ...            0                 0         0    0
# 3        0       22328     ...            0                 0         0    0
# 4        0       22328     ...            0                 0         0    0
# 5        0       22328     ...            0                 0         0    0
# 6        0       22328     ...            0                 0         0    0
# 7        0       22328     ...            0                 0         0    0
# 8        0       22328     ...            0                 0         0    0
# 9        0       22328     ...            0                 0         0    0
# 10       0       22328     ...            0                 0         0    0
# 11       0       22328     ...            0                 0         0    0
# 12       0       22328     ...            0                 0         1    0
# 13       0       22328     ...            0                 0         0    0
# 14       0       22328     ...            0                 0         0    0
# 15       0       22328     ...            0                 0         3    0
#
#    tj_order total_cnt  tuan  wei_kuan wei_kuan_list wei_kuan_yn
# 0         0         0    {}        []            []           0
# 1         0         0    {}        []            []           0
# 2         0         0    {}        []            []           0
# 3         0         0    {}        []            []           0
# 4         0         0    {}        []            []           0
# 5         0         0    {}        []            []           0
# 6         0         0    {}        []            []           0
# 7         0         0    {}        []            []           0
# 8         0         0    {}        []            []           0
# 9         0         0    {}        []            []           0
# 10        0         0    {}        []            []           0
# 11        0         0    {}        []            []           0
# 12        0         0    {}        []            []           0
# 13        0         0    {}        []            []           0
# 14        0         0    {}        []            []           0
# 15        0         0    {}        []            []           0
#
# [16 rows x 35 columns]

# %%
test.save()
# Out:
# Save Success! for 34_0.xlsx
