# %%
import concurrent.futures
import requests
import os

from time import time, ctime
import pandas as pd

fail=[]

# %%
def download_image(img_url):
    global direct
    
    try:
        ID, url = img_url.split('__')
        cont = url.split('/')
        name= str(ID)+'_'+str(cont[-4])+str(cont[-1]).replace('_570','')
        
    except Exception as e:
        fail.append(img_url)
        print e

        
        
    try:
        img_request = requests.request(
            'get', url, stream=True, timeout=300)
        if img_request.status_code != 200:
            fail.append(img_url)
            print 'X2'
    except Exception as e:
        fail.append(img_url)
        print e

    try:
        img_content = img_request.content
        with open(os.path.join(direct,  name), 'wb') as f:
            byte_image = bytes(img_content)
            f.write(byte_image)
            
    except Exception as e:
        fail.append(img_url)
        print e

# %%
def batch(subber):
    start=time()
    with concurrent.futures.ThreadPoolExecutor(max_workers=8) as executor:
        executor.map(download_image, subber)
    past='{:.2f}'.format(time()-start)
    now=ctime()[4:]

    print 'imges ',len(subber),'  used ',past,'s', now

# %%
def spl(lists, n):
    return  [lists[i:i + n] for i in range(0, len(lists), n)]

# %%
if __name__=='__main__':
    
    choose=raw_input('which set (1-24)?: ')
    try:
        os.mkdir('img_'+str(choose))
    except:
        print 'dir img_'+str(choose)+' exists'
    
    direct='img_'+str(choose)
    df=pd.read_csv('img_'+str(choose)+'.csv')
    nn=df.shape[0]
    print nn,' pics'
    
    
    urls=[]
    for i in df.itertuples():
        urls.append(str(i[1])+'__'+str(i[2]))
    print len(urls)==nn
    
    many=int(raw_input('how many IDs a batch?: '))
      
    
    p=0
    q=0
    for i in spl(urls, many):
        q+=1
        batch(i)
        p+=many/float(nn)
        print p*100,'%', nn, many*q 

    fl = pd.DataFrame(fail, columns=['fail_url'])
    fl.save('failed_img_'+str(choose)+'.csv')
# Out:
# which set (1-24)?: 8
# 10000  pics
# True
# how many IDs a batch?: 100
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170601/6/20170601090606671_570.png (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d0fa6a90>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170601/2/20170601090743917_570.png (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d0d85a50>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170601/6/20170601091212257_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d0d85a50>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170601/2/20170601091426163_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d00ece50>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170601/7/20170601084901667_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d00ec0d0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170601/8/20170601084844602_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d00ec950>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170601/8/20170601085040211_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d00ec7d0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170530/4/20170530103630138_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d00f3890>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170530/8/20170530103812833_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d0091e10>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20170530/2/20170530095235388_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d00d5750>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20170530/1/20170530095234722_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d0091e10>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20170530/2/20170530095234357_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d00d5750>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20170530/3/20170530095235978_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d0fa6d50>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170530/6/20170530090619231_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d00f3890>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170530/2/20170530090634249_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d00f3b10>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170530/6/20170530090706444_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d00f36d0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170530/5/20170530090841155_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d00f35d0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170530/3/20170530092107512_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d00f3490>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170530/5/20170530092235913_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d00f3e10>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170530/7/20170530092250836_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d00fcd50>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170529/3/20170529143513236_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d00f3650>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170529/5/20170529143910965_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d00fc750>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170529/9/20170529144706348_570.png (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d00fcd90>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170529/5/20170529144120796_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d00fc750>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170526/8/20170526162013869_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d00fcf10>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170526/6/20170526163044731_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d0103b50>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170529/6/20170529091017740_570.png (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d0103350>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170529/6/20170529091031521_570.png (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d0103d50>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170529/7/20170529091834445_570.gif (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d0103150>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170529/6/20170529091922784_570.png (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d0103850>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170529/0/20170529091851749_570.png (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d00f3650>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170526/9/20170526130431296_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d0103510>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170526/1/20170526130556408_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d0103fd0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170526/4/20170526131145168_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d0103850>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170526/4/20170526131159799_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d01030d0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170526/8/20170526131438800_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d0103850>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170526/4/20170526131801845_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d0103f10>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170526/9/20170526132408520_570.png (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d0103850>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170526/9/20170526132328350_570.png (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d0103950>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170526/3/20170526132341406_570.png (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d0103850>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170526/5/20170526105506610_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d0103b50>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Read timed out.
# imges  100   used  330.80 s Aug 31 00:39:12 2017
# 1.0 % 10000 100
# X2
# X2
# X2
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170524/4/20170524105809106_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d0091d50>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170524/3/20170524105828501_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d00910d0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170524/6/20170524110420360_570.png (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d0091cd0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170524/3/20170524110446519_570.png (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d0091cd0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170524/2/20170524110735527_570.png (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d00fc310>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170524/9/20170524110755727_570.png (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d054cb90>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170524/2/20170524110835879_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d054cb10>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170523/3/20170523134144974_570.png (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d054cc50>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170522/3/20170522092523798_570.png (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d0518f90>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170522/5/20170522093804364_570.png (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d0518e50>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170522/2/20170522094226331_570.png (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d0518150>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170522/3/20170522094612959_570.png (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d0518050>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170522/6/20170522094635183_570.png (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d0518290>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170522/9/20170522112233535_570.png (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d0518d90>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170522/7/20170522112742841_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d0518650>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170522/5/20170522112943264_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d0518dd0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170522/2/20170522113315564_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d0518d50>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20170522/5/20170522085410129_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d0518b10>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20170522/0/20170522085410450_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d0518490>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20170522/9/20170522085411445_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d0518d50>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='y.soyoung.com', port=80): Max retries exceeded with url: /assets/editor/plugins/emoticons/images/12_570.gif (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f96d