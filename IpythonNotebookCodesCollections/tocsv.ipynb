# %%
import pandas as pd
import json

# %%
f = open('Oprah_json_.txt','r')

# %%
a = f.readlines()

# %%
def  flatten_dict(data, layers=1, drop_deeper=True):
        """
        takes in a dictionary and will flatten it with level_1.level_2 as the key, for however many levels are
        specified. If specified (true by default), anything deeper than the specified level will be dropped from the
        dictionary outright.

        :param data:
        :param layers:
        :param drop_deeper:
        :return:
        """
        for _ in range(layers):
            data = [(k, v) if not isinstance(v, dict) else [(k + '.' + k2, v2) for k2, v2 in v.items()] for k, v in
                    data.items()]
            data = [item for sublist in data for item in sublist if isinstance(sublist, list)] + [y for y in data if
                                                                                                  not isinstance(y,
                                                                                                                 list)]
            data = dict(data)

        if drop_deeper:
            data = {k: v for k, v in data.items() if not isinstance(v, dict) or isinstance(v, list)}

        return data

# %%
b=json.loads(a[0])

# %%
c=flatten_dict(b)

# %%
c
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sun Aug 20 15:03:53 +0000 2017',
#  'entities.hashtags': [{'indices': [76, 92], 'text': 'SuperSoulSunday'}],
#  'entities.symbols': [],
#  'entities.urls': [],
#  'entities.user_mentions': [],
#  'favorite_count': 1901,
#  'favorited': False,
#  'geo': None,
#  'id': 899285865972629504,
#  'id_str': '899285865972629504',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'retweet_count': 156,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'text': "Morning everyone.. hope you'll join us LIVE streaming on Facebook right now!#SuperSoulSunday",
#  'truncated': False,
#  'user.contributors_enabled': False,
#  'user.created_at': 'Fri Jan 23 15:18:34 +0000 2009',
#  'user.default_profile': False,
#  'user.default_profile_image': False,
#  'user.description': '',
#  'user.favourites_count': 148,
#  'user.follow_request_sent': False,
#  'user.followers_count': 38210480,
#  'user.following': False,
#  'user.friends_count': 284,
#  'user.geo_enabled': False,
#  'user.has_extended_profile': False,
#  'user.id': 19397785,
#  'user.id_str': '19397785',
#  'user.is_translation_enabled': True,
#  'user.is_translator': False,
#  'user.lang': 'en',
#  'user.listed_count': 89689,
#  'user.location': '',
#  'user.name': 'Oprah Winfrey',
#  'user.notifications': False,
#  'user.profile_background_color': '131516',
#  'user.profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#  'user.profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#  'user.profile_background_tile': True,
#  'user.profile_banner_url': 'https://pbs.twimg.com/profile_banners/19397785/1419227197',
#  'user.profile_image_url': 'http://pbs.twimg.com/profile_images/771885422834098176/c5_Nj8j4_normal.jpg',
#  'user.profile_image_url_https': 'https://pbs.twimg.com/profile_images/771885422834098176/c5_Nj8j4_normal.jpg',
#  'user.profile_link_color': '009999',
#  'user.profile_sidebar_border_color': 'EEEEEE',
#  'user.profile_sidebar_fill_color': 'EFEFEF',
#  'user.profile_text_color': '333333',
#  'user.profile_use_background_image': True,
#  'user.protected': False,
#  'user.screen_name': 'Oprah',
#  'user.statuses_count': 12144,
#  'user.time_zone': 'Central Time (US & Canada)',
#  'user.translator_type': 'none',
#  'user.url': 'https://t.co/IKOnfAha8E',
#  'user.utc_offset': -18000,
#  'user.verified': True}

# %%
for item in c:
    for key, value in c.items():
        try:
            c[key] = str(value)
        except:
            print('x')

# %%
pd.options.display.max_columns=100

# %%
df = pd.DataFrame(c, index=[0])
df
# Out:
#   contributors coordinates                      created_at  \
# 0         None        None  Sun Aug 20 15:03:53 +0000 2017
#
#                                    entities.hashtags entities.symbols  \
# 0  [{'indices': [76, 92], 'text': 'SuperSoulSunda...               []
#
#   entities.urls entities.user_mentions favorite_count favorited   geo  \
# 0            []                     []           1901     False  None
#
#                    id              id_str in_reply_to_screen_name  \
# 0  899285865972629504  899285865972629504                    None
#
#   in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id  \
# 0                  None                      None                None
#
#   in_reply_to_user_id_str is_quote_status lang place retweet_count retweeted  \
# 0                    None           False   en  None           156     False
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text truncated  \
# 0  Morning everyone.. hope you'll join us LIVE st...     False
#
#   user.contributors_enabled                 user.created_at  \
# 0                     False  Fri Jan 23 15:18:34 +0000 2009
#
#   user.default_profile user.default_profile_image user.description  \
# 0                False                      False
#
#   user.favourites_count user.follow_request_sent user.followers_count  \
# 0                   148                    False             38210480
#
#   user.following user.friends_count user.geo_enabled  \
# 0          False                284            False
#
#   user.has_extended_profile   user.id user.id_str user.is_translation_enabled  \
# 0                     False  19397785    19397785                        True
#
#   user.is_translator user.lang user.listed_count user.location      user.name  \
# 0              False        en             89689                Oprah Winfrey
#
#   user.notifications user.profile_background_color  \
# 0              False                        131516
#
#                    user.profile_background_image_url  \
# 0  http://abs.twimg.com/images/themes/theme14/bg.gif
#
#              user.profile_background_image_url_https  \
# 0  https://abs.twimg.com/images/themes/theme14/bg...
#
#   user.profile_background_tile  \
# 0                         True
#
#                              user.profile_banner_url  \
# 0  https://pbs.twimg.com/profile_banners/19397785...
#
#                               user.profile_image_url  \
# 0  http://pbs.twimg.com/profile_images/7718854228...
#
#                         user.profile_image_url_https user.profile_link_color  \
# 0  https://pbs.twimg.com/profile_images/771885422...                  009999
#
#   user.profile_sidebar_border_color user.profile_sidebar_fill_color  \
# 0                            EEEEEE                          EFEFEF
#
#   user.profile_text_color user.profile_use_background_image user.protected  \
# 0                  333333                              True          False
#
#   user.screen_name user.statuses_count              user.time_zone  \
# 0            Oprah               12144  Central Time (US & Canada)
#
#   user.translator_type                 user.url user.utc_offset user.verified
# 0                 none  https://t.co/IKOnfAha8E          -18000          True

# %%
df.to_csv('one.csv')

# %%
df.append(df)
# Out:
#   contributors coordinates                      created_at  \
# 0         None        None  Sun Aug 20 15:03:53 +0000 2017
# 0         None        None  Sun Aug 20 15:03:53 +0000 2017
#
#                                    entities.hashtags entities.symbols  \
# 0  [{'indices': [76, 92], 'text': 'SuperSoulSunda...               []
# 0  [{'indices': [76, 92], 'text': 'SuperSoulSunda...               []
#
#   entities.urls entities.user_mentions favorite_count favorited   geo  \
# 0            []                     []           1901     False  None
# 0            []                     []           1901     False  None
#
#                    id              id_str in_reply_to_screen_name  \
# 0  899285865972629504  899285865972629504                    None
# 0  899285865972629504  899285865972629504                    None
#
#   in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id  \
# 0                  None                      None                None
# 0                  None                      None                None
#
#   in_reply_to_user_id_str is_quote_status lang place retweet_count retweeted  \
# 0                    None           False   en  None           156     False
# 0                    None           False   en  None           156     False
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 0  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text truncated  \
# 0  Morning everyone.. hope you'll join us LIVE st...     False
# 0  Morning everyone.. hope you'll join us LIVE st...     False
#
#   user.contributors_enabled                 user.created_at  \
# 0                     False  Fri Jan 23 15:18:34 +0000 2009
# 0                     False  Fri Jan 23 15:18:34 +0000 2009
#
#   user.default_profile user.default_profile_image user.description  \
# 0                False                      False
# 0                False                      False
#
#   user.favourites_count user.follow_request_sent user.followers_count  \
# 0                   148                    False             38210480
# 0                   148                    False             38210480
#
#   user.following user.friends_count user.geo_enabled  \
# 0          False                284            False
# 0          False                284            False
#
#   user.has_extended_profile   user.id user.id_str user.is_translation_enabled  \
# 0                     False  19397785    19397785                        True
# 0                     False  19397785    19397785                        True
#
#   user.is_translator user.lang user.listed_count user.location      user.name  \
# 0              False        en             89689                Oprah Winfrey
# 0              False        en             89689                Oprah Winfrey
#
#   user.notifications user.profile_background_color  \
# 0              False                        131516
# 0              False                        131516
#
#                    user.profile_background_image_url  \
# 0  http://abs.twimg.com/images/themes/theme14/bg.gif
# 0  http://abs.twimg.com/images/themes/theme14/bg.gif
#
#              user.profile_background_image_url_https  \
# 0  https://abs.twimg.com/images/themes/theme14/bg...
# 0  https://abs.twimg.com/images/themes/theme14/bg...
#
#   user.profile_background_tile  \
# 0                         True
# 0                         True
#
#                              user.profile_banner_url  \
# 0  https://pbs.twimg.com/profile_banners/19397785...
# 0  https://pbs.twimg.com/profile_banners/19397785...
#
#                               user.profile_image_url  \
# 0  http://pbs.twimg.com/profile_images/7718854228...
# 0  http://pbs.twimg.com/profile_images/7718854228...
#
#                         user.profile_image_url_https user.profile_link_color  \
# 0  https://pbs.twimg.com/profile_images/771885422...                  009999
# 0  https://pbs.twimg.com/profile_images/771885422...                  009999
#
#   user.profile_sidebar_border_color user.profile_sidebar_fill_color  \
# 0                            EEEEEE                          EFEFEF
# 0                            EEEEEE                          EFEFEF
#
#   user.profile_text_color user.profile_use_background_image user.protected  \
# 0                  333333                              True          False
# 0                  333333                              True          False
#
#   user.screen_name user.statuses_count              user.time_zone  \
# 0            Oprah               12144  Central Time (US & Canada)
# 0            Oprah               12144  Central Time (US & Canada)
#
#   user.translator_type                 user.url user.utc_offset user.verified
# 0                 none  https://t.co/IKOnfAha8E          -18000          True
# 0                 none  https://t.co/IKOnfAha8E          -18000          True

# %%
pd.DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
pd.DataFrame(c, index=[0])
# Out:
#   contributors coordinates                      created_at  \
# 0         None        None  Sun Aug 20 15:03:53 +0000 2017
#
#                                    entities.hashtags entities.symbols  \
# 0  [{'indices': [76, 92], 'text': 'SuperSoulSunda...               []
#
#   entities.urls entities.user_mentions favorite_count favorited   geo  \
# 0            []                     []           1901     False  None
#
#                    id              id_str in_reply_to_screen_name  \
# 0  899285865972629504  899285865972629504                    None
#
#   in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id  \
# 0                  None                      None                None
#
#   in_reply_to_user_id_str is_quote_status lang place retweet_count retweeted  \
# 0                    None           False   en  None           156     False
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text truncated  \
# 0  Morning everyone.. hope you'll join us LIVE st...     False
#
#   user.contributors_enabled                 user.created_at  \
# 0                     False  Fri Jan 23 15:18:34 +0000 2009
#
#   user.default_profile user.default_profile_image user.description  \
# 0                False                      False
#
#   user.favourites_count user.follow_request_sent user.followers_count  \
# 0                   148                    False             38210480
#
#   user.following user.friends_count user.geo_enabled  \
# 0          False                284            False
#
#   user.has_extended_profile   user.id user.id_str user.is_translation_enabled  \
# 0                     False  19397785    19397785                        True
#
#   user.is_translator user.lang user.listed_count user.location      user.name  \
# 0              False        en             89689                Oprah Winfrey
#
#   user.notifications user.profile_background_color  \
# 0              False                        131516
#
#                    user.profile_background_image_url  \
# 0  http://abs.twimg.com/images/themes/theme14/bg.gif
#
#              user.profile_background_image_url_https  \
# 0  https://abs.twimg.com/images/themes/theme14/bg...
#
#   user.profile_background_tile  \
# 0                         True
#
#                              user.profile_banner_url  \
# 0  https://pbs.twimg.com/profile_banners/19397785...
#
#                               user.profile_image_url  \
# 0  http://pbs.twimg.com/profile_images/7718854228...
#
#                         user.profile_image_url_https user.profile_link_color  \
# 0  https://pbs.twimg.com/profile_images/771885422...                  009999
#
#   user.profile_sidebar_border_color user.profile_sidebar_fill_color  \
# 0                            EEEEEE                          EFEFEF
#
#   user.profile_text_color user.profile_use_background_image user.protected  \
# 0                  333333                              True          False
#
#   user.screen_name user.statuses_count              user.time_zone  \
# 0            Oprah               12144  Central Time (US & Canada)
#
#   user.translator_type                 user.url user.utc_offset user.verified
# 0                 none  https://t.co/IKOnfAha8E          -18000          True

# %%
pd.DataFrame().append(pd.DataFrame(c, index=[0]))
# Out:
#   contributors coordinates                      created_at  \
# 0         None        None  Sun Aug 20 15:03:53 +0000 2017
#
#                                    entities.hashtags entities.symbols  \
# 0  [{'indices': [76, 92], 'text': 'SuperSoulSunda...               []
#
#   entities.urls entities.user_mentions favorite_count favorited   geo  \
# 0            []                     []           1901     False  None
#
#                    id              id_str in_reply_to_screen_name  \
# 0  899285865972629504  899285865972629504                    None
#
#   in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id  \
# 0                  None                      None                None
#
#   in_reply_to_user_id_str is_quote_status lang place retweet_count retweeted  \
# 0                    None           False   en  None           156     False
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text truncated  \
# 0  Morning everyone.. hope you'll join us LIVE st...     False
#
#   user.contributors_enabled                 user.created_at  \
# 0                     False  Fri Jan 23 15:18:34 +0000 2009
#
#   user.default_profile user.default_profile_image user.description  \
# 0                False                      False
#
#   user.favourites_count user.follow_request_sent user.followers_count  \
# 0                   148                    False             38210480
#
#   user.following user.friends_count user.geo_enabled  \
# 0          False                284            False
#
#   user.has_extended_profile   user.id user.id_str user.is_translation_enabled  \
# 0                     False  19397785    19397785                        True
#
#   user.is_translator user.lang user.listed_count user.location      user.name  \
# 0              False        en             89689                Oprah Winfrey
#
#   user.notifications user.profile_background_color  \
# 0              False                        131516
#
#                    user.profile_background_image_url  \
# 0  http://abs.twimg.com/images/themes/theme14/bg.gif
#
#              user.profile_background_image_url_https  \
# 0  https://abs.twimg.com/images/themes/theme14/bg...
#
#   user.profile_background_tile  \
# 0                         True
#
#                              user.profile_banner_url  \
# 0  https://pbs.twimg.com/profile_banners/19397785...
#
#                               user.profile_image_url  \
# 0  http://pbs.twimg.com/profile_images/7718854228...
#
#                         user.profile_image_url_https user.profile_link_color  \
# 0  https://pbs.twimg.com/profile_images/771885422...                  009999
#
#   user.profile_sidebar_border_color user.profile_sidebar_fill_color  \
# 0                            EEEEEE                          EFEFEF
#
#   user.profile_text_color user.profile_use_background_image user.protected  \
# 0                  333333                              True          False
#
#   user.screen_name user.statuses_count              user.time_zone  \
# 0            Oprah               12144  Central Time (US & Canada)
#
#   user.translator_type                 user.url user.utc_offset user.verified
# 0                 none  https://t.co/IKOnfAha8E          -18000          True
