# %%
import pandas as pd

# %%
df=pd.read_csv('post_url.csv')
print df.shape

df2=df.iloc[2154:,:]

urls2 = zip(df['id'], df['post_url'])
len(urls2)

df2.head(3)
# Out:
# (210467, 10)
#           id                          post_url  note program_id   user_id  \
# 2154  610001  http://www.soyoung.com/p10385273     0     cp1040  u7708427
# 2155  610002  http://www.soyoung.com/p10355919     0     cp1040  u7707782
# 2156  610003   http://www.soyoung.com/p9983977     0     cp1040  u1579509
#
#      user_name                 date  pic_num rating  \
# 2154      田田蜜蜜  2016-12-21 17:30:10        2   100%
# 2155       莎美人  2016-12-19 18:07:33        6   100%
# 2156      izoe  2016-11-24 15:35:06        6   100%
#
#                       program_url
# 2154  http://y.soyoung.com/cp1040
# 2155  http://y.soyoung.com/cp1040
# 2156  http://y.soyoung.com/cp1040

# %%
df0=df[['id','post_url']]
df0.shape
# Out:
# (210467, 2)

# %%
past = df0.iloc[:2154]
past.shape
# Out:
# (2154, 2)

# %%
past.head(3)
# Out:
#        id                          post_url
# 0  607843  http://www.soyoung.com/p12360175
# 1  607844  http://www.soyoung.com/p10127503
# 2  607845   http://www.soyoung.com/p7615001

# %%
past.tail(3)
# Out:
#           id                          post_url
# 2151  609998  http://www.soyoung.com/p10398626
# 2152  609999  http://www.soyoung.com/p10398411
# 2153  610000  http://www.soyoung.com/p10397217

# %%
past.to_csv('60.csv', index=False)

# %%
df3.head(3)
# Out:
#           id                          post_url
# 2154  610001  http://www.soyoung.com/p10385273
# 2155  610002  http://www.soyoung.com/p10355919
# 2156  610003   http://www.soyoung.com/p9983977

# %%
df3.tail()
# Out:
#             id                         post_url
# 210462  856658  http://www.soyoung.com/p7588822
# 210463  856659  http://www.soyoung.com/p7541014
# 210464  856660  http://www.soyoung.com/p7299775
# 210465  856661  http://www.soyoung.com/p5680009
# 210466  856662  http://www.soyoung.com/p3447210

# %%
# splitting = [df3.iloc[i:i + 10000,:] for i in range(0, df3.shape[0], 10000)]
# len(splitting),type(splitting[0])
# Out:
# (21, pandas.core.frame.DataFrame)

# %% [markdown]
# ## by ID

# %%
(df3.id>i*10000) & (df3.id<=i*10000+10000)
# Out:
# 2154       True
# 2155       True
# 2156       True
# 2157       True
# 2158       True
# 2159       True
# 2160       True
# 2161       True
# 2162       True
# 2163       True
# 2164       True
# 2165       True
# 2166       True
# 2167       True
# 2168       True
# 2169       True
# 2170       True
# 2171       True
# 2172       True
# 2173       True
# 2174       True
# 2175       True
# 2176       True
# 2177       True
# 2178       True
# 2179       True
# 2180       True
# 2181       True
# 2182       True
# 2183       True
#           ...
# 210437    False
# 210438    False
# 210439    False
# 210440    False
# 210441    False
# 210442    False
# 210443    False
# 210444    False
# 210445    False
# 210446    False
# 210447    False
# 210448    False
# 210449    False
# 210450    False
# 210451    False
# 210452    False
# 210453    False
# 210454    False
# 210455    False
# 210456    False
# 210457    False
# 210458    False
# 210459    False
# 210460    False
# ...

# %%
splitting = [df3[(df3.id>i*10000) & (df3.id<=i*10000+10000)] for i in range(61,86)]
len(splitting),type(splitting[0])
# Out:
# (25, pandas.core.frame.DataFrame)

# %%
splitting[0]
# Out:
#            id                          post_url
# 2154   610001  http://www.soyoung.com/p10385273
# 2155   610002  http://www.soyoung.com/p10355919
# 2156   610003   http://www.soyoung.com/p9983977
# 2157   610004   http://www.soyoung.com/p9951537
# 2158   610005   http://www.soyoung.com/p9936145
# 2159   610006   http://www.soyoung.com/p9926306
# 2160   610007   http://www.soyoung.com/p9758421
# 2161   610008   http://www.soyoung.com/p9732465
# 2162   610009   http://www.soyoung.com/p9731415
# 2163   610010   http://www.soyoung.com/p9655937
# 2164   610011   http://www.soyoung.com/p9586120
# 2165   610012   http://www.soyoung.com/p9576159
# 2166   610013   http://www.soyoung.com/p9362563
# 2167   610014   http://www.soyoung.com/p9251522
# 2168   610015   http://www.soyoung.com/p9129961
# 2169   610016   http://www.soyoung.com/p9091862
# 2170   610017   http://www.soyoung.com/p8888086
# 2171   610018   http://www.soyoung.com/p8784093
# 2172   610019   http://www.soyoung.com/p8711370
# ...

# %%
m=60

for i in splitting:
    m+=1
    i.to_csv(str(m)+'.csv', index=False)

# %%
sixone=pd.read_csv('61.csv')
print sixone.shape
sixone.head()
# Out:
# (9956, 2)
#        id                          post_url
# 0  610001  http://www.soyoung.com/p10385273
# 1  610002  http://www.soyoung.com/p10355919
# 2  610003   http://www.soyoung.com/p9983977
# 3  610004   http://www.soyoung.com/p9951537
# 4  610005   http://www.soyoung.com/p9936145

# %%
sixone.tail()
# Out:
#           id                          post_url
# 9951  619996  http://www.soyoung.com/p12251880
# 9952  619997  http://www.soyoung.com/p11958459
# 9953  619998   http://www.soyoung.com/p5459275
# 9954  619999   http://www.soyoung.com/p5444466
# 9955  620000  http://www.soyoung.com/p13102382

# %%
eightthree=pd.read_csv('83.csv')
eightthree.shape
# Out:
# (1841, 2)

# %%
eightthree.head()
# Out:
#        id                          post_url
# 0  830003   http://www.soyoung.com/p7910501
# 1  830004   http://www.soyoung.com/p7889017
# 2  830015  http://www.soyoung.com/p13161517
# 3  830016  http://www.soyoung.com/p13146316
# 4  830039  http://www.soyoung.com/p11447146

# %%
eightthree.tail()
# Out:
#           id                          post_url
# 1836  839857  http://www.soyoung.com/p11745961
# 1837  839858  http://www.soyoung.com/p11637630
# 1838  839930  http://www.soyoung.com/p13162639
# 1839  839947  http://www.soyoung.com/p10694298
# 1840  839948  http://www.soyoung.com/p10666092
