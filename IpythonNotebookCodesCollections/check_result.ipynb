# %%
from collections import defaultdict
iniDict = defaultdict(lambda: None)

def flatten_dict(data, layers=1, drop_deeper=False):

        for _ in range(layers):
            data = [(k, v) if not isinstance(v, dict) else [(k + '.' + k2, v2) for k2, v2 in v.items()] for k, v in
                    data.items()]
            data = [item for sublist in data for item in sublist if isinstance(sublist, list)] + [y for y in data if
                                                                                                  not isinstance(y,

    list)]
            data = dict(data)

        if drop_deeper:
            data = {k: v for k, v in data.items() if not isinstance(v, dict) or isinstance(v, list)}

        return data

def get_columns(path):
    import re, json
    from time import ctime
    global failed_names, collect, n

    n+=1
    if n%5000==0 or n==1:
        print ctime(), ': processed', n, 'and failed: ',len(failed_names)
    get=[]

    with open(folder+path,'r') as fl:
        text=fl.read()
#         tree=etree.HTML(text)
    try:
#         script = tree.xpath('//script')[-2]
        data = re.search(r"window.profileData=(.*?)\n", text)
        jsondata=data.group(1)[:-1]

        json_dict = json.loads(jsondata)
        flat = flatten_dict(json_dict, layers=1)
        for i in flat:
            iniDict[i]=str(flat[i])
        collect.append(pd.DataFrame(iniDict, index=[path]))

#         return pd.DataFrame(iniDict, index=[0])
#         names = flat.keys()
#         return flat
    except Exception as e:
        print path,e
        failed_names.append(path)
        collect.append(pd.DataFrame(index=[path]))

folder = "Combined_cookie_htmls/"
failed_names , collect, n = [], [], 0

# %%
import os
import pandas as pd
os.chdir('../../weekly/')

# %%
# !ls|grep debug
# Out:
# clean_Json_all_cookie_debug_Dec_16_2017.csv
# old_Json_all_cookie_debug_Dec_16_2017.csv

# %%
df = pd.read_csv('./clean_Json_all_cookie_debug_Dec_16_2017.csv')
df.shape
# Out:
# (186855, 78)

# %%
df['index'].value_counts().head()
# Out:
# awillowhawk.html    1
# shahriz7.html       1
# tsigroup.html       1
# sertilekus.html     1
# iphonesree.html     1
# Name: index, dtype: int64

# %%
df['username'].value_counts().head()
# Out:
# fantazia         5
# pixperfection    5
# dodi20           5
# rivermiker       5
# sunny30051978    5
# Name: username, dtype: int64

# %%
df[df['username'] == "fantazia"]
# Out:
#                    index                                     abTests.CLT567  \
# 64266  way2earn2008.html  {u'variant': u'control', u'name': u'CLT-567-in...
# 64282       osonola.html  {u'variant': u'control', u'name': u'CLT-567-in...
# 64289   vw7979575vw.html  {u'variant': u'control', u'name': u'CLT-567-in...
# 64293      fantazia.html  {u'variant': u'control', u'name': u'CLT-567-in...
# 64299        bntbrl.html  {u'variant': u'control', u'name': u'CLT-567-in...
#
#       about.account_balances about.address  \
# 64266                   None          None
# 64282                   None          None
# 64289                   None          None
# 64293                   None          None
# 64299                   None          None
#
#                                             about.avatar  \
# 64266  /ppic/1214612/logo/595338/profile_logo_595338.jpg
# 64282                                   /img/unknown.png
# 64289   /ppic/653252/logo/280332/profile_logo_280332.jpg
# 64293   /ppic/653252/logo/280332/profile_logo_280332.jpg
# 64299                                   /img/unknown.png
#
#                                         about.avatar_cdn  \
# 64266  //cdn6.f-cdn.com/ppic/1214612/logo/595338/prof...
# 64282                   //cdn6.f-cdn.com/img/unknown.png
# 64289  //cdn3.f-cdn.com/ppic/653252/logo/280332/profi...
# 64293  //cdn3.f-cdn.com/ppic/653252/logo/280332/profi...
# 64299                   //cdn6.f-cdn.com/img/unknown.png
#
#                             about.avatar_large  \
# 64266   /ppic/1214610/logo/595338/Pakistan.jpg
# 64282                         /img/unknown.png
# 64289  /ppic/653251/logo/280332/gothic_034.jpg
# 64293  /ppic/653251/logo/280332/gothic_034.jpg
# 64299                         /img/unknown.png
#
#                                   about.avatar_large_cdn about.badges  \
# 64266  //cdn6.f-cdn.com/ppic/1214610/logo/595338/Paki...         None
# 64282                   //cdn6.f-cdn.com/img/unknown.png         None
# 64289  //cdn3.f-cdn.com/ppic/653251/logo/280332/gothi...         None
# 64293  //cdn3.f-cdn.com/ppic/653251/logo/280332/gothi...         None
# 64299                   //cdn6.f-cdn.com/img/unknown.png         None
#
#       about.bid_quality_details       ...         resume.exams  \
# 64266                      None       ...                   []
# 64282                      None       ...                   []
# 64289                      None       ...                   []
# 64293                      None       ...                   []
# 64299                      None       ...                   []
#
#        resume.experience resume.publications resume.show  \
# 64266                 []                  []       False
# 64282                 []                  []       False
# 64289                 []                  []       False
# 64293                 []                  []       False
# 64299                 []                  []       False
#
#                                                   skills timeOffset    userId  \
# 64266  [{u'usages': 0, u'seo_url': u'php', u'islocal'...        0.0  280332.0
# 64282  [{u'usages': 0, u'seo_url': u'php', u'islocal'...        0.0  280332.0
# 64289  [{u'usages': 0, u'seo_url': u'php', u'islocal'...        0.0  280332.0
# 64293  [{u'usages': 0, u'seo_url': u'php', u'islocal'...        0.0  280332.0
# 64299  [{u'usages': 0, u'seo_url': u'php', u'islocal'...        0.0  280332.0
#
#        username viewer public_firstname
# 64266  fantazia    0.0            Javed
# 64282  fantazia    0.0          osonola
# 64289  fantazia    0.0         Fantazia
# 64293  fantazia    0.0         Fantazia
# 64299  fantazia    0.0           Bntbrl
#
# [5 rows x 78 columns]

# %%
get_columns('way2earn2008.html')

# %%
collect[0]
# Out:
#                                                       abTests.CLT567  \
# way2earn2008.html  {u'variant': u'control', u'name': u'CLT-567-in...
#
#                   about.account_balances about.address  \
# way2earn2008.html                   None          None
#
#                                                         about.avatar  \
# way2earn2008.html  /ppic/1214612/logo/595338/profile_logo_595338.jpg
#
#                                                     about.avatar_cdn  \
# way2earn2008.html  //cdn6.f-cdn.com/ppic/1214612/logo/595338/prof...
#
#                                        about.avatar_large  \
# way2earn2008.html  /ppic/1214610/logo/595338/Pakistan.jpg
#
#                                               about.avatar_large_cdn  \
# way2earn2008.html  //cdn6.f-cdn.com/ppic/1214610/logo/595338/Paki...
#
#                   about.badges about.bid_quality_details about.chosen_role  \
# way2earn2008.html         None                      None                 1
#
#                    ...                                     resume.education  \
# way2earn2008.html  ...    [{u'activities': None, u'start_year': u'2000',...
#
#                                                         resume.exams  \
# way2earn2008.html  [{u'examEnabled': u'1', u'description': u'Nume...
#
#                                                    resume.experience  \
# way2earn2008.html  [{u'year_interval': u'-2007', u'month_interval...
#
#                                                  resume.publications  \
# way2earn2008.html  [{u'publisher': u'', u'title': u'Marketing', u...
#
#                   resume.show  \
# way2earn2008.html        True
#
#                                                               skills  \
# way2earn2008.html  [{u'usages': 4, u'seo_url': u'facebook_marketi...
#
#                   timeOffset  userId      username viewer
# way2earn2008.html        300  595338  way2earn2008      0
#
# [1 rows x 75 columns]
