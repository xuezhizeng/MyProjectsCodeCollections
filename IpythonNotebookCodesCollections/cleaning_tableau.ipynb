# %%
import ast
import pandas as pd
import numpy as np
import os
from time import ctime
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_rows=300
# %matplotlib inline

# %%
# %%time
df = pd.read_csv('./info.to.hive.csv')
print df.shape
# Out:
# (102514, 26)
# CPU times: user 545 ms, sys: 20 ms, total: 565 ms
# Wall time: 1.41 s

# %%
df
# Out:
#          label   user_id                              about.company  \
# 0         Male   1018449                                      itsol
# 1       Female   8288991                                       None
# 2         Male    314218                            goldengatemedia
# 3       Female   1240449                                       None
# 4         Male   2157025                                       None
# 5       Female   9777483                                       None
# 6       Female   1503049                                 shopatwork
# 7         Male   3321030                         Innosoft Solutions
# 8         Male  11044746                                       None
# 9         Male   8868134                                  Vemomedia
# 10        Male   8830673                                       None
# 11        Male   8836659                            CDSINFORMATIQUE
# 12      Female   1384168                  Alachua County Data Entry
# ...
