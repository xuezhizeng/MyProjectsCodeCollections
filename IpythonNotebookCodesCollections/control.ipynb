# %% [markdown]
# https://github.com/dpressel/rude-carnie

# %% [markdown]
# https://github.com/coursera-dl/coursera-dl/issues/554

# %% [markdown]
# https://github.com/tensorflow/models/issues/729

# %%
import os
import cv2
from IPython.core.display import Image  
import matplotlib.pyplot as plt


def showpic(lists):
    n=len(lists)
    print 'viewing ',n, 'pics'
    
    f=0
    for i in lists:
        f+=1
        name=path+i
        if f%2==1:
            print f, '-', f+1
            plt.figure(figsize=((10,7)))
            plt.subplot(1,2,1)
            plt.imshow(plt.imread(name))
        else:

            plt.subplot(1,2,2)
            plt.imshow(plt.imread(name))
            plt.show()

# %% [markdown]
# https://github.com/floydhub/dl-docker

# %% [markdown]
# https://github.com/NVIDIA/nvidia-docker/wiki/Installation

# %%
# !ls
# Out:
# 21936  22801  control.ipynb  rude-carnie  test.ipynb

# %%
# !pwd
# Out:
# /home/soyoung/face/Freelancer/Tensorflow

# %%
path='/home/soyoung/face/Freelancer/bidderPics/'

# %%
names = os.listdir(path)
len(names)
# Out:
# 26349

# %%
showpic(names[113:115])
# Out:
# viewing  2 pics
# 1 - 2

# %%
names[113:115]
# Out:
# ['600125_profile.jpg', '1573462_profile.jpg']

# %%
# !python rude-carnie/guess.py --model_type inception --model_dir 22801 --filename /home/soyoung/face/Freelancer/bidderPics/1573462_profile.jpg
# Out:
# 2017-09-30 00:32:17.726046: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-09-30 00:32:17.726084: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-09-30 00:32:17.726098: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2017-09-30 00:32:17.726109: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
# !python rude-carnie/guess.py --class_type gender --model_type inception --model_dir 21936 --filename /home/soyoung/face/Freelancer/bidderPics/1573462_profile.jpg
# Out:
# 2017-09-30 00:35:50.137294: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-09-30 00:35:50.137315: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-09-30 00:35:50.137330: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2017-09-30 00:35:50.137338: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
# !python rude-carnie/guess.py --class_type gender --model_type inception --model_dir 21936 --filename /home/soyoung/face/Freelancer/bidderPics/600125_profile.jpg
# Out:
# 2017-09-30 00:36:53.273670: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-09-30 00:36:53.273689: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-09-30 00:36:53.273705: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2017-09-30 00:36:53.273711: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
# !python rude-carnie/guess.py --model_type inception --model_dir 22801 --filename /home/soyoung/face/Freelancer/bidderPics/600125_profile.jpg
# Out:
# 2017-09-30 00:37:17.500224: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-09-30 00:37:17.500244: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-09-30 00:37:17.500259: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2017-09-30 00:37:17.500264: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
# %%time
# !python rude-carnie/guess.py --class_type gender --model_type inception --model_dir 21936 --filename /home/soyoung/face/Freelancer/bidderPics/600125_profile.jpg
# Out:
# 2017-09-30 00:38:03.916233: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-09-30 00:38:03.916253: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-09-30 00:38:03.916268: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2017-09-30 00:38:03.916273: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
100000*8/60/60
# Out:
# 222
