# %%
# !ls
# Out:
# all_img_urls.csv  img_18  img_3   img_41  img_53  img_65  img_77
# arch		  img_19  img_30  img_42  img_54  img_66  img_78
# csv		  img_2   img_31  img_43  img_55  img_67  img_79
# diff_img_mod.py   img_20  img_32  img_44  img_56  img_68  img_8
# img_1		  img_21  img_33  img_45  img_57  img_69  img_80
# img_10		  img_22  img_34  img_46  img_58  img_7   img_9
# img_11		  img_23  img_35  img_47  img_59  img_70  img_ready.py
# img_12		  img_24  img_36  img_48  img_6   img_71  img_ready_all.ipynb
# img_13		  img_25  img_37  img_49  img_60  img_72  main.ipynb
# img_14		  img_26  img_38  img_5   img_61  img_73  split_csv.ipynb
# img_15		  img_27  img_39  img_50  img_62  img_74
# img_16		  img_28  img_4   img_51  img_63  img_75
# img_17		  img_29  img_40  img_52  img_64  img_76

# %%
from time import time,ctime
for i in range(1,81):
    start=time()
    # !python -u diff_img_mod.py {i}
    print
    print ctime()
    print '\n',i,'batch 10000 images used {:.2f} s'.format(time()-start),'\n\n\n!!!'
# Out:
# [Errno 17] File exists: 'img_1'
# dir img_1 exists
# 10000  pics
# (9997, 1)
# getiing  1 diff new pics!
# X1 X3 local variable 'img_request' referenced before assignment
# X4 used 0.00s| 10000.00% 100/1
#
# Wed Sep  6 22:39:45 2017
#
# 1 batch 10000 images used 0.78 s
#
#
# !!!
# [Errno 17] File exists: 'img_2'
# dir img_2 exists
# 10000  pics
# (9996, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:39:46 2017
#
# 2 batch 10000 images used 0.77 s
#
#
# !!!
# [Errno 17] File exists: 'img_3'
# dir img_3 exists
# 10000  pics
# (9996, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:39:46 2017
#
# 3 batch 10000 images used 0.77 s
#
#
# !!!
# [Errno 17] File exists: 'img_4'
# dir img_4 exists
# 10000  pics
# (9995, 1)
# getiing  1 diff new pics!
# X1 X3 local variable 'img_request' referenced before assignment
# X4 used 0.00s| 10000.00% 100/1
#
# Wed Sep  6 22:39:47 2017
#
# 4 batch 10000 images used 0.81 s
#
#
# !!!
# [Errno 17] File exists: 'img_5'
# dir img_5 exists
# 10000  pics
# (9997, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:39:48 2017
#
# 5 batch 10000 images used 0.77 s
#
#
# !!!
# [Errno 17] File exists: 'img_6'
# dir img_6 exists
# 10000  pics
# (9996, 1)
# getiing  1 diff new pics!
# used 1.12s| 10000.00% 100/1
#
# Wed Sep  6 22:39:50 2017
#
# 6 batch 10000 images used 1.88 s
#
#
# !!!
# [Errno 17] File exists: 'img_7'
# dir img_7 exists
# 10000  pics
# (9997, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:39:51 2017
#
# 7 batch 10000 images used 0.78 s
#
#
# !!!
# [Errno 17] File exists: 'img_8'
# dir img_8 exists
# 10000  pics
# (9996, 1)
# getiing  5 diff new pics!
# X2 X2 X2 X2 X2 used 3.54s| 2000.00% 100/5
#
# Wed Sep  6 22:39:55 2017
#
# 8 batch 10000 images used 4.31 s
#
#
# !!!
# [Errno 17] File exists: 'img_9'
# dir img_9 exists
# 10000  pics
# (9995, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:39:56 2017
#
# 9 batch 10000 images used 0.78 s
#
#
# !!!
# [Errno 17] File exists: 'img_10'
# dir img_10 exists
# 10000  pics
# (9994, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:39:56 2017
#
# 10 batch 10000 images used 0.78 s
#
#
# !!!
# [Errno 17] File exists: 'img_11'
# dir img_11 exists
# 10000  pics
# (9998, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:39:57 2017
#
# 11 batch 10000 images used 0.77 s
#
#
# !!!
# [Errno 17] File exists: 'img_12'
# dir img_12 exists
# 10000  pics
# (9998, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:39:58 2017
#
# 12 batch 10000 images used 0.78 s
#
#
# !!!
# [Errno 17] File exists: 'img_13'
# dir img_13 exists
# 10000  pics
# (9997, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:39:59 2017
#
# 13 batch 10000 images used 0.77 s
#
#
# !!!
# [Errno 17] File exists: 'img_14'
# dir img_14 exists
# 10000  pics
# (9992, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:40:00 2017
#
# 14 batch 10000 images used 0.77 s
#
#
# !!!
# [Errno 17] File exists: 'img_15'
# dir img_15 exists
# 10000  pics
# (9992, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:40:00 2017
#
# 15 batch 10000 images used 0.78 s
#
#
# !!!
# [Errno 17] File exists: 'img_16'
# dir img_16 exists
# 10000  pics
# (9995, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:40:01 2017
#
# 16 batch 10000 images used 0.78 s
#
#
# !!!
# [Errno 17] File exists: 'img_17'
# dir img_17 exists
# 10000  pics
# (9989, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:40:02 2017
#
# 17 batch 10000 images used 0.78 s
#
#
# !!!
# [Errno 17] File exists: 'img_18'
# dir img_18 exists
# 10000  pics
# (9995, 1)
# getiing  1 diff new pics!
# used 0.16s| 10000.00% 100/1
#
# Wed Sep  6 22:40:03 2017
#
# 18 batch 10000 images used 0.95 s
#
#
# !!!
# [Errno 17] File exists: 'img_19'
# dir img_19 exists
# 10000  pics
# (9998, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:40:04 2017
#
# 19 batch 10000 images used 0.77 s
#
#
# !!!
# [Errno 17] File exists: 'img_20'
# dir img_20 exists
# 10000  pics
# (9995, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:40:04 2017
#
# 20 batch 10000 images used 0.77 s
#
#
# !!!
# [Errno 17] File exists: 'img_21'
# dir img_21 exists
# 10000  pics
# (9994, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:40:05 2017
#
# 21 batch 10000 images used 0.77 s
#
#
# !!!
# [Errno 17] File exists: 'img_22'
# dir img_22 exists
# 10000  pics
# (9998, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:40:06 2017
#
# 22 batch 10000 images used 0.77 s
#
#
# !!!
# [Errno 17] File exists: 'img_23'
# dir img_23 exists
# 10000  pics
# (9998, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:40:07 2017
#
# 23 batch 10000 images used 0.77 s
#
#
# !!!
# [Errno 17] File exists: 'img_24'
# dir img_24 exists
# 10000  pics
# (9997, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:40:07 2017
#
# 24 batch 10000 images used 0.78 s
#
#
# !!!
# [Errno 17] File exists: 'img_25'
# dir img_25 exists
# 10000  pics
# (9996, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:40:08 2017
#
# 25 batch 10000 images used 0.77 s
#
#
# !!!
# [Errno 17] File exists: 'img_26'
# dir img_26 exists
# 10000  pics
# (9997, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:40:09 2017
#
# 26 batch 10000 images used 0.77 s
#
#
# !!!
# [Errno 17] File exists: 'img_27'
# dir img_27 exists
# 10000  pics
# (9997, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:40:10 2017
#
# 27 batch 10000 images used 0.78 s
#
#
# !!!
# [Errno 17] File exists: 'img_28'
# dir img_28 exists
# 10000  pics
# (9999, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:40:11 2017
#
# 28 batch 10000 images used 0.77 s
#
#
# !!!
# [Errno 17] File exists: 'img_29'
# dir img_29 exists
# 10000  pics
# (9993, 1)
# getiing  5 diff new pics!
# ^C
# Traceback (most recent call last):
#   File "diff_img_mod.py", line 137, in <module>
#     batch(i)
#   File "diff_img_mod.py", line 70, in batch
#     executor.map(download_image, subber)
#   File "/home/saya/anaconda2/lib/python2.7/site-packages/concurrent/futures/_base.py", line 630, in __exit__
#     self.shutdown(wait=True)
#   File "/home/saya/anaconda2/lib/python2.7/site-packages/concurrent/futures/thread.py", line 148, in shutdown
#     t.join(sys.maxint)
#   File "/home/saya/anaconda2/lib/python2.7/threading.py", line 951, in join
#     self.__block.wait(delay)
#   File "/home/saya/anaconda2/lib/python2.7/threading.py", line 359, in wait
#     _sleep(delay)
# KeyboardInterrupt
#
# Wed Sep  6 22:43:26 2017
#
# 29 batch 10000 images used 195.87 s
#
#
# !!!
# [Errno 17] File exists: 'img_30'
# dir img_30 exists
# 10000  pics
# (9997, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:43:27 2017
#
# 30 batch 10000 images used 0.78 s
#
#
# !!!
# [Errno 17] File exists: 'img_31'
# dir img_31 exists
# 10000  pics
# (9992, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:43:28 2017
#
# 31 batch 10000 images used 0.78 s
#
#
# !!!
# [Errno 17] File exists: 'img_32'
# dir img_32 exists
# 10000  pics
# (9996, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:43:29 2017
#
# 32 batch 10000 images used 0.78 s
#
#
# !!!
# [Errno 17] File exists: 'img_33'
# dir img_33 exists
# 10000  pics
# (9993, 1)
# getiing  2 diff new pics!
# X1 X3 X1local variable 'img_request' referenced before assignment
# X4 X3 local variable 'img_request' referenced before assignment
# X4 used 0.00s| 5000.00% 100/2
#
# Wed Sep  6 22:43:30 2017
#
# 33 batch 10000 images used 0.78 s
#
#
# !!!
# [Errno 17] File exists: 'img_34'
# dir img_34 exists
# 10000  pics
# (9995, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:43:30 2017
#
# 34 batch 10000 images used 0.78 s
#
#
# !!!
# [Errno 17] File exists: 'img_35'
# dir img_35 exists
# 10000  pics
# (9996, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:43:31 2017
#
# 35 batch 10000 images used 0.78 s
#
#
# !!!
# [Errno 17] File exists: 'img_36'
# dir img_36 exists
# 10000  pics
# (9998, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:43:32 2017
#
# 36 batch 10000 images used 0.79 s
#
#
# !!!
# [Errno 17] File exists: 'img_37'
# dir img_37 exists
# 10000  pics
# (10000, 1)
# getiing  2 diff new pics!
# used 2.57s| 5000.00% 100/2
#
# Wed Sep  6 22:43:35 2017
#
# 37 batch 10000 images used 3.33 s
#
#
# !!!
# [Errno 17] File exists: 'img_38'
# dir img_38 exists
# 10000  pics
# (9997, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:43:36 2017
#
# 38 batch 10000 images used 0.78 s
#
#
# !!!
# [Errno 17] File exists: 'img_39'
# dir img_39 exists
# 10000  pics
# (9999, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:43:37 2017
#
# 39 batch 10000 images used 0.77 s
#
#
# !!!
# [Errno 17] File exists: 'img_40'
# dir img_40 exists
# 10000  pics
# (9994, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:43:38 2017
#
# 40 batch 10000 images used 0.78 s
#
#
# !!!
# [Errno 17] File exists: 'img_41'
# dir img_41 exists
# 10000  pics
# (9996, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:43:38 2017
#
# 41 batch 10000 images used 0.77 s
#
#
# !!!
# [Errno 17] File exists: 'img_42'
# dir img_42 exists
# 10000  pics
# (9997, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:43:39 2017
#
# 42 batch 10000 images used 0.77 s
#
#
# !!!
# [Errno 17] File exists: 'img_43'
# dir img_43 exists
# 10000  pics
# (9995, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:43:40 2017
#
# 43 batch 10000 images used 0.77 s
#
#
# !!!
# [Errno 17] File exists: 'img_44'
# dir img_44 exists
# 10000  pics
# (9994, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:43:41 2017
#
# 44 batch 10000 images used 0.78 s
#
#
# !!!
# [Errno 17] File exists: 'img_45'
# dir img_45 exists
# 10000  pics
# (9995, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:43:41 2017
#
# 45 batch 10000 images used 0.77 s
#
#
# !!!
# [Errno 17] File exists: 'img_46'
# dir img_46 exists
# 10000  pics
# (9995, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:43:42 2017
#
# 46 batch 10000 images used 0.77 s
#
#
# !!!
# [Errno 17] File exists: 'img_47'
# dir img_47 exists
# 10000  pics
# (9999, 1)
# getiing  1 diff new pics!
# used 1.42s| 10000.00% 100/1
#
# Wed Sep  6 22:43:44 2017
#
# 47 batch 10000 images used 2.23 s
#
#
# !!!
# [Errno 17] File exists: 'img_48'
# dir img_48 exists
# 10000  pics
# (9996, 1)
# getiing  8 diff new pics!
# X2 X2 X2 X2 X2 X2 X2 X2 used 2.90s| 1250.00% 100/8
#
# Wed Sep  6 22:43:48 2017
#
# 48 batch 10000 images used 3.67 s
#
#
# !!!
# [Errno 17] File exists: 'img_49'
# dir img_49 exists
# 10000  pics
# (9991, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:43:49 2017
#
# 49 batch 10000 images used 0.79 s
#
#
# !!!
# [Errno 17] File exists: 'img_50'
# dir img_50 exists
# 10000  pics
# (9997, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:43:50 2017
#
# 50 batch 10000 images used 0.77 s
#
#
# !!!
# [Errno 17] File exists: 'img_51'
# dir img_51 exists
# 10000  pics
# (9998, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:43:50 2017
#
# 51 batch 10000 images used 0.78 s
#
#
# !!!
# [Errno 17] File exists: 'img_52'
# dir img_52 exists
# 10000  pics
# (9997, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:43:51 2017
#
# 52 batch 10000 images used 0.77 s
#
#
# !!!
# [Errno 17] File exists: 'img_53'
# dir img_53 exists
# 10000  pics
# (9997, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:43:52 2017
#
# 53 batch 10000 images used 0.79 s
#
#
# !!!
# [Errno 17] File exists: 'img_54'
# dir img_54 exists
# 10000  pics
# (9996, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:43:53 2017
#
# 54 batch 10000 images used 0.78 s
#
#
# !!!
# [Errno 17] File exists: 'img_55'
# dir img_55 exists
# 10000  pics
# (9996, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:43:54 2017
#
# 55 batch 10000 images used 0.76 s
#
#
# !!!
# [Errno 17] File exists: 'img_56'
# dir img_56 exists
# 10000  pics
# (9997, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:43:54 2017
#
# 56 batch 10000 images used 0.78 s
#
#
# !!!
# [Errno 17] File exists: 'img_57'
# dir img_57 exists
# 10000  pics
# (9993, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:43:55 2017
#
# 57 batch 10000 images used 0.78 s
#
#
# !!!
# [Errno 17] File exists: 'img_58'
# dir img_58 exists
# 10000  pics
# (9999, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:43:56 2017
#
# 58 batch 10000 images used 0.77 s
#
#
# !!!
# [Errno 17] File exists: 'img_59'
# dir img_59 exists
# 10000  pics
# (9995, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:43:57 2017
#
# 59 batch 10000 images used 0.78 s
#
#
# !!!
# [Errno 17] File exists: 'img_60'
# dir img_60 exists
# 10000  pics
# (9998, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:43:57 2017
#
# 60 batch 10000 images used 0.78 s
#
#
# !!!
# [Errno 17] File exists: 'img_61'
# dir img_61 exists
# 10000  pics
# (9996, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:43:58 2017
#
# 61 batch 10000 images used 0.77 s
#
#
# !!!
# [Errno 17] File exists: 'img_62'
# dir img_62 exists
# 10000  pics
# (9996, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:43:59 2017
#
# 62 batch 10000 images used 0.80 s
#
#
# !!!
# [Errno 17] File exists: 'img_63'
# dir img_63 exists
# 10000  pics
# (9995, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:44:00 2017
#
# 63 batch 10000 images used 0.77 s
#
#
# !!!
# [Errno 17] File exists: 'img_64'
# dir img_64 exists
# 10000  pics
# (9994, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:44:01 2017
#
# 64 batch 10000 images used 0.79 s
#
#
# !!!
# [Errno 17] File exists: 'img_65'
# dir img_65 exists
# 10000  pics
# (9997, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:44:01 2017
#
# 65 batch 10000 images used 0.78 s
#
#
# !!!
# [Errno 17] File exists: 'img_66'
# dir img_66 exists
# 10000  pics
# (9995, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:44:02 2017
#
# 66 batch 10000 images used 0.78 s
#
#
# !!!
# [Errno 17] File exists: 'img_67'
# dir img_67 exists
# 10000  pics
# (9993, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:44:03 2017
#
# 67 batch 10000 images used 0.78 s
#
#
# !!!
# [Errno 17] File exists: 'img_68'
# dir img_68 exists
# 10000  pics
# (9996, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:44:04 2017
#
# 68 batch 10000 images used 0.79 s
#
#
# !!!
# [Errno 17] File exists: 'img_69'
# dir img_69 exists
# 10000  pics
# (9996, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:44:04 2017
#
# 69 batch 10000 images used 0.80 s
#
#
# !!!
# [Errno 17] File exists: 'img_70'
# dir img_70 exists
# 10000  pics
# (9997, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:44:05 2017
#
# 70 batch 10000 images used 0.77 s
#
#
# !!!
# [Errno 17] File exists: 'img_71'
# dir img_71 exists
# 10000  pics
# (9997, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:44:06 2017
#
# 71 batch 10000 images used 0.79 s
#
#
# !!!
# [Errno 17] File exists: 'img_72'
# dir img_72 exists
# 10000  pics
# (9999, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:44:07 2017
#
# 72 batch 10000 images used 0.79 s
#
#
# !!!
# [Errno 17] File exists: 'img_73'
# dir img_73 exists
# 10000  pics
# (9999, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:44:08 2017
#
# 73 batch 10000 images used 0.78 s
#
#
# !!!
# [Errno 17] File exists: 'img_74'
# dir img_74 exists
# 10000  pics
# (9996, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:44:08 2017
#
# 74 batch 10000 images used 0.77 s
#
#
# !!!
# [Errno 17] File exists: 'img_75'
# dir img_75 exists
# 10000  pics
# (9999, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:44:09 2017
#
# 75 batch 10000 images used 0.79 s
#
#
# !!!
# [Errno 17] File exists: 'img_76'
# dir img_76 exists
# 10000  pics
# (10000, 1)
# getiing  1 diff new pics!
# X2 used 2.82s| 10000.00% 100/1
#
# Wed Sep  6 22:44:13 2017
#
# 76 batch 10000 images used 3.60 s
#
#
# !!!
# [Errno 17] File exists: 'img_77'
# dir img_77 exists
# 10000  pics
# (9996, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:44:14 2017
#
# 77 batch 10000 images used 0.77 s
#
#
# !!!
# [Errno 17] File exists: 'img_78'
# dir img_78 exists
# 10000  pics
# (9999, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:44:14 2017
#
# 78 batch 10000 images used 0.77 s
#
#
# !!!
# [Errno 17] File exists: 'img_79'
# dir img_79 exists
# 10000  pics
# (9994, 1)
# getiing  0 diff new pics!
#
# Wed Sep  6 22:44:15 2017
#
# 79 batch 10000 images used 0.77 s
#
#
# !!!
# [Errno 17] File exists: 'img_80'
# dir img_80 exists
# 3038  pics
# (3037, 1)
# getiing  2 diff new pics!
# X2 X2 used 2.94s| 5000.00% 100/2
#
# Wed Sep  6 22:44:19 2017
#
# 80 batch 10000 images used 3.68 s
#
#
# !!!
