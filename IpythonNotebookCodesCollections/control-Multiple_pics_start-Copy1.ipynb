# %%
import pandas as pd

# %%
import os
import cv2
from IPython.core.display import Image  
import matplotlib.pyplot as plt

# %%
# %%time
# !python rude-carnie/guess.py --class_type gender --model_type inception --model_dir 21936 \
--filename /home/soyoung/face/Freelancer/Tensorflow/bidder1.txt --target /home/soyoung/face/Freelancer/Tensorflow/bidder1_gender_predict.csv
# Out:
# 2017-10-01 00:42:34.389349: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-10-01 00:42:34.389383: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-10-01 00:42:34.389394: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2017-10-01 00:42:34.389402: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-10-01 00:42:34.389410: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# 2017-10-01 00:42:34.504342: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:893] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2017-10-01 00:42:34.505003: I tensorflow/core/common_runtime/gpu/gpu_device.cc:955] Found device 0 with properties:
# name: GeForce GTX 750 Ti
# major: 5 minor: 0 memoryClockRate (GHz) 1.0195
# pciBusID 0000:02:00.0
# Total memory: 1.96GiB
# Free memory: 198.69MiB
# 2017-10-01 00:42:34.505085: I tensorflow/core/common_runtime/gpu/gpu_device.cc:976] DMA: 0
# 2017-10-01 00:42:34.505102: I tensorflow/core/common_runtime/gpu/gpu_device.cc:986] 0:   Y
# 2017-10-01 00:42:34.505118: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1045] Creating TensorFlow device (/gpu:0) -> (device: 0, name: GeForce GTX 750 Ti, pci bus id: 0000:02:00.0)
# 2017-10-01 00:42:34.509067: E tensorflow/stream_executor/cuda/cuda_driver.cc:924] failed to allocate 198.69M (208338944 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY
# Executing on /cpu:0
# selected (fine-tuning) inception model
# 21936/checkpoint-14999
# 2017-10-01 00:42:39.780354: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1045] Creating TensorFlow device (/gpu:0) -> (device: 0, name: GeForce GTX 750 Ti, pci bus id: 0000:02:00.0)
# Creating output file /home/soyoung/face/Freelancer/Tensorflow/bidder1_gender_predict.csv
# ['/home/soyoung/face/Freelancer/headPics/bidderPics/1507866_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/38007_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1065281_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1304504_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/732274_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1250371_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1579934_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1536112_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1460850_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1383022_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1424982_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1253920_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1474941_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/560570_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/897455_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1390703_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1470703_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1359352_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1139396_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1549351_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1557321_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1071229_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/905557_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1383758_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/209751_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1304267_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/528617_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1062035_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1300764_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/354604_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1371086_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1265489_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1568271_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1302291_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1149237_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1507847_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1575872_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1514893_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1529227_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1362464_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1514696_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1130854_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1499450_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/780478_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1573682_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1209380_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/553387_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1172596_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/982554_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1148193_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1460657_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1360492_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/523868_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1513886_profile.png', '/home/soyoung/face/Freelancer/headPics/bidderPics/1352903_profile.png ...
# Running file /home/soyoung/face/Freelancer/headPics/bidderPics/1507866_profile.png
# Converting PNG to JPEG for /home/soyoung/face/Freelancer/headPics/bidderPics/1507866_profile.png
# Running multi-cropped image
# Guess @ 1 M, prob = 0.72
# Running file /home/soyoung/face/Freelancer/headPics/bidderPics/38007_profile.png
# Converting PNG to JPEG for /home/soyoung/face/Freelancer/headPics/bidderPics/38007_profile.png
# Running multi-cropped image
# Guess @ 1 F, prob = 0.56
# Running file /home/soyoung/face/Freelancer/headPics/bidderPics/1065281_profile.png
# Converting PNG to JPEG for /home/soyoung/face/Freelancer/headPics/bidderPics/1065281_profile.png
# Running multi-cropped image
# Guess @ 1 M, prob = 0.98
# Running file /home/soyoung/face/Freelancer/headPics/bidderPics/1304504_profile.png
# Converting PNG to JPEG for /home/soyoung/face/Freelancer/headPics/bidderPics/1304504_profile.png
# Running multi-cropped image
# Guess @ 1 F, prob = 1.00
# Running file /home/soyoung/face/Freelancer/headPics/bidderPics/732274_profile.png
# Converting PNG to JPEG for /home/soyoung/face/Freelancer/headPics/bidderPics/732274_profile.png
# Running multi-cropped image
# Guess @ 1 M, prob = 0.84
# Running file /home/soyoung/face/Freelancer/headPics/bidderPics/1250371_profile.png
# Converting PNG to JPEG for /home/soyoung/face/Freelancer/headPics/bidderPics/1250371_profile.png
# Running multi-cropped image
# Guess @ 1 M, prob = 1.00
# Running file /home/soyoung/face/Freelancer/headPics/bidderPics/1579934_profile.png
# Converting PNG to JPEG for /home/soyoung/face/Freelancer/headPics/bidderPics/1579934_profile.png
# Running multi-cropped image
# Guess @ 1 F, prob = 0.90
# Running file /home/soyoung/face/Freelancer/headPics/bidderPics/1536112_profile.png
# Converting PNG to JPEG for /home/soyoung/face/Freelancer/headPics/bidderPics/1536112_profile.png
# Running multi-cropped image
# Guess @ 1 M, prob = 0.97
# Running file /home/soyoung/face/Freelancer/headPics/bidderPics/1460850_profile.png
# Converting PNG to JPEG for /home/soyoung/face/Freelancer/headPics/bidderPics/1460850_profile.png
# Running multi-cropped image
# Guess @ 1 M, prob = 0.73
# Running file /home/soyoung/face/Freelancer/headPics/bidderPics/1383022_profile.png
# Converting PNG to JPEG for /home/soyoung/face/Freelancer/headPics/bidderPics/1383022_profile.png
# Running multi-cropped image
# Guess @ 1 M, prob = 0.93
# Running file /home/soyoung/face/Freelancer/headPics/bidderPics/1424982_profile.png
# Converting PNG to JPEG for /home/soyoung/face/Freelancer/headPics/bidderPics/1424982_profile.png
# Running multi-cropped image
# Guess @ 1 M, prob = 0.81
# Running file /home/soyoung/face/Freelancer/headPics/bidderPics/1253920_profile.png
# Converting PNG to JPEG for /home/soyoung/face/Freelancer/headPics/bidderPics/1253920_profile.png
# Running multi-cropped image
# Guess @ 1 F, prob = 0.80
# Running file /home/soyoung/face/Freelancer/headPics/bidderPics/1474941_profile.png
# Converting PNG to JPEG for /home/soyoung/face/Freelancer/headPics/bidderPics/1474941_profile.png
# Running multi-cropped image

# %% [markdown]
# CPU times: user 2min 18s, sys: 17 s, total: 2min 35s
# Wall time: 1h 34min 33s

# %%
df = pd.read_csv('bidder1_gender_predict.csv')
df.shape

# %%
df.shape
# Out:
# (896, 3)

# %%
df.head()
# Out:
#                                                 file label  score
# 0  /home/soyoung/face/Freelancer/headPics/bidderP...     M   0.72
# 1  /home/soyoung/face/Freelancer/headPics/bidderP...     F   0.56
# 2  /home/soyoung/face/Freelancer/headPics/bidderP...     M   0.98
# 3  /home/soyoung/face/Freelancer/headPics/bidderP...     F   1.00
# 4  /home/soyoung/face/Freelancer/headPics/bidderP...     M   0.84

# %%
done = df['file']
len(done)
# Out:
# 896

# %%
should = pd.read_fwf('bidder1.txt',names =['url'])
should.head()

# %%
should.shape
# Out:
# (10456, 1)

# %%
wanted=should['url']
len(wanted)
# Out:
# 10456

# %%
len(set(wanted)-set(done))
# Out:
# 9561

# %%
diff = set(wanted)-set(done)
type(diff)

# %%
len(diff)
# Out:
# 9561

# %%
# %%time
with open('bidder1_diff.txt','w+') as fl:
    for i in diff:
        fl.writelines(i+'\n')

# %%
# %%time
# !python rude-carnie/guess.py --class_type gender --model_type inception --model_dir 21936 \
--filename /home/soyoung/face/Freelancer/Tensorflow/bidder1_diff.txt --target /home/soyoung/face/Freelancer/Tensorflow/bidder1_gender_diff_predict.csv

# %%
df2 = pd.read_csv('bidder1_gender_diff_predict.csv')
df2.shape
# Out:
# (896, 3)

# %%
df2.head()
# Out:
#                                                 file label  score
# 0  /home/soyoung/face/Freelancer/headPics/bidderP...     M   0.82
# 1  /home/soyoung/face/Freelancer/headPics/bidderP...     M   0.92
# 2  /home/soyoung/face/Freelancer/headPics/bidderP...     M   0.83
# 3  /home/soyoung/face/Freelancer/headPics/bidderP...     F   0.70
# 4  /home/soyoung/face/Freelancer/headPics/bidderP...     F   0.93

# %%
df.head()
# Out:
#                                                 file label  score
# 0  /home/soyoung/face/Freelancer/headPics/bidderP...     M   0.72
# 1  /home/soyoung/face/Freelancer/headPics/bidderP...     F   0.56
# 2  /home/soyoung/face/Freelancer/headPics/bidderP...     M   0.98
# 3  /home/soyoung/face/Freelancer/headPics/bidderP...     F   1.00
# 4  /home/soyoung/face/Freelancer/headPics/bidderP...     M   0.84
