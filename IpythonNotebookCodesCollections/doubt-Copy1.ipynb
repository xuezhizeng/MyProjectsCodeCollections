# %%
import pandas as pd

# %% [markdown]
# #### map_bidder1 is the doc in this shared folder I uploaded at 10.13, which map pic name to set and pic id
# https://drive.google.com/open?id=0B1OglHNdwVZ2SnU5LWREcjhLdnc

# %%
df1=pd.read_csv('./map_bidder1.csv')
df1.shape
# Out:
# (26349, 4)

# %%
df1.head()
# Out:
#    id                 name  set_id  set
# 0   1   307898_profile.jpg       1    1
# 1   2  1189066_profile.jpg       2    1
# 2   3  1484438_profile.jpg       3    1
# 3   4  1265987_profile.jpg       4    1
# 4   5  1188950_profile.jpg       5    1

# %% [markdown]
# #### the file below is the final gender label file (me and Wu) I sent to you through that email

# %%
df2=pd.read_csv('./1_264_TwoWithComparison.csv')
df2.shape
# Out:
# (26349, 7)

# %%
df2.head()
# Out:
#    Pic_J Label_J  set_J  Pic_W Label_W  set_W  compare
# 0      1       M      1      1       M      1     True
# 1      2       M      1      2       M      1     True
# 2      3       M      1      3       M      1     True
# 3      4       M      1      4       M      1     True
# 4      5       M      1      5       M      1     True

# %% [markdown]
# #### the file below is the file you give me to be used for gender prediction training data, which I now use to map username to user_id since the above pic names are comprised with userid_profile.jpg

# %%
df3=pd.read_csv('./users.gender.golden.csv')
df3.shape
# Out:
# (121335, 9)

# %%
df3.head()
# Out:
#    user_id      username  freq  male.prob fname.gender  male.prob2  \
# 0      5.0       billion   2.0     1.0000         male    0.920000
# 1     63.0    paddyshyam   NaN        NaN          NaN         NaN
# 2     64.0     ArmenSoft   1.0     1.0000         male         NaN
# 3    128.0     okbookman   1.0     0.9945         male    0.998834
# 4    215.0  revitupmedia   1.0     1.0000         male         NaN
#
#   fname.gender2             Name pic.gender
# 0          male              NaN        NaN
# 1           NaN              NaN        NaN
# 2           NaN              NaN        NaN
# 3          male              NaN        NaN
# 4           NaN  215_profile.jpg        NaN

# %%
df3 = df3[~df3['Name'].isnull()][['user_id','username','Name','pic','pic.gender']]
# Out:
# KeyErrorTraceback (most recent call last)
# <ipython-input-56-9548c96a94fb> in <module>()
# ----> 1 df3 = df3[~df3['Name'].isnull()][['user_id','username','Name','pic','pic.gender']]
#
# /home/saya/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2054         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2055             # either boolean or fancy integer index
# -> 2056             return self._getitem_array(key)
#    2057         elif isinstance(key, DataFrame):
#    2058             return self._getitem_frame(key)
#
# /home/saya/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_array(self, key)
#    2098             return self.take(indexer, axis=0, convert=False)
#    2099         else:
# -> 2100             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2101             return self.take(indexer, axis=1, convert=True)
#    2102
#
# ...

# %%
df3.head()
# Out:
#    user_id      username  freq  male.prob fname.gender  male.prob2  \
# 0      5.0       billion   2.0     1.0000         male    0.920000
# 1     63.0    paddyshyam   NaN        NaN          NaN         NaN
# 2     64.0     ArmenSoft   1.0     1.0000         male         NaN
# 3    128.0     okbookman   1.0     0.9945         male    0.998834
# 4    215.0  revitupmedia   1.0     1.0000         male         NaN
#
#   fname.gender2             Name pic.gender
# 0          male              NaN        NaN
# 1           NaN              NaN        NaN
# 2           NaN              NaN        NaN
# 3          male              NaN        NaN
# 4           NaN  215_profile.jpg        NaN

# %%
df = df1.join(df2)
df.shape
# Out:
# (26349, 11)

# %%
df0 = df.set_index('name').join(df3.set_index('Name')).reset_index()

# %%
df0.shape
# Out:
# (27237, 19)

# %% [markdown]
# #### the doubt user names the student provide

# %%
doubt = ['MainFable','Jaimevv','Magneticgoat','vinesh37','evileyestudio','abhisheksoni','']

# %% [markdown]
# ### as you can see, the pic.gender are diff from the predicting gender from both me and Wu

# %%
df0[df0['username'].apply(lambda x: x in doubt)]
# Out:
#                      index     id  set_id  set  Pic_J Label_J  set_J  Pic_W  \
# 145     101299_profile.jpg  10842      42  109     42       B    109     42
# 2974   1185021_profile.jpg   4895      95   49     95       M     49     95
# 2975   1185021_profile.jpg   4895      95   49     95       M     49     95
# 18383  1568391_profile.jpg  11594      94  116     94       M    116     94
# 20212   225871_profile.jpg  11839      39  119     39       B    119     39
# 22987   581281_profile.jpg  14388      88  144     88       M    144     88
#
#       Label_W  set_W  compare    user_id       username  freq  male.prob  \
# 145         B    109     True   101299.0   abhisheksoni   NaN        NaN
# 2974        M     49     True  1185021.0       vinesh37   0.0        NaN
# 2975        M     49     True  1185021.0       vinesh37   0.0        NaN
# 18383       M    116     True  1568391.0      MainFable   NaN        NaN
# ...

# %%
df666 = pd.read_csv('./image_labels_final.csv')
df666.shape
# Out:
# (26349, 5)

# %%
df666.head()
# Out:
#    user_id       username Label_J Label_W  agreed
# 0      215   revitupmedia       M       M    True
# 1      220  ansonsequeira       M       M    True
# 2      224         tooner       M       M    True
# 3      274  sakshiinfosys       B       B    True
# 4      470        webdeem       M       M    True

# %%
df000 = df0[['index','id','Label_J','Label_W','compare','user_id','username']]
df000.head()
# Out:
#                  index     id Label_J Label_W  compare    user_id  \
# 0  1000057_profile.jpg  18162       B       B     True  1000057.0
# 1  1000244_profile.jpg   3047       B       B     True  1000244.0
# 2  1000350_profile.jpg   2797       M       M     True  1000350.0
# 3  1000354_profile.jpg  13632       M       M     True  1000354.0
# 4  1000417_profile.jpg  23550       M       M     True  1000417.0
#
#         username
# 0  tulipinfotech
# 1     vedanthemu
# 2       gkssroot
# 3    georgescifo
# 4        fapcent

# %%
chk = df666.set_index('username').join(df000.set_index('username'), rsuffix='_old', how='left')
chk.shape
# Out:
# (27011, 10)

# %%
chk.head()
# Out:
#                  user_id Label_J Label_W  agreed                index      id  \
# username
# a0109763626      1472590       G       G    True  1472590_profile.jpg  7232.0
# a1234567890endy  1329304       B       B    True                  NaN     NaN
# a1bert           1537299       M       M    True                  NaN     NaN
# a1dezine          137395       B       B    True   137395_profile.jpg  3011.0
# a1exm            1281149       M       M    True                  NaN     NaN
#
#                 Label_J_old Label_W_old compare  user_id_old
# username
# a0109763626               G           G    True    1472590.0
# a1234567890endy         NaN         NaN     NaN          NaN
# a1bert                  NaN         NaN     NaN          NaN
# a1dezine                  B           B    True     137395.0
# a1exm                   NaN         NaN     NaN          NaN

# %%
chk[chk['compare'].isnull()]
# Out:
#                   user_id Label_J Label_W  agreed index  id Label_J_old  \
# username
# a1234567890endy   1329304       B       B    True   NaN NaN         NaN
# a1bert            1537299       M       M    True   NaN NaN         NaN
# a1exm             1281149       M       M    True   NaN NaN         NaN
# a1multitask       1551886       M       M    True   NaN NaN         NaN
# a1retouching       889357       B       B    True   NaN NaN         NaN
# a2design           185747       B       B    True   NaN NaN         NaN
# a80tuderules       498290       M       M    True   NaN NaN         NaN
# aactivelink        748646       B       B    True   NaN NaN         NaN
# aadrish            146217       F       F    True   NaN NaN         NaN
# aagii             1559018       M       M    True   NaN NaN         NaN
# aajcreative       1426465       B       B    True   NaN NaN         NaN
# aarcha            1580676       B       B    True   NaN NaN         NaN
# ...
