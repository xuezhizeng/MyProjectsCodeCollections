# %%
import concurrent.futures
import requests
import os

from time import time, ctime
import pandas as pd

fail=[]

# %%
def download_image(img_url):
    global direct
    
    try:
        ID, url = img_url.split('__')
        cont = url.split('/')
        name= str(ID)+'_'+str(cont[-4])+str(cont[-1]).replace('_570','')
        
    except Exception as e:
        fail.append(img_url)
        print e

        
        
    try:
        img_request = requests.request(
            'get', url, stream=True, timeout=300)
        if img_request.status_code != 200:
            fail.append(img_url)
            print 'X2'
    except Exception as e:
        fail.append(img_url)
        print e

    try:
        img_content = img_request.content
        with open(os.path.join(direct,  name), 'wb') as f:
            byte_image = bytes(img_content)
            f.write(byte_image)
            
    except Exception as e:
        fail.append(img_url)
        print e

# %%
def batch(subber):
    start=time()
    with concurrent.futures.ThreadPoolExecutor(max_workers=8) as executor:
        executor.map(download_image, subber)
    past='{:.2f}'.format(time()-start)
    now=ctime()[4:]

    print 'imges ',len(subber),'  used ',past,'s', now

# %%
def spl(lists, n):
    return  [lists[i:i + n] for i in range(0, len(lists), n)]

# %%
if __name__=='__main__':
    
    choose=raw_input('which set (1-24)?: ')
    try:
        os.mkdir('img_'+str(choose))
    except:
        print 'dir img_'+str(choose)+' exists'
    
    direct='img_'+str(choose)
    df=pd.read_csv('img_'+str(choose)+'.csv')
    nn=df.shape[0]
    print nn,' pics'
    
    
    urls=[]
    for i in df.itertuples():
        urls.append(str(i[1])+'__'+str(i[2]))
    print len(urls)==nn
    
    many=int(raw_input('how many IDs a batch?: '))
      
    
    p=0
    q=0
    for i in spl(urls, many):
        q+=1
        batch(i)
        p+=many/float(nn)
        print p*100,'%', nn, many*q 

    fl = pd.DataFrame(fail, columns=['fail_url'])
    fl.save('failed_img_'+str(choose)+'.csv')
# Out:
# which set (1-24)?: 9
# 10000  pics
# True
# how many IDs a batch?: 100
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20161014/5/20161014153621602_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7fda09bc4350>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20161014/2/20161014153640575_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7fda09bc46d0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20161014/0/20161014153656994_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7fda0853b950>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20161014/3/20161014153732336_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7fda0853b0d0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20161018/5/20161018154704464_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7fda09b94a90>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20161018/1/20161018154718823_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7fda09b94410>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20161018/7/20161018154725819_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7fda09b943d0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20161018/4/20161018154731153_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7fda09b94b10>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20161018/6/20161018154554165_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7fda09b94850>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20161018/0/20161018154624274_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7fda09b94910>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20161017/3/20161017105834258_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7fda08544a90>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20161017/0/20161017105839305_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7fda09b94f90>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20161017/8/20161017105847328_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7fda08544950>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20161017/4/20161017105854937_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7fda09b94910>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20161017/5/20161017105900102_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7fda08544990>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20161017/2/20161017105905260_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7fda09b94b10>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20161017/8/20161017105943155_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7fda08544890>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20161017/9/20161017105950540_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7fda08544f90>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20161014/3/20161014145149133_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7fda08544790>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20161014/8/20161014145156227_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7fda09b94250>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20161014/9/20161014145208634_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7fda08544dd0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20161013/5/20161013152019990_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7fda085446d0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20161013/9/20161013152026268_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7fda0854b890>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20161013/8/20161013152038170_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7fda09b94f90>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20161013/4/20161013152046442_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7fda0854b610>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20161013/3/20161013152054768_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7fda09b94890>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20161013/3/20161013152101147_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7fda0854b650>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20161013/6/20161013152111363_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7fda0854bd90>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20