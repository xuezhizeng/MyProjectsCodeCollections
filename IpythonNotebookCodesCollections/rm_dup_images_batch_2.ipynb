# %%
import pandas as pd
import os
import shutil

# import sys
# reload(sys)
# sys.setdefaultencoding('utf8')

# %%
os.getcwd()
# Out:
# '/home/soyoung/face/baidu_face_project/96_data/batch1Data'

# %%
path = '/home/soyoung/face/baidu_face_project/batch2Data/'

# %%
df = pd.read_csv(path+'labels.csv', names=['id','url'])
df.shape
# Out:
# (90711, 2)

# %%
df.head()
# Out:
#    id                                                url
# 0   1  /home/face/prepared_baidu_faces_cp/sub_101/o_2...
# 1   1  /home/face/prepared_baidu_faces_cp/sub_101/p1_...
# 2   1  /home/face/prepared_baidu_faces_cp/sub_101/OT2...
# 3   1  /home/face/prepared_baidu_faces_cp/sub_101/oYY...
# 4   1  /home/face/prepared_baidu_faces_cp/sub_101/OOO...

# %%
data = pd.read_csv(path+'reps.csv', header=None)
data.shape
# Out:
# (90711, 128)

# %%
data.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.052561  0.000391 -0.056738  0.141174  0.027441  0.049612  0.030643
# 1  0.004180  0.191736  0.081938  0.131037 -0.017847  0.093564  0.027027
# 2  0.035473 -0.078845 -0.130248 -0.004106  0.108466  0.002791  0.043736
# 3  0.109629 -0.023703  0.022950  0.042831  0.109145  0.071201  0.059694
# 4  0.092153 -0.034413 -0.077425  0.056193  0.098403 -0.019449  0.039712
#
#         7         8         9      ...          118       119       120  \
# 0  0.007977  0.033394  0.018895    ...     0.074585  0.204278 -0.035850
# 1  0.025474  0.071489  0.059691    ...     0.073242  0.038770  0.041488
# 2  0.007019 -0.132781  0.007908    ...     0.033989  0.129211 -0.108007
# 3  0.060945  0.046343 -0.170765    ...     0.077519  0.138939 -0.005553
# 4 -0.005715  0.079965 -0.085981    ...     0.001492  0.166045 -0.031930
#
#         121       122       123       124       125       126       127
# ...

# %%
data['url']=df['url']
data.shape
# Out:
# (90711, 129)

# %%
del df
df = data

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.052561  0.000391 -0.056738  0.141174  0.027441  0.049612  0.030643
# 1  0.004180  0.191736  0.081938  0.131037 -0.017847  0.093564  0.027027
# 2  0.035473 -0.078845 -0.130248 -0.004106  0.108466  0.002791  0.043736
# 3  0.109629 -0.023703  0.022950  0.042831  0.109145  0.071201  0.059694
# 4  0.092153 -0.034413 -0.077425  0.056193  0.098403 -0.019449  0.039712
#
#           7         8         9  \
# 0  0.007977  0.033394  0.018895
# 1  0.025474  0.071489  0.059691
# 2  0.007019 -0.132781  0.007908
# 3  0.060945  0.046343 -0.170765
# 4 -0.005715  0.079965 -0.085981
#
#                          ...                               119       120  \
# 0                        ...                          0.204278 -0.035850
# 1                        ...                          0.038770  0.041488
# 2                        ...                          0.129211 -0.108007
# ...

# %%
df['full_url']=df['url'].apply(lambda x: '/home/soyoung/face/baidu_full_pics'+x.split('prepared_baidu_faces')[-1][:-3]+'jpg')
df.shape
# Out:
# (90711, 130)

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.052561  0.000391 -0.056738  0.141174  0.027441  0.049612  0.030643
# 1  0.004180  0.191736  0.081938  0.131037 -0.017847  0.093564  0.027027
# 2  0.035473 -0.078845 -0.130248 -0.004106  0.108466  0.002791  0.043736
# 3  0.109629 -0.023703  0.022950  0.042831  0.109145  0.071201  0.059694
# 4  0.092153 -0.034413 -0.077425  0.056193  0.098403 -0.019449  0.039712
#
#           7         8         9  \
# 0  0.007977  0.033394  0.018895
# 1  0.025474  0.071489  0.059691
# 2  0.007019 -0.132781  0.007908
# 3  0.060945  0.046343 -0.170765
# 4 -0.005715  0.079965 -0.085981
#
#                          ...                               120       121  \
# 0                        ...                         -0.035850  0.016196
# 1                        ...                          0.041488  0.088541
# 2                        ...                         -0.108007  0.002534
# ...

# %%
df['name']=df['full_url'].apply(lambda x:x.split('/home/soyoung/face/baidu_full_pics_cp/')[-1])
df.shape
# Out:
# (90711, 131)

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.052561  0.000391 -0.056738  0.141174  0.027441  0.049612  0.030643
# 1  0.004180  0.191736  0.081938  0.131037 -0.017847  0.093564  0.027027
# 2  0.035473 -0.078845 -0.130248 -0.004106  0.108466  0.002791  0.043736
# 3  0.109629 -0.023703  0.022950  0.042831  0.109145  0.071201  0.059694
# 4  0.092153 -0.034413 -0.077425  0.056193  0.098403 -0.019449  0.039712
#
#           7         8         9  \
# 0  0.007977  0.033394  0.018895
# 1  0.025474  0.071489  0.059691
# 2  0.007019 -0.132781  0.007908
# 3  0.060945  0.046343 -0.170765
# 4 -0.005715  0.079965 -0.085981
#
#                          ...                               121       122  \
# 0                        ...                          0.016196 -0.109116
# 1                        ...                          0.088541 -0.026927
# 2                        ...                          0.002534 -0.010056
# ...

# %%
for i in df['full_url']:
    print i
    break
# Out:
# /home/soyoung/face/baidu_full_pics_cp/sub_101/o_285821159850.jpg

# %%
dest = '/home/soyoung/face/baidu_full_pics/hasFace/'

# %%
source = '/home/soyoung/face/baidu_full_pics/'

# %%
# for i in range(112):
#     try:
#         os.mkdir(dest+'sub_'+str(i))
#     except:
#         pass

# %%
n=0
no=[]
for i in df['name']:
    try:
        shutil.move(source+i, dest+i)
    except Exception as e:
        n+=1
        no.append(i)
#         print '!',
n
# Out:
# 1408

# %%
n=0
no=[]
for i in df['name']:
    try:
        shutil.move(source+i[:-3]+'JPG', dest+i)
    except Exception as e:
        n+=1
        no.append(i)
#         print '!',
n
# Out:
# 89472

# %%
# nodf=pd.DataFrame(no, columns=['name'])
# nodf

# %%
n=0
no=[]
for i in df['name']:
    try:
        shutil.move(dest+i, dest+i)
    except Exception as e:
        n+=1
        no.append(i)
#         print '!',
n
# Out:
# 169

# %%
no[:10]
# Out:
# ['sub_101/P1200079_\xb8\xb1\xb1\xbe.jpg',
#  'sub_65/5744_\xc6\xd5\xb7\xa8\xb9\xa4\xd7\xf7\xc8\xcb\xd4\xb1\xce\xaa\xd1\xa7\xc9\xfa\xc9\xa2\xb7\xa2\xd0\xfb\xb4\xab\xb2\xc4\xc1\xcf\xcf\xd6\xb3\xa1.jpg',
#  'sub_111/\xe8\xd6\xd4\xc2\xa4\xa2\xa4\xa4ABP-308.jpg',
#  'sub_111/\xba\xa3\xd0\xc5\xb5\xe7\xc6\xf7\xc5\xb7\xd6\xde\xcd\xf8\xd5\xbe\xb8\xc4\xb0\xe607.jpg',
#  'sub_111/\xdf\xc7\xb2\xc1\xd5\xd5\xcf\xe0\xb9\xdd.jpg',
#  'sub_111/\xb1\xb1\xc3\xc0\xc7\xd9\xc9\xe7\xb9\xc5\xc7\xd9\xbc\xd2\xcd\xf5\xb7\xc6\xb2\xce\xb9\xdb\xd7\xc1\xc7\xd9\xcc\xc3 023.jpg',
#  'sub_111/\xb9\xc4\xd5\xc6\xb5\xc4\xc9\xcc\xce\xf1\xc8\xcb\xca\xbfppt\xb1\xb3\xbe\xb0\xcd\xbc\xc6\xac.jpg',
#  'sub_111/\xbb\xc6\xca\xa5\xd2\xc0\xd0\xd4\xb8\xd0 (4).jpg',
#  'sub_111/\xc9\xd9\xca\xfd\xc3\xf1\xd7\xe5\xc8\xcb\xce\xef\xd3\xcd\xbb\xad.jpg',
#  'sub_111/\xd0\xbb\xb0\xb2\xe7\xf7.jpg']

# %%
df.tail()
# Out:
#               0         1         2         3         4         5         6  \
# 90706  0.003517  0.052479 -0.044540  0.089930 -0.028029  0.054476  0.062636
# 90707  0.030297  0.122150 -0.020289  0.030955 -0.067142  0.080773  0.100250
# 90708  0.108930 -0.036421 -0.151056  0.065437  0.151416 -0.022955  0.069124
# 90709  0.076546  0.111801 -0.102897  0.136395  0.015714  0.078710  0.012302
# 90710  0.095205  0.065115 -0.086386  0.142298  0.062028  0.032015  0.062714
#
#               7         8         9                   ...                     \
# 90706  0.098270  0.111579  0.009150                   ...
# 90707  0.113896 -0.048586  0.022922                   ...
# 90708 -0.000841 -0.000843  0.038638                   ...
# 90709  0.009330  0.018362  0.073968                   ...
# 90710  0.025182  0.039111  0.017706                   ...
#
#             121       122       123       124       125       126       127  \
# ...

# %%
# !pwd
# Out:
# /home/soyoung/face/baidu_face_project/96_data/batch1Data

# %%
NotWant = df[df['name'].apply(lambda x: x in no)]
NotWant.shape
# Out:
# (169, 131)

# %%
NotWant.head()
# Out:
#               0         1         2         3         4         5         6  \
# 60     0.101504 -0.021542  0.036340  0.001354  0.158605  0.217536  0.084382
# 17132  0.037967  0.096498  0.107351  0.098461  0.001813  0.212054 -0.078043
# 21728  0.062408 -0.013088 -0.109287  0.148724  0.115410 -0.007249  0.118385
# 21731  0.041103  0.063438 -0.028321  0.074898 -0.132749  0.058876  0.024055
# 21732 -0.004882  0.262674 -0.027674  0.116892 -0.025736  0.070203  0.011612
#
#               7         8         9  \
# 60     0.051548 -0.023561 -0.069725
# 17132 -0.010327 -0.012693 -0.030228
# 21728  0.007383 -0.008671 -0.016104
# 21731 -0.071332 -0.078203 -0.075727
# 21732  0.002691  0.025162  0.128748
#
#                            ...                            121       122  \
# 60                         ...                       0.034167  0.064979
# 17132                      ...                      -0.022751  0.020324
# ...

# %%
to_be_drop = df[df['name'].apply(lambda x: x in no)].index
to_be_drop
# Out:
# Int64Index([   60, 17132, 21728, 21731, 21732, 21742, 21744, 21747, 21748,
#             21753,
#             ...
#             36053, 46410, 46533, 46560, 47273, 47476, 47481, 48366, 54837,
#             55140],
#            dtype='int64', length=169)

# %%
df.shape
# Out:
# (90711, 131)

# %%
df.drop(to_be_drop).shape
# Out:
# (90542, 131)

# %%
df_V2= df.drop(to_be_drop)
df_V2.shape
# Out:
# (90542, 131)

# %%
df_V3 = df_V2.reset_index(drop=True)
df_V3.shape
# Out:
# (90542, 131)

# %%
df_V3.tail()
# Out:
#               0         1         2         3         4         5         6  \
# 90537  0.003517  0.052479 -0.044540  0.089930 -0.028029  0.054476  0.062636
# 90538  0.030297  0.122150 -0.020289  0.030955 -0.067142  0.080773  0.100250
# 90539  0.108930 -0.036421 -0.151056  0.065437  0.151416 -0.022955  0.069124
# 90540  0.076546  0.111801 -0.102897  0.136395  0.015714  0.078710  0.012302
# 90541  0.095205  0.065115 -0.086386  0.142298  0.062028  0.032015  0.062714
#
#               7         8         9                   ...                     \
# 90537  0.098270  0.111579  0.009150                   ...
# 90538  0.113896 -0.048586  0.022922                   ...
# 90539 -0.000841 -0.000843  0.038638                   ...
# 90540  0.009330  0.018362  0.073968                   ...
# 90541  0.025182  0.039111  0.017706                   ...
#
#             121       122       123       124       125       126       127  \
# ...

# %%
df_V4 = df_V3.drop(['url'], axis=1)
df_V4 = df_V4.drop(['full_url'], axis=1)
df_V4.shape
# Out:
# (90542, 129)

# %%
df_V4.to_csv('new_batch_2.csv', index=False)

# %%
# !pwd
# Out:
# /home/soyoung/face/baidu_face_project/96_data/batch1Data
