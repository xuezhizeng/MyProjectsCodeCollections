# %%
import pandas as pd
import os
import shutil

# import sys
# reload(sys)
# sys.setdefaultencoding('utf8')

# %%
os.getcwd()
# Out:
# '/home/soyoung/face/baidu_face_project/96_data/batch1Data'

# %%
df=pd.read_csv('clean_batch_1.csv')
df.shape
# Out:
# (115180, 129)

# %%
df.tail()
# Out:
#                0         1         2         3         4         5         6  \
# 115175 -0.046567  0.149707  0.093097 -0.041780 -0.019232  0.105501 -0.069380
# 115176  0.006827  0.194953  0.053782  0.109431 -0.020998  0.135453 -0.030632
# 115177  0.041346  0.025335  0.124289  0.057312 -0.030401  0.006168 -0.017808
# 115178  0.014553  0.121114 -0.069149  0.151499 -0.021771  0.127191  0.033851
# 115179  0.107075  0.139922  0.109044  0.014968 -0.007285  0.109929  0.053823
#
#                7         8         9  \
# 115175  0.042693  0.000807  0.038537
# 115176 -0.017305 -0.017293  0.120162
# 115177  0.120122  0.091515 -0.067005
# 115178 -0.044419 -0.004313  0.093984
# 115179  0.135841  0.039213 -0.031574
#
#                               ...                               119       120  \
# 115175                        ...                          0.024313  0.089068
# 115176                        ...                          0.035527  0.077325
# 115177                        ...                          0.114932 -0.069747
# 115178                        ...                          0.080601  0.053754
# 115179                        ...                          0.104380  0.043419
#
#              121       122       123       124       125       126       127  \
# 115175 -0.031429  0.007614  0.013190  0.100177 -0.054101  0.121322  0.058682
# 115176 -0.024516 -0.036961  0.065445  0.219134 -0.067388  0.162601  0.095185
# 115177  0.049281 -0.102638  0.159025  0.148405 -0.058404  0.142797  0.073995
# 115178 -0.015292 -0.025931  0.138146  0.056176 -0.032523  0.052524  0.095914
# 115179 -0.003623 -0.083563  0.210578  0.076363 -0.129710  0.144843 -0.011868
#
#                                                       url
# 115175  /home/face/prepared_baidu_faces/sub_87/bki-201...
# 115176  /home/face/prepared_baidu_faces/sub_87/bd8a0a1...
# 115177  /home/face/prepared_baidu_faces/sub_87/c2fdfc0...
# 115178  /home/face/prepared_baidu_faces/sub_87/BG5JX8W...
# 115179  /home/face/prepared_baidu_faces/sub_87/c2_2017...
#
# [5 rows x 129 columns]

# %%
df['full_url']=df['url'].apply(lambda x: '/home/soyoung/face/baidu_full_pics'+x.split('prepared_baidu_faces')[-1][:-3]+'jpg')
df.shape
# Out:
# (115180, 130)

# %%
# df = df[['full_url','url']]

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.011476  0.165126 -0.129640  0.016787  0.022167  0.051669  0.014077
# 1 -0.003138 -0.094253 -0.074803  0.001642  0.080649 -0.065988 -0.029929
# 2  0.052159  0.078025 -0.058801  0.111056  0.011825  0.077016  0.018737
# 3 -0.022384  0.050678 -0.026818  0.041654  0.046246  0.022148  0.001582
# 4  0.059199  0.078390 -0.108855  0.071035 -0.007066 -0.000059  0.007308
#
#           7         8         9  \
# 0  0.017761  0.011484  0.137340
# 1  0.026139  0.026266 -0.024320
# 2  0.034417  0.029392 -0.014144
# 3  0.021008  0.024489  0.015352
# 4 -0.022881 -0.106324  0.033876
#
#                          ...                               120       121  \
# 0                        ...                         -0.054396 -0.000642
# 1                        ...                         -0.071909  0.113172
# 2                        ...                         -0.007938  0.055379
# 3                        ...                         -0.050696 -0.020838
# 4                        ...                         -0.019002  0.083863
#
#         122       123       124       125       126       127  \
# 0 -0.096280  0.126662 -0.005746 -0.006710 -0.089524  0.049204
# 1  0.045211  0.141725 -0.033956  0.012183 -0.019442  0.013153
# 2 -0.049870  0.153607  0.078589 -0.073745  0.036184  0.064255
# 3 -0.068645  0.067528 -0.124348  0.097163  0.079192  0.057003
# 4  0.170860  0.019041  0.054721  0.044380  0.145403 -0.038084
#
#                                                  url  \
# 0  /home/face/prepared_baidu_faces/sub_28/1aa1269...
# 1  /home/face/prepared_baidu_faces/sub_28/1985782...
# 2  /home/face/prepared_baidu_faces/sub_28/1993968...
# 3  /home/face/prepared_baidu_faces/sub_28/195943d...
# 4  /home/face/prepared_baidu_faces/sub_28/1dd0675...
#
#                                             full_url
# 0  /home/soyoung/face/baidu_full_pics/sub_28/1aa1...
# 1  /home/soyoung/face/baidu_full_pics/sub_28/1985...
# 2  /home/soyoung/face/baidu_full_pics/sub_28/1993...
# 3  /home/soyoung/face/baidu_full_pics/sub_28/1959...
# 4  /home/soyoung/face/baidu_full_pics/sub_28/1dd0...
#
# [5 rows x 130 columns]

# %%
df['name']=df['full_url'].apply(lambda x:x.split('/home/soyoung/face/baidu_full_pics/')[-1])
df.shape
# Out:
# (115180, 131)

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.011476  0.165126 -0.129640  0.016787  0.022167  0.051669  0.014077
# 1 -0.003138 -0.094253 -0.074803  0.001642  0.080649 -0.065988 -0.029929
# 2  0.052159  0.078025 -0.058801  0.111056  0.011825  0.077016  0.018737
# 3 -0.022384  0.050678 -0.026818  0.041654  0.046246  0.022148  0.001582
# 4  0.059199  0.078390 -0.108855  0.071035 -0.007066 -0.000059  0.007308
#
#           7         8         9  \
# 0  0.017761  0.011484  0.137340
# 1  0.026139  0.026266 -0.024320
# 2  0.034417  0.029392 -0.014144
# 3  0.021008  0.024489  0.015352
# 4 -0.022881 -0.106324  0.033876
#
#                          ...                               121       122  \
# 0                        ...                         -0.000642 -0.096280
# 1                        ...                          0.113172  0.045211
# 2                        ...                          0.055379 -0.049870
# 3                        ...                         -0.020838 -0.068645
# 4                        ...                          0.083863  0.170860
#
#         123       124       125       126       127  \
# 0  0.126662 -0.005746 -0.006710 -0.089524  0.049204
# 1  0.141725 -0.033956  0.012183 -0.019442  0.013153
# 2  0.153607  0.078589 -0.073745  0.036184  0.064255
# 3  0.067528 -0.124348  0.097163  0.079192  0.057003
# 4  0.019041  0.054721  0.044380  0.145403 -0.038084
#
#                                                  url  \
# 0  /home/face/prepared_baidu_faces/sub_28/1aa1269...
# 1  /home/face/prepared_baidu_faces/sub_28/1985782...
# 2  /home/face/prepared_baidu_faces/sub_28/1993968...
# 3  /home/face/prepared_baidu_faces/sub_28/195943d...
# 4  /home/face/prepared_baidu_faces/sub_28/1dd0675...
#
#                                             full_url  \
# 0  /home/soyoung/face/baidu_full_pics/sub_28/1aa1...
# 1  /home/soyoung/face/baidu_full_pics/sub_28/1985...
# 2  /home/soyoung/face/baidu_full_pics/sub_28/1993...
# 3  /home/soyoung/face/baidu_full_pics/sub_28/1959...
# 4  /home/soyoung/face/baidu_full_pics/sub_28/1dd0...
#
#                                                 name
# 0        sub_28/1aa1269cc4cd42aeb12fb6f83beb89f4.jpg
# 1                     sub_28/1985782_13_102812_1.jpg
# 2                     sub_28/1993968735118832174.jpg
# 3                  sub_28/195943d29ir441i444lhtr.jpg
# 4  sub_28/1dd0675b-b9d6-4cca-a03e-2134403a74a9_si...
#
# [5 rows x 131 columns]

# %%
for i in df['full_url']:
    print i
    break
# Out:
# /home/soyoung/face/baidu_full_pics/sub_28/1aa1269cc4cd42aeb12fb6f83beb89f4.jpg

# %%
dest = '/home/soyoung/face/baidu_full_pics/hasFace/'

# %%
source = '/home/soyoung/face/baidu_full_pics/'

# %%
for i in range(112):
    try:
        os.mkdir(dest+'sub_'+str(i))
    except:
        pass

# %%
n=0
no=[]
for i in df['name']:
    try:
        shutil.move(source+i, dest+i)
    except Exception as e:
        n+=1
        no.append(i)
#         print '!',
n
# Out:
# 115180

# %%
n=0
no=[]
for i in df['name']:
    try:
        shutil.move(source+i[:-3]+'JPG', dest+i)
    except Exception as e:
        n+=1
        no.append(i)
#         print '!',
n
# Out:
# 115180

# %%
# nodf=pd.DataFrame(no, columns=['name'])
# nodf

# %%
n=0
no=[]
for i in df['name']:
    try:
        shutil.move(dest+i, dest+i)
    except Exception as e:
        n+=1
        no.append(i)
#         print '!',
n
# Out:
# 6

# %%
no
# Out:
# ['sub_61/4\xc5\xc44.jpg',
#  'sub_98/initpintu_\xb8\xb1\xb1\xbe(2).jpg',
#  'sub_104/s_\xbe\xab\xc1\xe9_zf3d_2016122410950161.jpg',
#  'sub_93/DSC0361_\xb8\xb1\xb1\xbe_big.jpg',
#  'sub_93/DSC5039_\xb8\xb1\xb1\xbe_big.jpg',
#  'sub_18/140409150906828\xc6\xb1\xce\xf1\xba\xa3\xb1\xa81.jpg']

# %%
df[df['name'].apply(lambda x: x in no)]
# Out:
#               0         1         2         3         4         5         6  \
# 4673   0.008265  0.179262  0.030151  0.146780 -0.056116  0.132400 -0.017690
# 14136 -0.007711  0.273365  0.028495 -0.040322  0.002168  0.216434 -0.054876
# 40773 -0.040922  0.073680  0.202358  0.054240  0.088955  0.091790  0.000043
# 55776  0.116897 -0.008888  0.074119  0.106332 -0.024163  0.040991  0.046735
# 56253  0.087714  0.034428 -0.065060  0.119914 -0.013125  0.102743  0.010716
# 69817 -0.005432  0.300684  0.121067  0.104577 -0.052306  0.201671 -0.021691
#
#               7         8         9                    ...                     \
# 4673  -0.075108  0.041471  0.073151                    ...
# 14136 -0.032137 -0.022295  0.144679                    ...
# 40773 -0.051838  0.103089 -0.021957                    ...
# 55776  0.100372 -0.060855 -0.044114                    ...
# 56253  0.041360  0.009771 -0.031321                    ...
# 69817  0.023332  0.077453  0.086555                    ...
#
#             121       122       123       124       125       126       127  \
# 4673   0.049995  0.023780  0.056830  0.138941 -0.116147  0.136170  0.069204
# 14136 -0.106461  0.000754  0.035419  0.153044 -0.025815  0.122180  0.005653
# 40773  0.053948 -0.021142 -0.041587  0.114467  0.136450  0.141601 -0.003907
# 55776 -0.016364 -0.061529  0.147782  0.103095 -0.047293  0.098242  0.021800
# 56253 -0.041904 -0.126628  0.165686  0.130644 -0.053557  0.064478  0.110025
# 69817  0.066273  0.073897  0.065939  0.237523 -0.045096  0.179087  0.039779
#
#                                                      url  \
# 4673     /home/face/prepared_baidu_faces/sub_61/4��4.png
# 14136  /home/face/prepared_baidu_faces/sub_98/initpin...
# 40773  /home/face/prepared_baidu_faces/sub_104/s_����...
# 55776  /home/face/prepared_baidu_faces/sub_93/DSC0361...
# 56253  /home/face/prepared_baidu_faces/sub_93/DSC5039...
# 69817  /home/face/prepared_baidu_faces/sub_18/1404091...
#
#                                                 full_url  \
# 4673   /home/soyoung/face/baidu_full_pics/sub_61/4��4...
# 14136  /home/soyoung/face/baidu_full_pics/sub_98/init...
# 40773  /home/soyoung/face/baidu_full_pics/sub_104/s_�...
# 55776  /home/soyoung/face/baidu_full_pics/sub_93/DSC0...
# 56253  /home/soyoung/face/baidu_full_pics/sub_93/DSC5...
# 69817  /home/soyoung/face/baidu_full_pics/sub_18/1404...
#
#                                            name
# 4673                            sub_61/4��4.jpg
# 14136              sub_98/initpintu_����(2).jpg
# 40773  sub_104/s_����_zf3d_2016122410950161.jpg
# 55776               sub_93/DSC0361_����_big.jpg
# 56253               sub_93/DSC5039_����_big.jpg
# 69817           sub_18/140409150906828Ʊ�񺣱�1.jpg
#
# [6 rows x 131 columns]

# %%
to_be_drop = df[df['name'].apply(lambda x: x in no)].index
to_be_drop
# Out:
# Int64Index([4673, 14136, 40773, 55776, 56253, 69817], dtype='int64')

# %%
df.shape
# Out:
# (115180, 131)

# %%
df.drop(to_be_drop).shape
# Out:
# (115174, 131)

# %%
df_V2= df.drop(to_be_drop)
df_V2.shape
# Out:
# (115174, 131)

# %%
df_V3 = df_V2.reset_index(drop=True)
df_V3.shape
# Out:
# (115174, 131)

# %%
df_V3.tail()
# Out:
#                0         1         2         3         4         5         6  \
# 115169 -0.046567  0.149707  0.093097 -0.041780 -0.019232  0.105501 -0.069380
# 115170  0.006827  0.194953  0.053782  0.109431 -0.020998  0.135453 -0.030632
# 115171  0.041346  0.025335  0.124289  0.057312 -0.030401  0.006168 -0.017808
# 115172  0.014553  0.121114 -0.069149  0.151499 -0.021771  0.127191  0.033851
# 115173  0.107075  0.139922  0.109044  0.014968 -0.007285  0.109929  0.053823
#
#                7         8         9  \
# 115169  0.042693  0.000807  0.038537
# 115170 -0.017305 -0.017293  0.120162
# 115171  0.120122  0.091515 -0.067005
# 115172 -0.044419 -0.004313  0.093984
# 115173  0.135841  0.039213 -0.031574
#
#                               ...                               121       122  \
# 115169                        ...                         -0.031429  0.007614
# 115170                        ...                         -0.024516 -0.036961
# 115171                        ...                          0.049281 -0.102638
# 115172                        ...                         -0.015292 -0.025931
# 115173                        ...                         -0.003623 -0.083563
#
#              123       124       125       126       127  \
# 115169  0.013190  0.100177 -0.054101  0.121322  0.058682
# 115170  0.065445  0.219134 -0.067388  0.162601  0.095185
# 115171  0.159025  0.148405 -0.058404  0.142797  0.073995
# 115172  0.138146  0.056176 -0.032523  0.052524  0.095914
# 115173  0.210578  0.076363 -0.129710  0.144843 -0.011868
#
#                                                       url  \
# 115169  /home/face/prepared_baidu_faces/sub_87/bki-201...
# 115170  /home/face/prepared_baidu_faces/sub_87/bd8a0a1...
# 115171  /home/face/prepared_baidu_faces/sub_87/c2fdfc0...
# 115172  /home/face/prepared_baidu_faces/sub_87/BG5JX8W...
# 115173  /home/face/prepared_baidu_faces/sub_87/c2_2017...
#
#                                                  full_url  \
# 115169  /home/soyoung/face/baidu_full_pics/sub_87/bki-...
# 115170  /home/soyoung/face/baidu_full_pics/sub_87/bd8a...
# 115171  /home/soyoung/face/baidu_full_pics/sub_87/c2fd...
# 115172  /home/soyoung/face/baidu_full_pics/sub_87/BG5J...
# 115173  /home/soyoung/face/baidu_full_pics/sub_87/c2_2...
#
#                                                      name
# 115169           sub_87/bki-20110205143937-1732728006.jpg
# 115170        sub_87/bd8a0a1e850988f271482289ddd39f34.jpg
# 115171  sub_87/c2fdfc039245d68813f27b89afc27d1ed21b242...
# 115172                            sub_87/BG5JX8W374WA.jpg
# 115173                 sub_87/c2_20170830104837_26350.jpg
#
# [5 rows x 131 columns]

# %%
df_V4 = df_V3.drop(['url'], axis=1)
df_V4 = df_V4.drop(['full_url'], axis=1)
df_V4.shape
# Out:
# (115174, 129)

# %%
df_V4.tail()
# Out:
#                0         1         2         3         4         5         6  \
# 115169 -0.046567  0.149707  0.093097 -0.041780 -0.019232  0.105501 -0.069380
# 115170  0.006827  0.194953  0.053782  0.109431 -0.020998  0.135453 -0.030632
# 115171  0.041346  0.025335  0.124289  0.057312 -0.030401  0.006168 -0.017808
# 115172  0.014553  0.121114 -0.069149  0.151499 -0.021771  0.127191  0.033851
# 115173  0.107075  0.139922  0.109044  0.014968 -0.007285  0.109929  0.053823
#
#                7         8         9  \
# 115169  0.042693  0.000807  0.038537
# 115170 -0.017305 -0.017293  0.120162
# 115171  0.120122  0.091515 -0.067005
# 115172 -0.044419 -0.004313  0.093984
# 115173  0.135841  0.039213 -0.031574
#
#                               ...                               119       120  \
# 115169                        ...                          0.024313  0.089068
# 115170                        ...                          0.035527  0.077325
# 115171                        ...                          0.114932 -0.069747
# 115172                        ...                          0.080601  0.053754
# 115173                        ...                          0.104380  0.043419
#
#              121       122       123       124       125       126       127  \
# 115169 -0.031429  0.007614  0.013190  0.100177 -0.054101  0.121322  0.058682
# 115170 -0.024516 -0.036961  0.065445  0.219134 -0.067388  0.162601  0.095185
# 115171  0.049281 -0.102638  0.159025  0.148405 -0.058404  0.142797  0.073995
# 115172 -0.015292 -0.025931  0.138146  0.056176 -0.032523  0.052524  0.095914
# 115173 -0.003623 -0.083563  0.210578  0.076363 -0.129710  0.144843 -0.011868
#
#                                                      name
# 115169           sub_87/bki-20110205143937-1732728006.jpg
# 115170        sub_87/bd8a0a1e850988f271482289ddd39f34.jpg
# 115171  sub_87/c2fdfc039245d68813f27b89afc27d1ed21b242...
# 115172                            sub_87/BG5JX8W374WA.jpg
# 115173                 sub_87/c2_20170830104837_26350.jpg
#
# [5 rows x 129 columns]

# %%
df_V4.to_csv('new_batch_1.csv', index=False)
