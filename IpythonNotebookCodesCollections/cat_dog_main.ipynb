# %% [markdown]
# http://cmusatyalab.github.io/openface/

# %%
# !ls
# Out:
# align-dlib_mod.py	       landmarkCatDog
# catDog_test		       landmark_catDog.zip
# cat_dog_main.ipynb	       landmarks.ipynb
# cat_dog_report.ipynb	       landmarks_cat_dog.ipynb
# chopHead256_real_soyoung_pics  newFlask
# chop_code		       opencvTest.ipynb
# facial_landmarks.py	       openface.ipynb
# facial_landmarks2.py	       pic_report.ipynb
# freelencer_face.ipynb	       real_soyoung_pics
# headLab			       shape_predictor_68_face_landmarks.dat
# idFace.ipynb		       soyoung_test
# lab

# %%
# !pwd
# Out:
# /home/face

# %% [markdown]
# #### training files in total

# %%
# !find catVsdog/ -type f|wc -l
# Out:
# 794

# %%
# !ls catVsdog/cat |wc -l
# Out:
# 376

# %%
# !ls catVsdog/dog |wc -l
# Out:
# 418

# %% [markdown]
# ### 1. generate chopped head

# %% [markdown]
# #### head size 96x96

# %%
# %%time
# !for N in {1..3}; do /root/openface/util/align-dlib.py \
./catVsdog/ align outerEyesAndNose ./catDog_Head_96 --size 96 & done
# Out:
# CPU times: user 16 ms, sys: 4 ms, total: 20 ms
# Wall time: 1.17 s

# %% [markdown]
# #### head size 128*128

# %%
# %%time
# !for N in {1..3}; do /root/openface/util/align-dlib.py \
./catVsdog/ align outerEyesAndNose ./catDog_Head_128 --size 128 & done
# Out:
# CPU times: user 28 ms, sys: 8 ms, total: 36 ms
# Wall time: 1.42 s

# %% [markdown]
# #### head size 192*192

# %%
# %%time
# !for N in {1..3}; do /root/openface/util/align-dlib.py \
./catVsdog/ align outerEyesAndNose ./catDog_Head_192 --size 192 & done
# Out:
# CPU times: user 4 ms, sys: 8 ms, total: 12 ms
# Wall time: 608 ms

# %% [markdown]
# #### head size 256*256

# %%
# %%time
# !for N in {1..3}; do /root/openface/util/align-dlib.py \
./catVsdog/ align outerEyesAndNose ./catDog_Head_256 --size 256 & done
# Out:
# CPU times: user 12 ms, sys: 4 ms, total: 16 ms
# Wall time: 763 ms

# %%
# !date
# Out:
# Fri Sep  8 23:39:12 UTC 2017

# %% [markdown]
# #### lost how many (not detect faces in pic)

# %%
# !find catDog_Head_256/ -type f|wc -l
# Out:
# 451

# %%
794-451
# Out:
# 343

# %% [markdown]
# lost rate

# %%
343/794.0
# Out:
# 0.43198992443324935

# %% [markdown]
# ### 2. extract head features to csv

# %% [markdown]
# #### 96

# %%
# %%time
! /root/openface/batch-represent/main.lua \
-outDir catDog_data_96 -data catDog_Head_96
# Out:
# {
#   data : "catDog_Head_96"
#   imgDim : 96
#   model : "/root/openface/models/openface/nn4.small2.v1.t7"
#   device : 1
#   outDir : "catDog_data_96"
#   cache : false
#   cuda : false
#   batchSize : 50
# }
# catDog_Head_96
# cache lotation: 	/home/face/catDog_Head_96/cache.t7
# Creating metadata for cache.
# {
#   sampleSize :
#     {
#       1 : 3
#       2 : 96
#       3 : 96
#     }
#   split : 0
#   verbose : true
#   paths :
#     {
#       1 : "catDog_Head_96"
#     }
#   samplingMode : "balanced"
#   loadSize :
#     {
#       1 : 3
#       2 : 96
#       3 : 96
#     }
# }
# running "find" on each class directory, and concatenate all those filenames into a single file containing all image paths for a given class
# now combine all the files to a single large file
# load the large concatenated list of sample paths to self.imagePath
# 450 samples found.	.....................]                              ETA: 0ms | Step: 0m 0/450
# Updating classList and imageClass appropriately
#  [=============================================>]                              Tot: 3ms | Step: 1m 2/2
# Cleaning up temporary files
# Splitting training and test sets to a ratio of 0/100
# nImgs: 	450
# Represent: 50/450
# Represent: 100/450
# Represent: 150/450
# Represent: 200/450
# Represent: 250/450
# Represent: 300/450
# Represent: 350/450
# Represent: 400/450
# Represent: 450/450
# CPU times: user 736 ms, sys: 128 ms, total: 864 ms
# Wall time: 51.9 s

# %% [markdown]
# #### 128

# %%
# %%time
! /root/openface/batch-represent/main.lua \
-outDir catDog_data_128 -data catDog_Head_128
# Out:
# {
#   data : "catDog_Head_128"
#   imgDim : 96
#   model : "/root/openface/models/openface/nn4.small2.v1.t7"
#   device : 1
#   outDir : "catDog_data_128"
#   cache : false
#   cuda : false
#   batchSize : 50
# }
# catDog_Head_128
# cache lotation: 	/home/face/catDog_Head_128/cache.t7
# Creating metadata for cache.
# {
#   sampleSize :
#     {
#       1 : 3
#       2 : 96
#       3 : 96
#     }
#   split : 0
#   verbose : true
#   paths :
#     {
#       1 : "catDog_Head_128"
#     }
#   samplingMode : "balanced"
#   loadSize :
#     {
#       1 : 3
#       2 : 96
#       3 : 96
#     }
# }
# running "find" on each class directory, and concatenate all those filenames into a single file containing all image paths for a given class
# now combine all the files to a single large file
# load the large concatenated list of sample paths to self.imagePath
# 450 samples found.	.....................]                              ETA: 0ms | Step: 0m 0/450
# Updating classList and imageClass appropriately
#  [=============================================>]                              Tot: 3ms | Step: 1m 2/2
# Cleaning up temporary files
# Splitting training and test sets to a ratio of 0/100
# nImgs: 	450
# Represent: 50/450
# Represent: 100/450
# Represent: 150/450
# Represent: 200/450
# Represent: 250/450
# Represent: 300/450
# Represent: 350/450
# Represent: 400/450
# Represent: 450/450
# CPU times: user 808 ms, sys: 156 ms, total: 964 ms
# Wall time: 57.3 s

# %% [markdown]
# #### 192

# %%
# %%time
! /root/openface/batch-represent/main.lua \
-outDir catDog_data_192 -data catDog_Head_192
# Out:
# {
#   data : "catDog_Head_192"
#   imgDim : 96
#   model : "/root/openface/models/openface/nn4.small2.v1.t7"
#   device : 1
#   outDir : "catDog_data_192"
#   cache : false
#   cuda : false
#   batchSize : 50
# }
# catDog_Head_192
# cache lotation: 	/home/face/catDog_Head_192/cache.t7
# Creating metadata for cache.
# {
#   sampleSize :
#     {
#       1 : 3
#       2 : 96
#       3 : 96
#     }
#   split : 0
#   verbose : true
#   paths :
#     {
#       1 : "catDog_Head_192"
#     }
#   samplingMode : "balanced"
#   loadSize :
#     {
#       1 : 3
#       2 : 96
#       3 : 96
#     }
# }
# running "find" on each class directory, and concatenate all those filenames into a single file containing all image paths for a given class
# now combine all the files to a single large file
# load the large concatenated list of sample paths to self.imagePath
# 450 samples found.	.....................]                              ETA: 0ms | Step: 0m 0/450
# Updating classList and imageClass appropriately
#  [=============================================>]                              Tot: 3ms | Step: 1m 2/2
# Cleaning up temporary files
# Splitting training and test sets to a ratio of 0/100
# nImgs: 	450
# Represent: 50/450
# Represent: 100/450
# Represent: 150/450
# Represent: 200/450
# Represent: 250/450
# Represent: 300/450
# Represent: 350/450
# Represent: 400/450
# Represent: 450/450
# CPU times: user 820 ms, sys: 108 ms, total: 928 ms
# Wall time: 53.2 s

# %% [markdown]
# #### 256

# %%
# %%time
! /root/openface/batch-represent/main.lua \
-outDir catDog_data_256 -data catDog_Head_256
# Out:
# {
#   data : "catDog_Head_256"
#   imgDim : 96
#   model : "/root/openface/models/openface/nn4.small2.v1.t7"
#   device : 1
#   outDir : "catDog_data_256"
#   cache : false
#   cuda : false
#   batchSize : 50
# }
# catDog_Head_256
# cache lotation: 	/home/face/catDog_Head_256/cache.t7
# Creating metadata for cache.
# {
#   sampleSize :
#     {
#       1 : 3
#       2 : 96
#       3 : 96
#     }
#   split : 0
#   verbose : true
#   paths :
#     {
#       1 : "catDog_Head_256"
#     }
#   samplingMode : "balanced"
#   loadSize :
#     {
#       1 : 3
#       2 : 96
#       3 : 96
#     }
# }
# running "find" on each class directory, and concatenate all those filenames into a single file containing all image paths for a given class
# now combine all the files to a single large file
# load the large concatenated list of sample paths to self.imagePath
# 450 samples found.	.....................]                              ETA: 0ms | Step: 0m 0/450
# Updating classList and imageClass appropriately
#  [=============================================>]                              Tot: 3ms | Step: 1m 2/2
# Cleaning up temporary files
# Splitting training and test sets to a ratio of 0/100
# nImgs: 	450
# Represent: 50/450
# Represent: 100/450
# Represent: 150/450
# Represent: 200/450
# Represent: 250/450
# Represent: 300/450
# Represent: 350/450
# Represent: 400/450
# Represent: 450/450
# CPU times: user 852 ms, sys: 144 ms, total: 996 ms
# Wall time: 1min 2s

# %% [markdown]
# #### check feature file dimentions

# %%
import pandas as pd

# %%
f96=pd.read_csv('catDog_data_96/reps.csv', header=None)
f96.shape
# Out:
# (450, 128)

# %%
f96.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.095006  0.114895 -0.040929  0.002802 -0.060583  0.164475  0.036179
# 1  0.137295  0.108829 -0.157067  0.086312  0.090994  0.045749  0.061320
# 2  0.025899  0.033756 -0.033221 -0.065075  0.099303  0.007095  0.003282
# 3  0.070520  0.007260 -0.035757  0.071901  0.027261 -0.007601  0.033085
# 4  0.120933  0.050017 -0.090746  0.057719  0.020990  0.106089  0.075409
#
#          7         8         9         10        11        12        13  \
# 0  0.089683  0.099084 -0.134550  0.007068  0.026751  0.013505 -0.111769
# 1 -0.083791 -0.005898 -0.117213  0.071663  0.032275  0.089404 -0.057295
# 2  0.076465  0.109737 -0.108329 -0.025985  0.073604  0.063265 -0.058728
# 3  0.042394  0.064380 -0.134384  0.019899  0.144023  0.005666 -0.079865
# 4  0.023931  0.093390 -0.098105  0.032173  0.071104  0.035584 -0.206047
#
#          14        15        16        17        18        19
# 0 -0.052792 -0.060445 -0.076484 -0.164740 -0.195195  0.021376 ...
# 1 -0.089638  0.032636  0.004368  0.054325 -0.205876  0.159025 ...
# 2 -0.041794  0.000205 -0.045691 -0.025312 -0.307362  0.104779 ...
# 3 -0.076105  0.002645 -0.018480 -0.142820 -0.178851  0.154239 ...
# 4 -0.139992  0.046117 -0.089187 -0.098780 -0.257584  0.137817 ...
#
# [5 rows x 128 columns]

# %%
f128=pd.read_csv('catDog_data_128/reps.csv', header=None)
f128.shape
# Out:
# (450, 128)

# %%
f128.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.086243  0.124854 -0.035895  0.000419 -0.061562  0.162168  0.041044
# 1  0.139364  0.105016 -0.157514  0.089904  0.094985  0.048664  0.059912
# 2  0.024157  0.031765 -0.037189 -0.066783  0.100834 -0.001507  0.008431
# 3  0.067764  0.005367 -0.035476  0.075289  0.028887 -0.011612  0.032036
# 4  0.121165  0.049362 -0.092587  0.060962  0.020293  0.104238  0.080345
#
#          7         8         9         10        11        12        13  \
# 0  0.087962  0.095252 -0.126775  0.004067  0.026089  0.014860 -0.114933
# 1 -0.085001 -0.009705 -0.117959  0.071064  0.036369  0.085311 -0.057629
# 2  0.078287  0.112682 -0.112771 -0.032721  0.071997  0.064183 -0.054581
# 3  0.038982  0.064892 -0.132440  0.019720  0.149014  0.002379 -0.083960
# 4  0.026756  0.092205 -0.099629  0.034261  0.075425  0.034695 -0.208176
#
#          14        15        16        17        18        19
# 0 -0.050952 -0.058112 -0.084955 -0.167485 -0.197519  0.020055 ...
# 1 -0.090126  0.036832  0.004098  0.054226 -0.200800  0.160812 ...
# 2 -0.042026 -0.005342 -0.043992 -0.031034 -0.307723  0.109155 ...
# 3 -0.080280  0.004745 -0.021731 -0.142685 -0.175762  0.158615 ...
# 4 -0.142693  0.040240 -0.088874 -0.100054 -0.257735  0.143877 ...
#
# [5 rows x 128 columns]

# %%
f192=pd.read_csv('catDog_data_192/reps.csv', header=None)
f192.shape
# Out:
# (450, 128)

# %%
f192.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.085534  0.121875 -0.033242 -0.005517 -0.061785  0.158229  0.041956
# 1  0.143668  0.104192 -0.158872  0.090996  0.096745  0.050620  0.059986
# 2  0.026961  0.034759 -0.045398 -0.066963  0.102839 -0.000167  0.010788
# 3  0.067774  0.001850 -0.033142  0.077854  0.028086 -0.014208  0.033387
# 4  0.124617  0.058271 -0.091265  0.062588  0.012904  0.107413  0.081266
#
#          7         8         9         10        11        12        13  \
# 0  0.084505  0.088980 -0.133272 -0.003205  0.027524  0.014034 -0.111096
# 1 -0.088667 -0.016674 -0.119501  0.071367  0.035538  0.084429 -0.054915
# 2  0.078728  0.125323 -0.114181 -0.028812  0.070645  0.062023 -0.060677
# 3  0.040117  0.066311 -0.131989  0.021156  0.151910 -0.000293 -0.085862
# 4  0.023759  0.089420 -0.098806  0.041917  0.072050  0.035991 -0.205544
#
#          14        15        16        17        18        19
# 0 -0.055958 -0.056309 -0.091178 -0.171083 -0.199078  0.022139 ...
# 1 -0.091975  0.037258  0.006054  0.057875 -0.195842  0.161042 ...
# 2 -0.049936 -0.004069 -0.037664 -0.025548 -0.312729  0.107154 ...
# 3 -0.080985  0.003352 -0.019888 -0.141862 -0.175353  0.160097 ...
# 4 -0.140867  0.038168 -0.085385 -0.100266 -0.258854  0.142295 ...
#
# [5 rows x 128 columns]

# %%
f256=pd.read_csv('catDog_data_256/reps.csv', header=None)
f256.shape
# Out:
# (450, 128)

# %%
f256.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.084256  0.124602 -0.032911 -0.005287 -0.062790  0.158262  0.043912
# 1  0.145251  0.102179 -0.159995  0.091649  0.098659  0.052362  0.059707
# 2  0.028025  0.036355 -0.047401 -0.067069  0.103842 -0.002339  0.012883
# 3  0.066869  0.002742 -0.032741  0.078806  0.027590 -0.016663  0.033716
# 4  0.124326  0.057964 -0.089978  0.062997  0.010768  0.107759  0.082306
#
#          7         8         9         10        11        12        13  \
# 0  0.082694  0.086530 -0.132431 -0.003451  0.028661  0.013015 -0.112457
# 1 -0.089451 -0.018852 -0.120745  0.071557  0.036485  0.083100 -0.054829
# 2  0.079872  0.127512 -0.113367 -0.029214  0.070639  0.061048 -0.061276
# 3  0.039150  0.065654 -0.131226  0.021373  0.152363 -0.000653 -0.085730
# 4  0.025259  0.089133 -0.102017  0.042654  0.072407  0.034893 -0.206650
#
#          14        15        16        17        18        19
# 0 -0.057183 -0.056525 -0.093483 -0.171704 -0.197998  0.021992 ...
# 1 -0.092525  0.039074  0.005904  0.059043 -0.193330  0.161276 ...
# 2 -0.050789 -0.004422 -0.033777 -0.026529 -0.313481  0.109807 ...
# 3 -0.082067  0.003570 -0.019690 -0.142042 -0.174617  0.162027 ...
# 4 -0.140678  0.035104 -0.087567 -0.101625 -0.259181  0.142993 ...
#
# [5 rows x 128 columns]

# %% [markdown]
# #### train classifier using only SVM in scikit-learn

# %%
# %%time
# !/root/openface/demos/classifier.py train catDog_data_96
# Out:
# /root/.local/lib/python2.7/site-packages/sklearn/lda.py:4: DeprecationWarning: lda.LDA has been moved to discriminant_analysis.LinearDiscriminantAnalysis in 0.17 and will be removed in 0.19
#   "in 0.17 and will be removed in 0.19", DeprecationWarning)
# Loading embeddings.
# Training for 2 classes.
# Saving classifier to 'catDog_data_96/classifier.pkl'
# CPU times: user 44 ms, sys: 24 ms, total: 68 ms
# Wall time: 2.36 s

# %%
# %%time
# !/root/openface/demos/classifier.py train catDog_data_128
# Out:
# /root/.local/lib/python2.7/site-packages/sklearn/lda.py:4: DeprecationWarning: lda.LDA has been moved to discriminant_analysis.LinearDiscriminantAnalysis in 0.17 and will be removed in 0.19
#   "in 0.17 and will be removed in 0.19", DeprecationWarning)
# Loading embeddings.
# Training for 2 classes.
# Saving classifier to 'catDog_data_128/classifier.pkl'
# CPU times: user 52 ms, sys: 12 ms, total: 64 ms
# Wall time: 2.4 s

# %%
# %%time
# !/root/openface/demos/classifier.py train catDog_data_192
# Out:
# /root/.local/lib/python2.7/site-packages/sklearn/lda.py:4: DeprecationWarning: lda.LDA has been moved to discriminant_analysis.LinearDiscriminantAnalysis in 0.17 and will be removed in 0.19
#   "in 0.17 and will be removed in 0.19", DeprecationWarning)
# Loading embeddings.
# Training for 2 classes.
# Saving classifier to 'catDog_data_192/classifier.pkl'
# CPU times: user 32 ms, sys: 20 ms, total: 52 ms
# Wall time: 2.38 s

# %%
# %%time
# !/root/openface/demos/classifier.py train catDog_data_256
# Out:
# /root/.local/lib/python2.7/site-packages/sklearn/lda.py:4: DeprecationWarning: lda.LDA has been moved to discriminant_analysis.LinearDiscriminantAnalysis in 0.17 and will be removed in 0.19
#   "in 0.17 and will be removed in 0.19", DeprecationWarning)
# Loading embeddings.
# Training for 2 classes.
# Saving classifier to 'catDog_data_256/classifier.pkl'
# CPU times: user 28 ms, sys: 32 ms, total: 60 ms
# Wall time: 2.38 s

# %% [markdown]
# ### make prediction on tests , un-train pics

# %% [markdown]
# ### note: out of 60 test pics (30 from each), 21 out of 60 cannot identify head,  yet for the 39 pics with head detected, only 2 misclassification. 2/39
#
# ### PS: images saved as 256x256 has better confidence than 96x96

# %% [markdown]
# 96

# %%
# %%time
# !/root/openface/demos/classifier.py \
infer ./catDog_data_96/classifier.pkl \
test_catDog/*
# Out:
# /root/.local/lib/python2.7/site-packages/sklearn/lda.py:4: DeprecationWarning: lda.LDA has been moved to discriminant_analysis.LinearDiscriminantAnalysis in 0.17 and will be removed in 0.19
#   "in 0.17 and will be removed in 0.19", DeprecationWarning)
#
# === test_catDog/110814_0.jpg ===
# Predict dog with 0.94 confidence.
#
# === test_catDog/110814_104.jpg ===
# Predict dog with 0.99 confidence.
#
# === test_catDog/110814_118.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/110814_133.jpg ===
# Predict cat with 0.76 confidence.
#
# === test_catDog/110814_152.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_163.jpg ===
# Predict dog with 0.91 confidence.
#
# === test_catDog/110814_18.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/110814_181.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/110814_211.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_221.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/110814_223.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_249.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_253.jpg ===
# Predict dog with 0.97 confidence.
#
# === test_catDog/110814_278.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_287.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_306.jpg ===
# Predict dog with 0.98 confidence.
#
# === test_catDog/110814_332.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/110814_376.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_383.jpg ===
# Predict dog with 0.99 confidence.
#
# === test_catDog/110814_423.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/110814_432.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/110814_441.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/110814_447.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_45.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_61.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_66.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_79.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_80.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_9.jpg ===
# Predict dog with 0.87 confidence.
#
# === test_catDog/110814_92.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_101.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_117.jpg ===
# Predict cat with 1.00 confidence.
#
# === test_catDog/131098_12.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_137.jpg ===
# Predict cat with 0.98 confidence.
#
# === test_catDog/131098_144.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_148.jpg ===
# Predict cat with 1.00 confidence.
#
# === test_catDog/131098_166.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_173.jpg ===
# Predict cat with 1.00 confidence.
#
# === test_catDog/131098_175.jpg ===
# Predict dog with 0.65 confidence.
#
# === test_catDog/131098_198.jpg ===
# Predict cat with 0.99 confidence.
#
# === test_catDog/131098_205.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_216.jpg ===
# Predict cat with 0.72 confidence.
#
# === test_catDog/131098_226.jpg ===
# Predict cat with 0.96 confidence.
#
# === test_catDog/131098_235.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_236.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_27.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_273.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_274.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_301.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_314.jpg ===
# Predict cat with 1.00 confidence.
#
# === test_catDog/131098_337.jpg ===
# Predict cat with 0.99 confidence.
#
# === test_catDog/131098_350.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_351.jpg ===
# Predict cat with 0.98 confidence.
#
# === test_catDog/131098_392.jpg ===
# Predict cat with 0.92 confidence.
#
# === test_catDog/131098_405.jpg ===
# Predict cat with 0.90 confidence.
#
# === test_catDog/131098_52.jpg ===
# Predict cat with 1.00 confidence.
#
# === test_catDog/131098_7.jpg ===
# Predict cat with 0.65 confidence.
#
# === test_catDog/131098_70.jpg ===
# Predict cat with 0.98 confidence.
#
# === test_catDog/131098_88.jpg ===
# Predict cat with 1.00 confidence.
#
# === test_catDog/131098_99.jpg ===
# Predict cat with 0.89 confidence.
# CPU times: user 272 ms, sys: 80 ms, total: 352 ms
# Wall time: 14 s

# %% [markdown]
# 128

# %%
# %%time
# !/root/openface/demos/classifier.py \
infer ./catDog_data_128/classifier.pkl \
test_catDog/*
# Out:
# /root/.local/lib/python2.7/site-packages/sklearn/lda.py:4: DeprecationWarning: lda.LDA has been moved to discriminant_analysis.LinearDiscriminantAnalysis in 0.17 and will be removed in 0.19
#   "in 0.17 and will be removed in 0.19", DeprecationWarning)
#
# === test_catDog/110814_0.jpg ===
# Predict dog with 0.94 confidence.
#
# === test_catDog/110814_104.jpg ===
# Predict dog with 0.99 confidence.
#
# === test_catDog/110814_118.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/110814_133.jpg ===
# Predict cat with 0.72 confidence.
#
# === test_catDog/110814_152.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_163.jpg ===
# Predict dog with 0.90 confidence.
#
# === test_catDog/110814_18.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/110814_181.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/110814_211.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_221.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/110814_223.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_249.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_253.jpg ===
# Predict dog with 0.98 confidence.
#
# === test_catDog/110814_278.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_287.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_306.jpg ===
# Predict dog with 0.98 confidence.
#
# === test_catDog/110814_332.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/110814_376.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_383.jpg ===
# Predict dog with 0.99 confidence.
#
# === test_catDog/110814_423.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/110814_432.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/110814_441.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/110814_447.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_45.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_61.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_66.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_79.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_80.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_9.jpg ===
# Predict dog with 0.85 confidence.
#
# === test_catDog/110814_92.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_101.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_117.jpg ===
# Predict cat with 1.00 confidence.
#
# === test_catDog/131098_12.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_137.jpg ===
# Predict cat with 0.97 confidence.
#
# === test_catDog/131098_144.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_148.jpg ===
# Predict cat with 1.00 confidence.
#
# === test_catDog/131098_166.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_173.jpg ===
# Predict cat with 1.00 confidence.
#
# === test_catDog/131098_175.jpg ===
# Predict dog with 0.59 confidence.
#
# === test_catDog/131098_198.jpg ===
# Predict cat with 0.99 confidence.
#
# === test_catDog/131098_205.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_216.jpg ===
# Predict cat with 0.67 confidence.
#
# === test_catDog/131098_226.jpg ===
# Predict cat with 0.96 confidence.
#
# === test_catDog/131098_235.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_236.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_27.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_273.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_274.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_301.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_314.jpg ===
# Predict cat with 1.00 confidence.
#
# === test_catDog/131098_337.jpg ===
# Predict cat with 0.98 confidence.
#
# === test_catDog/131098_350.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_351.jpg ===
# Predict cat with 0.98 confidence.
#
# === test_catDog/131098_392.jpg ===
# Predict cat with 0.90 confidence.
#
# === test_catDog/131098_405.jpg ===
# Predict cat with 0.90 confidence.
#
# === test_catDog/131098_52.jpg ===
# Predict cat with 1.00 confidence.
#
# === test_catDog/131098_7.jpg ===
# Predict cat with 0.63 confidence.
#
# === test_catDog/131098_70.jpg ===
# Predict cat with 0.98 confidence.
#
# === test_catDog/131098_88.jpg ===
# Predict cat with 1.00 confidence.
#
# === test_catDog/131098_99.jpg ===
# Predict cat with 0.87 confidence.
# CPU times: user 280 ms, sys: 68 ms, total: 348 ms
# Wall time: 14.1 s

# %% [markdown]
# 192

# %%
# %%time
# !/root/openface/demos/classifier.py \
infer ./catDog_data_192/classifier.pkl \
test_catDog/*
# Out:
# /root/.local/lib/python2.7/site-packages/sklearn/lda.py:4: DeprecationWarning: lda.LDA has been moved to discriminant_analysis.LinearDiscriminantAnalysis in 0.17 and will be removed in 0.19
#   "in 0.17 and will be removed in 0.19", DeprecationWarning)
#
# === test_catDog/110814_0.jpg ===
# Predict dog with 0.94 confidence.
#
# === test_catDog/110814_104.jpg ===
# Predict dog with 0.99 confidence.
#
# === test_catDog/110814_118.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/110814_133.jpg ===
# Predict cat with 0.64 confidence.
#
# === test_catDog/110814_152.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_163.jpg ===
# Predict dog with 0.88 confidence.
#
# === test_catDog/110814_18.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/110814_181.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/110814_211.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_221.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/110814_223.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_249.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_253.jpg ===
# Predict dog with 0.98 confidence.
#
# === test_catDog/110814_278.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_287.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_306.jpg ===
# Predict dog with 0.98 confidence.
#
# === test_catDog/110814_332.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/110814_376.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_383.jpg ===
# Predict dog with 0.99 confidence.
#
# === test_catDog/110814_423.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/110814_432.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/110814_441.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/110814_447.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_45.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_61.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_66.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_79.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_80.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_9.jpg ===
# Predict dog with 0.84 confidence.
#
# === test_catDog/110814_92.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_101.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_117.jpg ===
# Predict cat with 1.00 confidence.
#
# === test_catDog/131098_12.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_137.jpg ===
# Predict cat with 0.97 confidence.
#
# === test_catDog/131098_144.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_148.jpg ===
# Predict cat with 1.00 confidence.
#
# === test_catDog/131098_166.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_173.jpg ===
# Predict cat with 1.00 confidence.
#
# === test_catDog/131098_175.jpg ===
# Predict dog with 0.62 confidence.
#
# === test_catDog/131098_198.jpg ===
# Predict cat with 0.98 confidence.
#
# === test_catDog/131098_205.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_216.jpg ===
# Predict cat with 0.66 confidence.
#
# === test_catDog/131098_226.jpg ===
# Predict cat with 0.95 confidence.
#
# === test_catDog/131098_235.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_236.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_27.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_273.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_274.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_301.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_314.jpg ===
# Predict cat with 0.99 confidence.
#
# === test_catDog/131098_337.jpg ===
# Predict cat with 0.98 confidence.
#
# === test_catDog/131098_350.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_351.jpg ===
# Predict cat with 0.97 confidence.
#
# === test_catDog/131098_392.jpg ===
# Predict cat with 0.91 confidence.
#
# === test_catDog/131098_405.jpg ===
# Predict cat with 0.92 confidence.
#
# === test_catDog/131098_52.jpg ===
# Predict cat with 1.00 confidence.
#
# === test_catDog/131098_7.jpg ===
# Predict cat with 0.68 confidence.
#
# === test_catDog/131098_70.jpg ===
# Predict cat with 0.97 confidence.
#
# === test_catDog/131098_88.jpg ===
# Predict cat with 1.00 confidence.
#
# === test_catDog/131098_99.jpg ===
# Predict cat with 0.87 confidence.
# CPU times: user 284 ms, sys: 64 ms, total: 348 ms
# Wall time: 14.1 s

# %% [markdown]
# 256

# %%
# %%time
# !/root/openface/demos/classifier.py \
infer ./catDog_data_256/classifier.pkl \
test_catDog/*
# Out:
# /root/.local/lib/python2.7/site-packages/sklearn/lda.py:4: DeprecationWarning: lda.LDA has been moved to discriminant_analysis.LinearDiscriminantAnalysis in 0.17 and will be removed in 0.19
#   "in 0.17 and will be removed in 0.19", DeprecationWarning)
#
# === test_catDog/110814_0.jpg ===
# Predict dog with 0.93 confidence.
#
# === test_catDog/110814_104.jpg ===
# Predict dog with 0.99 confidence.
#
# === test_catDog/110814_118.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/110814_133.jpg ===
# Predict cat with 0.67 confidence.
#
# === test_catDog/110814_152.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_163.jpg ===
# Predict dog with 0.88 confidence.
#
# === test_catDog/110814_18.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/110814_181.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/110814_211.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_221.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/110814_223.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_249.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_253.jpg ===
# Predict dog with 0.98 confidence.
#
# === test_catDog/110814_278.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_287.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_306.jpg ===
# Predict dog with 0.98 confidence.
#
# === test_catDog/110814_332.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/110814_376.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_383.jpg ===
# Predict dog with 0.99 confidence.
#
# === test_catDog/110814_423.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/110814_432.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/110814_441.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/110814_447.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_45.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_61.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_66.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_79.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_80.jpg ===
# Predict dog with 1.00 confidence.
#
# === test_catDog/110814_9.jpg ===
# Predict dog with 0.80 confidence.
#
# === test_catDog/110814_92.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_101.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_117.jpg ===
# Predict cat with 1.00 confidence.
#
# === test_catDog/131098_12.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_137.jpg ===
# Predict cat with 0.97 confidence.
#
# === test_catDog/131098_144.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_148.jpg ===
# Predict cat with 1.00 confidence.
#
# === test_catDog/131098_166.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_173.jpg ===
# Predict cat with 1.00 confidence.
#
# === test_catDog/131098_175.jpg ===
# Predict dog with 0.54 confidence.
#
# === test_catDog/131098_198.jpg ===
# Predict cat with 0.99 confidence.
#
# === test_catDog/131098_205.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_216.jpg ===
# Predict cat with 0.64 confidence.
#
# === test_catDog/131098_226.jpg ===
# Predict cat with 0.95 confidence.
#
# === test_catDog/131098_235.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_236.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_27.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_273.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_274.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_301.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_314.jpg ===
# Predict cat with 1.00 confidence.
#
# === test_catDog/131098_337.jpg ===
# Predict cat with 0.98 confidence.
#
# === test_catDog/131098_350.jpg ===
# cannot find even one face in the picture
#
# === test_catDog/131098_351.jpg ===
# Predict cat with 0.98 confidence.
#
# === test_catDog/131098_392.jpg ===
# Predict cat with 0.90 confidence.
#
# === test_catDog/131098_405.jpg ===
# Predict cat with 0.92 confidence.
#
# === test_catDog/131098_52.jpg ===
# Predict cat with 1.00 confidence.
#
# === test_catDog/131098_7.jpg ===
# Predict cat with 0.70 confidence.
#
# === test_catDog/131098_70.jpg ===
# Predict cat with 0.97 confidence.
#
# === test_catDog/131098_88.jpg ===
# Predict cat with 1.00 confidence.
#
# === test_catDog/131098_99.jpg ===
# Predict cat with 0.88 confidence.
# CPU times: user 268 ms, sys: 72 ms, total: 340 ms
# Wall time: 13.8 s
