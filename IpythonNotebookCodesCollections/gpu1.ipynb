# %%
from time import time, ctime
import natsort
import os

# %%
path = 'AllText/'
want = os.listdir(path)
want = natsort.natsorted(want)
len(want), want[0], want[-1]
# Out:
# (367, 'batch_1.txt', 'batch_367.txt')

# %%
start_point = 60
batch = 20
want[start_point: start_point+1]
# Out:
# ['batch_61.txt']

# %%
n=start_point
for i in want[start_point: start_point+20]:
    n+=1
    start=time()
    print (n)
    print (i)
    # !/home/shj16110/anaconda2/envs/3.6.1/bin/python \
    Tensorflow/rude-carnie/guess.py --class_type gender --model_type inception --model_dir Tensorflow/21936 \
    --filename `pwd`/{path}{i} \
    --target `pwd`/predict/predict_{n}.csv \
#     > /dev/null 2>&1
    print ('used {:.2f} s, {:.2f} m, {:.2f} h'.format(time()-start, (time()-start)/60.0,(time()-start)/3600.0), ctime())
    print ('{:.2f} sceond per pic'.format((time()-start)/(300*batch)))
    print
# Out:
# 61
# batch_61.txt
# 2017-12-29 10:14:29.111256: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2017-12-29 10:14:29.111285: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-12-29 10:14:29.111291: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# 2017-12-29 10:14:29.297277: I tensorflow/core/common_runtime/gpu/gpu_device.cc:940] Found device 0 with properties:
# name: Tesla K40m
# major: 3 minor: 5 memoryClockRate (GHz) 0.745
# pciBusID 0000:03:00.0
# Total memory: 11.17GiB
# Free memory: 819.12MiB
# 2017-12-29 10:14:29.297302: I tensorflow/core/common_runtime/gpu/gpu_device.cc:961] DMA: 0
# 2017-12-29 10:14:29.297308: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   Y
# 2017-12-29 10:14:29.297316: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1030] Creating TensorFlow device (/gpu:0) -> (device: 0, name: Tesla K40m, pci bus id: 0000:03:00.0)
# Executing on /cpu:0
# selected (fine-tuning) inception model
# Tensorflow/21936/checkpoint-14999
# 2017-12-29 10:14:35.896895: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1030] Creating TensorFlow device (/gpu:0) -> (device: 0, name: Tesla K40m, pci bus id: 0000:03:00.0)
# Creating output file /home/shj16110/notebook/DeepGenderPred/predict/predict_61.csv
# ['/home/shj16110/notebook/DeepGenderPred/AllPics/10346008_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/7370037_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/11425305_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/13021938_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/1482713_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/9177112_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/6684016_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/14370486_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/1090951_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/10889671_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/10932605_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/733690_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/392271_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/9738340_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/1449066_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/9638005_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/3091918_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/912443_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/1157224_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/1353109_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/7524210_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/10074991_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/590057_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/13906279_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/10453691_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/3905255_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/1542763_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/11098320_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/480649_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/10434392_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/1971610_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/10484778_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/11186175_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/6974381_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/810866_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/1317261_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/1557630_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/1560306_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/540042_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/944733_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/7923851_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/995276_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/4302249_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/13965115_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/7759214_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/1420403_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/1637046_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/8293340_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/14044895_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/13713878_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/8022400_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/1532219_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/13006413_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/2843647_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/240430_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/541219_profile.jpg', '/home/shj16110/notebook/DeepGenderPred/AllPics/815188_profile.jpg', '/ho ...
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/10346008_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.60
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/7370037_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 1.00
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/11425305_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 1.00
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/13021938_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.92
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/1482713_profile.jpg
# Got 7 frames, but animated gifs can only be decoded by tf.image.decode_gif or tf.image.decode_image
# 	 [[Node: DecodeJpeg = DecodeJpeg[acceptable_fraction=1, channels=3, dct_method="", fancy_upscaling=true, ratio=1, try_recover_truncated=false, _device="/job:localhost/replica:0/task:0/cpu:0"](_arg_Placeholder_2_0_0)]]
#
# Caused by op 'DecodeJpeg', defined at:
#   File "Tensorflow/rude-carnie/guess.py", line 210, in <module>
#     tf.app.run()
#   File "/home/shj16110/anaconda2/envs/3.6.1/lib/python3.6/site-packages/tensorflow/python/platform/app.py", line 48, in run
#     _sys.exit(main(_sys.argv[:1] + flags_passthrough))
#   File "Tensorflow/rude-carnie/guess.py", line 173, in main
#     coder = ImageCoder()
#   File "/home/shj16110/notebook/DeepGenderPred/Tensorflow/rude-carnie/utils.py", line 72, in __init__
#     self._decode_jpeg = tf.image.decode_jpeg(self._decode_jpeg_data, channels=3)
#   File "/home/shj16110/anaconda2/envs/3.6.1/lib/python3.6/site-packages/tensorflow/python/ops/gen_image_ops.py", line 333, in decode_jpeg
#     dct_method=dct_method, name=name)
#   File "/home/shj16110/anaconda2/envs/3.6.1/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 767, in apply_op
#     op_def=op_def)
#   File "/home/shj16110/anaconda2/envs/3.6.1/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 2506, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/home/shj16110/anaconda2/envs/3.6.1/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1269, in __init__
#     self._traceback = _extract_stack()
#
# InvalidArgumentError (see above for traceback): Got 7 frames, but animated gifs can only be decoded by tf.image.decode_gif or tf.image.decode_image
# 	 [[Node: DecodeJpeg = DecodeJpeg[acceptable_fraction=1, channels=3, dct_method="", fancy_upscaling=true, ratio=1, try_recover_truncated=false, _device="/job:localhost/replica:0/task:0/cpu:0"](_arg_Placeholder_2_0_0)]]
#
# Failed to run image /home/shj16110/notebook/DeepGenderPred/AllPics/1482713_profile.jpg
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/9177112_profile.jpg
# Running multi-cropped image
# Guess @ 1 F, prob = 0.56
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/6684016_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.87
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/14370486_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.97
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/1090951_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 1.00
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/10889671_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.88
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/10932605_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.92
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/733690_profile.jpg
# Running multi-cropped image
# Guess @ 1 F, prob = 0.67
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/392271_profile.jpg
# Running multi-cropped image
# Guess @ 1 F, prob = 0.53
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/9738340_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.89
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/1449066_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.77
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/9638005_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.89
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/3091918_profile.jpg
# Running multi-cropped image
# Guess @ 1 F, prob = 0.52
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/912443_profile.jpg
# Running multi-cropped image
# Guess @ 1 F, prob = 0.80
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/1157224_profile.jpg
# Running multi-cropped image
# Guess @ 1 F, prob = 0.91
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/1353109_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.72
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/7524210_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.65
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/10074991_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.72
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/590057_profile.jpg
# Running multi-cropped image
# Guess @ 1 F, prob = 0.57
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/13906279_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.85
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/10453691_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.96
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/3905255_profile.jpg
# Running multi-cropped image
# Guess @ 1 F, prob = 0.58
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/1542763_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 1.00
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/11098320_profile.jpg
# Running multi-cropped image
# Guess @ 1 F, prob = 0.74
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/480649_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.95
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/10434392_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 1.00
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/1971610_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.56
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/10484778_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 1.00
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/11186175_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.67
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/6974381_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.57
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/810866_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.92
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/1317261_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.91
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/1557630_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.51
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/1560306_profile.jpg
# Running multi-cropped image
# Guess @ 1 F, prob = 1.00
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/540042_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.90
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/944733_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.73
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/7923851_profile.jpg
# Running multi-cropped image
# Guess @ 1 F, prob = 0.79
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/995276_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.99
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/4302249_profile.jpg
# Running multi-cropped image
# Guess @ 1 F, prob = 0.99
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/13965115_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.98
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/7759214_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.68
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/1420403_profile.jpg
# Running multi-cropped image
# Guess @ 1 F, prob = 0.91
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/1637046_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 1.00
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/8293340_profile.jpg
# Running multi-cropped image
# Guess @ 1 F, prob = 0.98
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/14044895_profile.jpg
# Running multi-cropped image
# Guess @ 1 F, prob = 1.00
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/13713878_profile.jpg
# Running multi-cropped image
# Guess @ 1 F, prob = 0.93
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/8022400_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.99
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/1532219_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.70
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/13006413_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.55
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/2843647_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.72
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/240430_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.67
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/541219_profile.jpg
# Running multi-cropped image
# Guess @ 1 F, prob = 0.78
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/815188_profile.jpg
# Running multi-cropped image
# Guess @ 1 F, prob = 1.00
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/13902163_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.98
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/749094_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.81
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/7077002_profile.jpg
# Running multi-cropped image
# Guess @ 1 F, prob = 0.84
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/2097568_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.93
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/1051612_profile.jpg
# Running multi-cropped image
# Guess @ 1 F, prob = 0.99
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/7115847_profile.jpg
# Running multi-cropped image
# Guess @ 1 F, prob = 0.70
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/1062084_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.99
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/537305_profile.jpg
# Running multi-cropped image
# Guess @ 1 F, prob = 0.95
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/1247592_profile.jpg
# Running multi-cropped image
# Guess @ 1 F, prob = 0.76
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/1640385_profile.jpg
# Running multi-cropped image
# Guess @ 1 F, prob = 0.93
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/11536788_profile.jpg
# Running multi-cropped image
# Guess @ 1 F, prob = 0.71
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/1590470_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.90
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/1660736_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.91
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/6838214_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.62
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/4097868_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.98
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/11447216_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.65
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/11694260_profile.jpg
# Running multi-cropped image
# Guess @ 1 F, prob = 0.62
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/284593_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.91
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/3115078_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.65
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/1466125_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 1.00
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/1507497_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.92
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/13860069_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.83
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/3430683_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.53
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/554685_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.92
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/1343029_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.68
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/13849587_profile.jpg
# Running multi-cropped image
# Guess @ 1 F, prob = 0.89
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/861696_profile.jpg
# Running multi-cropped image
# Guess @ 1 F, prob = 0.76
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/6592429_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.80
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/7523679_profile.jpg
# Running multi-cropped image
# Guess @ 1 F, prob = 0.87
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/9214439_profile.jpg
# Running multi-cropped image
# Guess @ 1 F, prob = 0.73
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/13096205_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.60
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/9263164_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.65
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/10967871_profile.jpg
# Running multi-cropped image
# Guess @ 1 F, prob = 0.77
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/8251417_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.65
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/11565896_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.92
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/10874605_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.99
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/13405980_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.78
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/1413396_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.71
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/6438592_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.71
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/4031688_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.71
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/4914359_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.99
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/5499684_profile.jpg
# Running multi-cropped image
# Guess @ 1 F, prob = 1.00
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/1570688_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.65
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/11064217_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 1.00
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/7018724_profile.jpg
# Running multi-cropped image
# Guess @ 1 M, prob = 0.92
# Running file /home/shj16110/notebook/DeepGenderPred/AllPics/1077280_profile.jpg
