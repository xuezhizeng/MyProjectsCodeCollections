# %%
# -*- coding: utf-8 -*-
import pandas as pd
from time import time
import seaborn as sns


import sys
reload(sys)
sys.setdefaultencoding('utf8')

# %%
gg = pd.read_excel('Google & Yelp Reviews.xlsx',sheetname=0)
df = gg[~gg['Review'].isnull()]

# %%
df = df[(df['Rating']>3)]

# %%
import nltk
# nltk.download('stopwords')
from nltk.stem.wordnet import WordNetLemmatizer
import string

from nltk.corpus import stopwords 
stopwords = set(stopwords.words('english'))
punctuation = set(string.punctuation) 
lemmatize = WordNetLemmatizer()

# %%
stop = pd.read_fwf('stop.txt',names=['words'])
stopwords.update(set(stop['words'].values))
# print (list(stopwords)[:10])
stopwords.update(set(['dont','lot','wa','im','ha','doe','wa', 'able',]))

# %%
def cleaning(article):
    article = str(article)
    zero = "".join(i for i in article if i not in punctuation)
    
    one = " ".join([i for i in zero.lower().split() if i not in stopwords])
    
    three = " ".join(lemmatize.lemmatize(i) for i in one.split())
    return three

# %%
from collections import defaultdict
freq = defaultdict(int)

for i in stopwords:
    freq[i]+=1

# %%
print type(freq)
freq['it']
# Out:
# 1

# %% [markdown]
# ### all

# %%
# all_content = df['content'].append(holdout['content'])

# %%
all_content=df['Review']
apple = all_content

# %% [markdown]
# ### choices

# %%
# nltk.download('wordnet')
start = time()

ap_text = apple.apply(cleaning)
ap_text_list = [i.split() for i in ap_text]
print (len(ap_text_list))

print ('used: {:.2f}s'.format(time()-start))

# %%
ap_text[:10]
# Out:
# 2     edward schiller service tech complete highly r...
# 3     product service impressed job foundation compa...
# 4     tried charge 500 replace sump pump battery rep...
# 6                                  awesome company deal
# 7            prompt efficient glad chose company thanks
# 8                                              time job
# 9     ive heard masterdry little positive neighbor a...
# 11    jeremy kevin extremely nice informative extrem...
# 13                 service tech professional inspection
# 14                       solve quickly price affordable
# Name: Review, dtype: object

# %%
from gensim.models.phrases import Phraser, Phrases

start = time()
phs = Phrases(ap_text_list)
('used: {:.2f}s'.format(time()-start))
# Out:
# 'used: 0.09s'

# %%
bi_gram = Phraser(phs)
start = time()

new_bi_list = [bi_gram[i] for i in ap_text_list]

('used: {:.2f}s'.format(time()-start))
# Out:
# 'used: 0.16s'

# %%
bi_gram[ap_text_list[0]]
# Out:
# [u'edward', u'schiller', u'service_tech', u'complete', u'highly_recommend']

# %%
new_bi_list[0]
# Out:
# [u'edward', u'schiller', u'service_tech', u'complete', u'highly_recommend']

# %%
start = time()

phs3=Phrases(new_bi_list)
tri_gram=Phraser(phs3)

('used: {:.2f}s'.format(time()-start))
# Out:
# 'used: 0.46s'

# %%
start = time()

new_tri_list = [tri_gram[i] for i in new_bi_list]

('used: {:.2f}s'.format(time()-start))
# Out:
# 'used: 0.19s'

# %%
# new_tri_list = new_bi_list

# %%
make_dic = dict()
for i,j in zip(range(len(new_tri_list)), new_tri_list):
    make_dic[i]=j

# %%
without_stop = pd.Series(make_dic)

# %%
without_stop.head(10)
# Out:
# 0    [edward, schiller, service_tech, complete, hig...
# 1    [product, service, impressed, job, foundation,...
# 2    [tried, charge, 500, replace, sump_pump, batte...
# 3                             [awesome, company, deal]
# 4    [prompt, efficient, glad, chose, company, thanks]
# 5                                          [time, job]
# 6    [ive, heard, masterdry, little, positive, neig...
# 7    [jeremy_kevin, extremely, nice, informative, e...
# 8             [service_tech, professional, inspection]
# 9                  [solve, quickly, price, affordable]
# dtype: object

# %%
len(without_stop[0])
# Out:
# 5

# %%
def helper_len(x):
    leng=[0]
    for i in x:
        leng.append(len(i))
    return max(leng)

# %%
with_stop = without_stop.apply(helper_len)

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
with_stop.value_counts().head(10)
# Out:
# 16    212
# 12    192
# 13    148
# 17    140
# 15    109
# 20    102
# 11     85
# 18     84
# 10     75
# 14     70
# dtype: int64

# %%
graph = with_stop.value_counts()

plt.figure(figsize=(12,6))
plt.bar(graph.index, graph.values, .7, color='g', alpha=.7)
# Out:
# <Container object of 27 artists>

# %%
without_stop[:10]
# Out:
# 0    [edward, schiller, service_tech, complete, hig...
# 1    [product, service, impressed, job, foundation,...
# 2    [tried, charge, 500, replace, sump_pump, batte...
# 3                             [awesome, company, deal]
# 4    [prompt, efficient, glad, chose, company, thanks]
# 5                                          [time, job]
# 6    [ive, heard, masterdry, little, positive, neig...
# 7    [jeremy_kevin, extremely, nice, informative, e...
# 8             [service_tech, professional, inspection]
# 9                  [solve, quickly, price, affordable]
# dtype: object

# %%
ap_text_list = list(without_stop.values)

# %%
len(ap_text_list)
# Out:
# 1551

# %%
ap_text_list[0]
# Out:
# [u'edward', u'schiller', u'service_tech', u'complete', u'highly_recommend']

# %% [markdown]
# ## topic models

# %%
# ! pip install gensim pyLDAvis WordCloud

# %% [markdown]
# ### change name

# %%
# Importing Gensim
import gensim
from gensim import corpora

from time import time
import logging

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO,
                   filename='hw_running120.log',filemode='w')

# %%
# Creating the term dictionary of our courpus, where every unique term is assigned an index. dictionary = corpora.Dictionary(doc_clean)
dictionary = corpora.Dictionary(ap_text_list)
dictionary.save('hw120.dict')
(dictionary)

# %%
# gensim.models.ldamodel.LdaModel?

# %%
# Converting list of documents (corpus) into Document Term Matrix using dictionary prepared above.
doc_term_matrix = [dictionary.doc2bow(doc) for doc in ap_text_list]
corpora.MmCorpus.serialize('hw120.mm', doc_term_matrix)

(len(doc_term_matrix))
(doc_term_matrix[100])
# Out:
# [(3, 1),
#  (21, 1),
#  (24, 1),
#  (43, 1),
#  (62, 1),
#  (103, 1),
#  (212, 2),
#  (222, 1),
#  (223, 1),
#  (359, 1),
#  (376, 1),
#  (383, 1),
#  (393, 1),
#  (398, 1),
#  (486, 1),
#  (569, 1),
#  (584, 1),
#  (932, 1),
#  (987, 1),
#  (1075, 1),
#  (1076, 1),
#  (1077, 1),
#  (1078, 1),
#  (1079, 1),
#  (1080, 1)]

# %%
# Lda?

# %%
start = time()
# Creating the object for LDA model using gensim library
Lda = gensim.models.ldamodel.LdaModel

# Running and Trainign LDA model on the document term matrix.
ldamodel = Lda(doc_term_matrix, num_topics=5, id2word = dictionary, 
#                passes=5
              )
'used: {:.2f}s'.format(time()-start)
# Out:
# 'used: 6.82s'

# %%
ldamodel.print_topics()
# Out:
# [(0,
#   u'0.013*"crew" + 0.012*"job" + 0.012*"time" + 0.011*"company" + 0.011*"professional" + 0.009*"service" + 0.007*"basement" + 0.007*"home" + 0.007*"system" + 0.006*"thank"'),
#  (1,
#   u'0.013*"basement" + 0.011*"crew" + 0.011*"job" + 0.010*"professional" + 0.008*"time" + 0.007*"house" + 0.007*"system" + 0.007*"day" + 0.006*"home" + 0.006*"service"'),
#  (2,
#   u'0.022*"job" + 0.014*"basement" + 0.012*"company" + 0.011*"crew" + 0.008*"professional" + 0.008*"time" + 0.007*"home" + 0.007*"system" + 0.007*"day" + 0.006*"service"')]

# %%
# !pip install pyLDAvis

# %%
ldamodel.save('hw120.model')

# %% [markdown]
# ## load saved model

# %%
from gensim.models import LdaModel
loading = LdaModel.load('hw120.model')

# %% [markdown]
# ## plotting

# %%
import pyLDAvis.gensim
import gensim
from time import time
pyLDAvis.enable_notebook()

# %%
d = gensim.corpora.Dictionary.load('hw120.dict')
c = gensim.corpora.MmCorpus('hw120.mm')
lda = gensim.models.LdaModel.load('hw120.model')

# %%
start = time()

data = pyLDAvis.gensim.prepare(lda, c, d)

print ('used: {:.2f}s'.format(time()-start))

# %%
pyLDAvis.save_html(data,'hw120.html')

# %%
data
# Out:
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 2      37.859668        1       1 -0.001349 -0.026397
# 1      31.323367        1       2 -0.022826  0.014335
# 0      30.816965        1       3  0.024176  0.012062, topic_info=     Category        Freq               Term       Total  loglift  logprob
# term
# 3110  Default  146.000000              thank  146.000000  30.0000  30.0000
# 2696  Default   99.000000          courteous   99.000000  29.0000  29.0000
# 6410  Default  664.000000                job  664.000000  28.0000  28.0000
# 908   Default  406.000000            company  406.000000  27.0000  27.0000
# 4254  Default   81.000000               hard   81.000000  26.0000  26.0000
# 2674  Default  129.000000              clean  129.000000  25.0000  25.0000
# 414   Default  379.000000               time  379.000000  24.0000  24.0000
# 2055  Default  139.000000                guy  139.000000  23.0000  23.0000
# 5319  Default   62.000000  answered_question   62.000000  22.0000  22.0000
# 2690  Default  505.000000           basement  505.000000  21.0000  21.0000
# 4633  Default   49.000000                 le   49.000000  20.0000  20.0000
# 2356  Default  112.000000      knowledgeable  112.000000  19.0000  19.0000
# 1854  Default   62.000000                 de   62.000000  18.0000  18.0000
# 1538  Default   51.000000               juan   51.000000  17.0000  17.0000
# 167   Default  288.000000            service  288.000000  16.0000  16.0000
# 1801  Default   67.000000      excellent_job   67.000000  15.0000  15.0000
# 3884  Default   95.000000          efficient   95.000000  14.0000  14.0000
# 4666  Default   36.000000               matt   36.000000  13.0000  13.0000
# 1947  Default  121.000000             thanks  121.000000  12.0000  12.0000
# 4252  Default  238.000000              house  238.000000  11.0000  11.0000
# 5111  Default   42.000000         insulation   42.000000  10.0000  10.0000
# 2252  Default   63.000000              price   63.000000   9.0000   9.0000
# 2203  Default   60.000000              fixed   60.000000   8.0000   8.0000
# 225   Default   35.000000                  ��   35.000000   7.0000   7.0000
# 3418  Default  494.000000               crew  494.000000   6.0000   6.0000
# 2262  Default  414.000000       professional  414.000000   5.0000   5.0000
# 3618  Default  122.000000               left  122.000000   4.0000   4.0000
# 3930  Default   31.000000               sean   31.000000   3.0000   3.0000
# 2186  Default   45.000000                 et   45.000000   2.0000   2.0000
# 181   Default  107.000000            project  107.000000   1.0000   1.0000
# ...       ...         ...                ...         ...      ...      ...
# 2203   Topic3   29.605215              fixed   60.097420   0.4691  -6.0971
# 3418   Topic3  176.762046               crew  494.361584   0.1486  -4.3102
# 3745   Topic3   32.242036           thrasher   67.523494   0.4379  -6.0118
# 1105   Topic3   14.615863     representative   26.385338   0.5864  -6.8029
# 908    Topic3  145.194848            company  406.650920   0.1472  -4.5070
# 2262   Topic3  144.858073       professional  414.373972   0.1261  -4.5093
# 6365   Topic3   45.639110            pleased  103.656281   0.3568  -5.6643
# 886    Topic3   65.213841         experience  161.863160   0.2680  -5.3074
# 3357   Topic3   52.893097          recommend  130.596596   0.2733  -5.5168
# 3244   Topic3   30.730964         technician   68.186124   0.3801  -6.0598
# 239    Topic3   25.858287             result   54.822987   0.4256  -6.2324
# 3206   Topic3   89.976326               home  294.454415  -0.0085  -4.9855
# 6410   Topic3  159.881883                job  664.898772  -0.2481  -4.4106
# 2598   Topic3   50.338086              issue  139.629854   0.1569  -5.5663
# 1417   Topic3   86.952565             system  293.653735  -0.0399  -5.0197
# 4322   Topic3   37.189958          extremely   94.958081   0.2397  -5.8690
# 787    Topic3   28.318286           complete   65.804573   0.3339  -6.1415
# 4181   Topic3   26.594262               hour   60.532896   0.3546  -6.2043
# 2301   Topic3   40.315183       installation  115.715888   0.1227  -5.7883
# 4252   Topic3   64.140107              house  238.550199  -0.1364  -5.3240
# 181    Topic3   37.834495            project  107.860061   0.1295  -5.8518
# 2690   Topic3   96.075758           basement  505.352245  -0.4830  -4.9199
# 51     Topic3   43.737381          explained  139.708698   0.0157  -5.7068
# 4651   Topic3   60.596294                day  261.420072  -0.2848  -5.3808
# 378    Topic3   43.302070               call  141.151265  -0.0045  -5.7168
# 5589   Topic3   42.120136          installed  138.457381  -0.0129  -5.7445
# 5419   Topic3   40.870005              water  129.523772   0.0236  -5.7746
# 3445   Topic3   39.464854   highly_recommend  153.738404  -0.1827  -5.8096
# 4809   Topic3   35.223635           finished  109.736329   0.0407  -5.9233
# 6163   Topic3   35.237347             called  133.002773  -0.1512  -5.9229
#
# [278 rows x 6 columns], token_table=      Topic      Freq               Term
# term
# 3064      3  0.795264                125
# 1294      1  0.738501               1400
# 1294      2  0.184625               1400
# 1294      3  0.184625               1400
# 3576      2  0.784684                163
# 588       1  0.339382                  2
# 588       2  0.447368                  2
# 588       3  0.215971                  2
# 4224      1  0.132874                 24
# 4224      2  0.265747                 24
# 4224      3  0.664368                 24
# 673       1  0.739983                830
# 673       2  0.184996                830
# 673       3  0.184996                830
# 257       1  0.234648           accident
# 257       2  0.703945           accident
# 4712      1  0.871904           ackworth
# 5837      1  0.197307            agustin
# 5837      2  0.789229            agustin
# 5837      3  0.197307            agustin
# 4028      3  0.795633             ailton
# 4124      1  0.733560            alberto
# 2298      1  0.734262           analyzed
# 5319      1  0.304177  answered_question
# 5319      2  0.112065  answered_question
# 5319      3  0.576335  answered_question
# 2735      1  0.711076            anthony
# 2735      2  0.158017            anthony
# 2735      3  0.079008            anthony
# 854       1  0.198798        appointment
# ...     ...       ...                ...
# 3745      3  0.473909           thrasher
# 3761      1  0.827452               thru
# 3761      2  0.275817               thru
# 414       1  0.321718               time
# 414       2  0.274252               time
# 414       3  0.403467               time
# 1694      1  0.457270               told
# 1694      2  0.293960               told
# 1694      3  0.250410               told
# 5699      2  0.786924              tower
# 4940      1  0.738030                ubs
# 6422      1  0.408049               wall
# 6422      2  0.349757               wall
# 6422      3  0.241499               wall
# 5419      1  0.409191              water
# 5419      2  0.270221              water
# 5419      3  0.316544              water
# 5960      1  0.630618      waterproofing
# 5960      2  0.244110      waterproofing
# 5960      3  0.122055      waterproofing
# 976       1  0.313344               week
# 976       2  0.394582               week
# 976       3  0.278528               week
# 4325      3  0.795962            western
# 5583      1  0.516069               wood
# 5583      2  0.309641               wood
# 5583      3  0.176938               wood
# 225       1  0.199870                  ��
# 225       2  0.628162                  ��
# 225       3  0.171317                  ��
#
# [479 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[3, 2, 1])

# %% [markdown]
# ## wordcloud

# %%
ap_text_list
# Out:
# [[u'edward', u'schiller', u'service_tech', u'complete', u'highly_recommend'],
#  [u'product',
#   u'service',
#   u'impressed',
#   u'job',
#   u'foundation',
#   u'company',
#   u'tell',
#   u'prevent',
#   u'sinking',
#   u'pier',
#   u'called',
#   u'strive',
#   u'jeremy',
#   u'raise',
#   u'concrete',
#   u'driveway',
#   u'original',
#   u'exactly',
#   u'doraise',
#   u'4',
#   u'inch',
#   u'driveway',
#   u'normal'],
#  [u'tried',
#   u'charge',
#   u'500',
#   u'replace',
#   u'sump_pump',
#   u'battery',
#   u'replaced',
#   u'exact',
#   u'battery',
#   u'100',
#   u'10',
#   u'minute',
#   u'disappointing',
#   u'ripoff'],
#  [u'awesome', u'company', u'deal'],
#  [u'prompt', u'efficient', u'glad', u'chose', u'company', u'thanks'],
#  [u'time', u'job'],
#  [u'ive',
#   u'heard',
#   u'masterdry',
#   u'little',
#   u'positive',
#   u'neighbor',
#   u'associate',
#   u'mine',
#   u'house',
#   u'terrible',
#   u'experience',
#   u'ive',
#   u'heard',
#   u'management',
#   u'poor',
#   u'8th',
#   u'grader',
#   u'run',
#   u'business',
#   u'efficiently',
#   u'worker',
#   u'ive',
#   u'heard',
#   u'seen',
#   u'suppose',
#   u'run',
#   u'try',
#   u'solve',
#   u'calling',
#   u'office',
#   u'solid',
#   u'answer',
#   u'figure',
#   u'heard',
#   u'negative',
#   u'worker',
#   u'little',
#   u'started',
#   u'salesman',
#   u'mean',
#   u'salesman',
#   u'try_sell',
#   u'extra',
#   u'dollar',
#   u'line',
#   u'pocket',
#   u'recommend',
#   u'masterdry',
#   u'looking',
#   u'professional',
#   u'business',
#   u'hard_worker',
#   u'yes',
#   u'wanna',
#   u'lose',
#   u'money',
#   u'advise',
#   u'staying'],
#  [u'jeremy_kevin',
#   u'extremely',
#   u'nice',
#   u'informative',
#   u'extremely',
#   u'excellent_job',
#   u'excellent_job',
#   u'final',
#   u'concrete',
#   u'patching',
#   u'look',
#   u'nice',
#   u'recommend',
#   u'neighbor',
#   u'family',
#   u'wood',
#   u'foundation_repair',
#   u'job',
#   u'especially',
#   u'couple',
#   u'professional',
#   u'jeremy_kevin',
#   u'job',
#   u'thank',
#   u'job',
#   u'add',
#   u'job_cleaning',
#   u'thank',
#   u'woodsfoundation',
#   u'repair',
#   u'sleep',
#   u'easier',
#   u'knowing',
#   u'job'],
#  [u'service_tech', u'professional', u'inspection'],
#  [u'solve', u'quickly', u'price', u'affordable'],
#  [u'guy',
#   u'crook',
#   u'contacted',
#   u'estimate',
#   u'crawl_space',
#   u'fairly',
#   u'dampness',
#   u'14',
#   u'crawl_space',
#   u'guy',
#   u'looked',
#   u'crawl_space',
#   u'kept',
#   u'living',
#   u'trying',
#   u'impress',
#   u'power',
#   u'session',
#   u'whats',
#   u'crawl_space',
#   u'kept',
#   u'living',
#   u'quote',
#   u'3000000',
#   u'telling',
#   u'quote',
#   u'wayy',
#   u'priced',
#   u'quote',
#   u'told',
#   u'500000',
#   u'okay',
#   u'charge',
#   u'25000',
#   u'yes',
#   u'pushy',
#   u'told',
#   u'leave',
#   u'quote',
#   u'ill',
#   u'contact',
#   u'deem',
#   u'wouldnt',
#   u'stop',
#   u'trying',
#   u'money',
#   u'else',
#   u'review',
#   u'pushy',
#   u'thats',
#   u'exactly',
#   u'true',
#   u'guy',
#   u'pushy',
#   u'research',
#   u'person',
#   u'little',
#   u'digging',
#   u'found',
#   u'guy',
#   u'operate',
#   u'name',
#   u'figure',
#   u'inconclusion',
#   u'hire',
#   u'guy',
#   u'hire',
#   u'risk'],
#  [u'time', u'service', u'thorough', u'job'],
#  [u'experience',
#   u'standard_heating',
#   u'air_conditioning',
#   u'ac',
#   u'friday',
#   u'standard',
#   u'called',
#   u'monday',
#   u'called',
#   u'9',
#   u'ac',
#   u'job',
#   u'standard',
#   u'larger',
#   u'scope',
#   u'expected',
#   u'broken',
#   u'3_day',
#   u'standard',
#   u'finally',
#   u'ac',
#   u'thats',
#   u'yay',
#   u'despite',
#   u'standard',
#   u'crew',
#   u'redo',
#   u'original',
#   u'developer',
#   u'construction',
#   u'installers',
#   u'performed',
#   u'ago',
#   u'standard',
#   u'crew',
#   u'job',
#   u'super',
#   u'nice',
#   u'polite',
#   u'dog',
#   u'standard',
#   u'technical',
#   u'guy',
#   u'knowledgeable',
#   u'fixed',
#   u'quickly',
#   u'utility',
#   u'space',
#   u'consideration',
#   u'home',
#   u'livable',
#   u'photo',
#   u'issue',
#   u'left',
#   u'original',
#   u'contractor',
#   u'resultsfixes',
#   u'standard',
#   u'thank',
#   u'standard'],
#  [u'michael',
#   u'ran',
#   u'crew',
#   u'ran',
#   u'obstacle',
#   u'kept_informed',
#   u'talk',
#   u'option',
#   u'care',
#   u'overall_experience'],
#  [u'hour', u'calling', u'job'],
#  [u'competent',
#   u'efficient',
#   u'technician',
#   u'impressed',
#   u'recommend',
#   u'standard'],
#  [u'past',
#   u'month',
#   u'trying',
#   u'morris',
#   u'jenkins',
#   u'service',
#   u'air_conditioning',
#   u'excuse',
#   u'called',
#   u'gsm_service',
#   u'immediately',
#   u'hour',
#   u'nishan',
#   u'fixed',
#   u'ac_unit',
#   u'hour',
#   u'thank',
#   u'gsm',
#   u'thank',
#   u'dj',
#   u'recommending',
#   u'gsm'],
#  [u'jeremy_kevin', u'malik', u'professional', u'hard', u'job', u'time'],
#  [u'uneven',
#   u'temperature',
#   u'house',
#   u'furnace',
#   u'ac',
#   u'running',
#   u'mark',
#   u'assessed',
#   u'situation',
#   u'attic',
#   u'insulation',
#   u'terribly',
#   u'insufficient',
#   u'original',
#   u'house',
#   u'circu',
#   u'1950\xe2\u20ac\u2122s',
#   u'flattened',
#   u'dirty',
#   u'broken',
#   u'team',
#   u'removed',
#   u'insulation',
#   u'installed',
#   u'proper',
#   u'insulation',
#   u'house',
#   u'world',
#   u'difference',
#   u'house',
#   u'heated',
#   u'cooled',
#   u'comfortable',
#   u'heating',
#   u'ac',
#   u'bill',
#   u'decreased',
#   u'team',
#   u'excellent_job',
#   u'completed',
#   u'time',
#   u'cleanup',
#   u'job',
#   u'afterwards',
#   u'happy',
#   u'recommend',
#   u'highly'],
#  [u'quick',
#   u'professional',
#   u'knowledgeable',
#   u'happy',
#   u'wrong',
#   u'didnt',
#   u'blow',
#   u'smoke',
#   u'try_sell',
#   u'didnt',
#   u'15',
#   u'hvac',
#   u'replace',
#   u'compressor',
#   u'breaking',
#   u'bank'],
#  [u'scott_wilson',
#   u'afs',
#   u'developed',
#   u'proposal',
#   u'alleviate',
#   u'moisture',
#   u'water',
#   u'crawlspace',
#   u'realized',
#   u'afs',
#   u'appeared',
#   u'solution',
#   u'industry',
#   u'system',
#   u'exactly',
#   u'proposed',
#   u'eliminated',
#   u'crawlspace',
#   u'moisture',
#   u'water',
#   u'found',
#   u'afs',
#   u'reputable',
#   u'company',
#   u'provides',
#   u'product',
#   u'solution',
#   u'highly_recommend',
#   u'scott',
#   u'afs',
#   u'team'],
#  [u'installed',
#   u'french_drain',
#   u'sump_pump',
#   u'half',
#   u'basement',
#   u'gentleman',
#   u'profession',
#   u'job',
#   u'water',
#   u'basement',
#   u'march',
#   u'ground',
#   u'hard',
#   u'installed',
#   u'discharge_line',
#   u'ground',
#   u'temporarily',
#   u'weve',
#   u'called',
#   u'couple',
#   u'time',
#   u'reply',
#   u'bury',
#   u'time',
#   u'unfortunately',
#   u'doesnt',
#   u'appear',
#   u'theyve',
#   u'6',
#   u'month',
#   u'look',
#   u'finish',
#   u'unfortunately',
#   u'money',
#   u'finally',
#   u'bury',
#   u'discharge_line',
#   u'id',
#   u'revisit',
#   u'star'],
#  [u'steven',
#   u'grant',
#   u'install',
#   u'hvac',
#   u'equipment',
#   u'duct',
#   u'design',
#   u'hvac',
#   u'system',
#   u'additional',
#   u'insulation',
#   u'happier',
#   u'result',
#   u'process',
#   u'highly_recommend',
#   u'steven',
#   u'gsm',
#   u'positive',
#   u'experience',
#   u'home',
#   u'challenge',
#   u'design',
#   u'system',
#   u'due',
#   u'splitlevel',
#   u'design',
#   u'steven',
#   u'spent',
#   u'hour',
#   u'evaluating',
#   u'home',
#   u'wellrounded',
#   u'solution',
#   u'steven',
#   u'straightforward',
#   u'patient',
#   u'throughout_process',
#   u'told',
#   u'recommendation',
#   u'husband',
#   u'detailed',
#   u'technical',
#   u'question',
#   u'design',
#   u'gsm',
#   u'team',
#   u'exceeded_expectation',
#   u'knowledge',
#   u'experience',
#   u'positive',
#   u'attitude',
#   u'project',
#   u'steven',
#   u'space',
#   u'steven',
#   u'followed',
#   u'throughout',
#   u'installation',
#   u'inspection',
#   u'process',
#   u'extremely',
#   u'responsive',
#   u'busy',
#   u'perfect',
#   u'hvac',
#   u'system',
#   u'happier',
#   u'top',
#   u'steven',
#   u'set',
#   u'duke',
#   u'power',
#   u'rebate',
#   u'home',
#   u'efficient',
#   u'thank',
#   u'steven'],
#  [u'service', u'day', u'called'],
#  [u'impression',
#   u'called',
#   u'gsm',
#   u'issue',
#   u'central',
#   u'air',
#   u'tech',
#   u'home',
#   u'day',
#   u'friday',
#   u'tech',
#   u'clean',
#   u'condenser',
#   u'inspected',
#   u'system',
#   u'couldnt',
#   u'wrong',
#   u'suggested',
#   u'running',
#   u'duct',
#   u'apparently',
#   u'answer',
#   u'hear',
#   u'installing',
#   u'bypass',
#   u'system',
#   u'home',
#   u'6',
#   u'installed',
#   u'fixed',
#   u'consultant',
#   u'home',
#   u'stated',
#   u'tech',
#   u'couldnt',
#   u'fix',
#   u'option',
#   u'install',
#   u'system',
#   u'18000',
#   u'called',
#   u'quote',
#   u'week',
#   u'called',
#   u'company',
#   u'quote',
#   u'bringing',
#   u'cooling',
#   u'tower',
#   u'decided',
#   u'call',
#   u'day',
#   u'answer',
#   u'called',
#   u'cooling',
#   u'tower',
#   u'luckily',
#   u'week',
#   u'gm',
#   u'van',
#   u'neighbor',
#   u'home',
#   u'tech',
#   u'please',
#   u'stop',
#   u'garage',
#   u'solution',
#   u'fixed',
#   u'researching',
#   u'internet',
#   u'finding',
#   u'blower',
#   u'motor',
#   u'husband',
#   u'checked',
#   u'found',
#   u'disconnected',
#   u'wire',
#   u'connected',
#   u'fine',
#   u'wasted',
#   u'money',
#   u'time',
#   u'gsm'],
#  [u'excellent_service',
#   u'guy',
#   u'ontime',
#   u'fast',
#   u'courteous',
#   u'professional',
#   u'highly_recommended'],
#  [u'scott', u'straightened', u'unit', u'decided', u'service'],
#  [u'jeremy_kevin',
#   u'house',
#   u'install',
#   u'wall_anchor',
#   u'super',
#   u'friendly',
#   u'time',
#   u'finished',
#   u'ahead',
#   u'schedule',
#   u'look',
#   u'question',
#   u'basement',
#   u'happy',
#   u'answer',
#   u'overall_experience',
#   u'highly_recommend_wood_basement',
#   u'system'],
#  [u'waiting',
#   u'2',
#   u'month',
#   u'basement',
#   u'water_coming',
#   u'door',
#   u'looked',
#   u'told',
#   u'completely',
#   u'waterproof',
#   u'entire',
#   u'basement',
#   u'included',
#   u'purchasing',
#   u'sump_pump',
#   u'fine',
#   u'except',
#   u'spot',
#   u'fixed',
#   u'brand',
#   u'sump_pump',
#   u'perfectly',
#   u'technician',
#   u'gouging',
#   u'company',
#   u'nothing',
#   u'address',
#   u'issue',
#   u'voiced',
#   u'concern',
#   u'completely',
#   u'ignored',
#   u'apologized',
#   u'technician',
#   u'embarrassed',
#   u'unethical',
#   u'practice',
#   u'company',
#   u'recommend'],
#  [u'gsm',
#   u'replaced',
#   u'aging',
#   u'hvac',
#   u'system',
#   u'efficient',
#   u'system',
#   u'wonderfully',
#   u'pleased'],
#  [u'jeremy_kevin'],
#  [u'pipework',
#   u'schedule',
#   u'quickly',
#   u'clean',
#   u'tricky',
#   u'roof',
#   u'drain',
#   u'glad',
#   u'plumbing',
#   u'contractor',
#   u'clean',
#   u'roof',
#   u'drain',
#   u'pleased',
#   u'completed',
#   u'technician',
#   u'pablo',
#   u'explained',
#   u'carefully',
#   u'clean',
#   u'job',
#   u'price',
#   u'fair',
#   u'definitely_recommend'],
#  [u'job',
#   u'exceeded_expectation',
#   u'guy',
#   u'gary',
#   u'cox',
#   u'foreman',
#   u'jonathan',
#   u'bush',
#   u'co',
#   u'foreman',
#   u'james',
#   u'brown',
#   u'installer',
#   u'professional',
#   u'knowledgeable',
#   u'gentleman',
#   u'recommend',
#   u'job',
#   u'ensured',
#   u'understood',
#   u'hard_worker',
#   u'produce',
#   u'quality',
#   u'remove',
#   u'tree',
#   u'gate',
#   u'defeated',
#   u'yard',
#   u'look',
#   u'gate',
#   u'secure',
#   u'clean',
#   u'free',
#   u'material',
#   u'branch',
#   u'etc',
#   u'hopefully',
#   u'wont',
#   u'service',
#   u'smile',
#   u'blessed',
#   u'crew'],
#  [u'courteous',
#   u'thorough',
#   u'wonderful',
#   u'accurate',
#   u'complete',
#   u'service',
#   u'adk'],
#  [u'excellent',
#   u'efficient',
#   u'product',
#   u'market',
#   u'flooding',
#   u'yesterday',
#   u'29aug',
#   u'received',
#   u'water',
#   u'proof',
#   u'pudding'],
#  [u'excellent',
#   u'efficient',
#   u'product',
#   u'market',
#   u'flooding',
#   u'yesterday',
#   u'29aug',
#   u'received',
#   u'water',
#   u'proof',
#   u'pudding'],
#  [u'salestech',
#   u'representative',
#   u'ed',
#   u'okonsky',
#   u'company\xe2\u20ac\u2122s',
#   u'asset',
#   u'ed',
#   u'halco',
#   u'professionalism',
#   u'proved',
#   u'\xe2\u20ac\u0153subject',
#   u'matter',
#   u'expert\xe2\u20ac\x9d',
#   u'impressed',
#   u'ability',
#   u'patiently',
#   u'absorb',
#   u'verbal',
#   u'basic',
#   u'knowledge',
#   u'hvac',
#   u'educate',
#   u'familiar',
#   u'build',
#   u'overall',
#   u'confidence',
#   u'halco',
#   u'respected',
#   u'knowledge',
#   u'try',
#   u'intimidate',
#   u'extensive',
#   u'knowledge',
#   u'base',
#   u'appreciated',
#   u'hvac',
#   u'company',
#   u'home',
#   u'advise',
#   u'quote',
#   u'somewhat',
#   u'price',
#   u'choice',
#   u'hire',
#   u'company',
#   u'wife',
#   u'happy',
#   u'decision',
#   u'start',
#   u'initial',
#   u'consult',
#   u'expert',
#   u'install',
#   u'team',
#   u'assigned',
#   u'homehalco',
#   u'expertly',
#   u'professionally',
#   u'installed',
#   u'coil',
#   u'outside',
#   u'ac',
#   u'condenser',
#   u'endorsement',
#   u'company',
#   u'folk',
#   u'sent',
#   u'complete',
#   u'home',
#   u'project',
#   u'regarding',
#   u'assessment',
#   u'quotation',
#   u'response',
#   u'24',
#   u'hour',
#   u'install',
#   u'bochenski',
#   u'dryden',
#   u'ny',
#   u'30',
#   u'aug',
#   u'2017'],
#  [u'wonderful',
#   u'team',
#   u'gsm',
#   u'wayne',
#   u'addressed',
#   u'question',
#   u'extremely',
#   u'focused',
#   u'meeting',
#   u'hvac'],
#  [u'dave',
#   u'palmer',
#   u'crew',
#   u'jeremy_kevin',
#   u'excellent_job',
#   u'explaining',
#   u'completing',
#   u'requested',
#   u'continue',
#   u'recommend_wood',
#   u'family_friend',
#   u'coworkers'],
#  [u'wow',
#   u'company',
#   u'top_notch',
#   u'quality',
#   u'service',
#   u'guarantee',
#   u'customer_service',
#   u'nervewracking',
#   u'repair',
#   u'basement',
#   u'mention',
#   u'costly',
#   u'informative',
#   u'informed',
#   u'decision',
#   u'feel',
#   u'cost',
#   u'involved',
#   u'office_staff',
#   u'consultant',
#   u'sam',
#   u'gentleman',
#   u'installed',
#   u'system',
#   u'josh',
#   u'henry',
#   u'nothing',
#   u'short',
#   u'amazing',
#   u'stressful',
#   u'circumstance',
#   u'peace_mind',
#   u'process',
#   u'happy',
#   u'chose',
#   u'tarheel',
#   u'basement_system',
#   u'truly',
#   u'breathe',
#   u'easier',
#   u'time',
#   u'look',
#   u'repaired',
#   u'basement',
#   u'wall'],
#  [u'team',
#   u'polite',
#   u'people',
#   u'go',
#   u'wrong',
#   u'help',
#   u'highly_recommend',
#   u'gsm_service'],
#  [u'luis',
#   u'foreman',
#   u'intense',
#   u'respectful',
#   u'house',
#   u'di',
#   u'awesome_job',
#   u'luis',
#   u'excellent_job',
#   u'explaining',
#   u'step_step',
#   u'guy',
#   u'representative',
#   u'company',
#   u'definitely',
#   u'calling',
#   u'complete_basement_system',
#   u'requesting',
#   u'luis',
#   u'thank'],
#  [u'recently',
#   u'sump_pump',
#   u'exit',
#   u'drain',
#   u'installed',
#   u'wood',
#   u'crew',
#   u'installed',
#   u'french_drain',
#   u'exited',
#   u'middle',
#   u'yard',
#   u'caused',
#   u'yard',
#   u'flood',
#   u'call',
#   u'time',
#   u'crew',
#   u'fix',
#   u'specialist',
#   u'pete',
#   u'return',
#   u'phone_call',
#   u'completed',
#   u'according',
#   u'standard',
#   u'explained',
#   u'pete',
#   u'drain',
#   u'foot',
#   u'ground',
#   u'pouring',
#   u'concrete',
#   u'walkway',
#   u'foundation',
#   u'assured',
#   u'discovered',
#   u'afterward',
#   u'pipe',
#   u'barely',
#   u'ground',
#   u'call',
#   u'contractor',
#   u'fix',
#   u'rely',
#   u'wood',
#   u'project'],
#  [u'dealing',
#   u'charlotte',
#   u'comfort',
#   u'system',
#   u'incompetent',
#   u'tech',
#   u'nasty',
#   u'management',
#   u'decided',
#   u'switched',
#   u'gsm',
#   u'wow',
#   u'difference',
#   u'service',
#   u'pleasure',
#   u'deal',
#   u'system',
#   u'running',
#   u'top',
#   u'wish',
#   u'switched',
#   u'sooner',
#   u'recommend',
#   u'improvement',
#   u'contact',
#   u'schedule',
#   u'springfall',
#   u'tune',
#   u'ups',
#   u'remember',
#   u'call',
#   u'overall',
#   u'guy'],
#  [u'experience', u'talented', u'technician'],
#  [u'gsm',
#   u'prompt',
#   u'send',
#   u'system_installed',
#   u'26',
#   u'month',
#   u'ago',
#   u'liked',
#   u'system',
#   u'service',
#   u'contract',
#   u'pay',
#   u'diagnostic',
#   u'fee',
#   u'sometimes',
#   u'cost',
#   u'extra',
#   u'service',
#   u'people',
#   u'wish',
#   u'product',
#   u'bought',
#   u'little',
#   u'reliable'],
#  [u'scott_ramsey',
#   u'technician',
#   u'thorough',
#   u'polite',
#   u'helpful',
#   u'resolved',
#   u'issue',
#   u'promptly'],
#  [u'wonderful_job', u'hard'],
#  [u'nous_avon',
#   u'maintenant',
#   u'lesprit',
#   u'tranquille',
#   u'depuis',
#   u'linstallation',
#   u'de',
#   u'poutres',
#   u'de',
#   u'soutien',
#   u'smart_jack',
#   u'pour',
#   u'soutenir',
#   u'le',
#   u'poutres',
#   u'fatigu\xc3\xa9es',
#   u'de',
#   u'notre',
#   u'maison',
#   u'centenaire',
#   u'nous',
#   u'somme',
#   u'tr\xc3\xa8s',
#   u'satisfaits',
#   u'du',
#   u'professionnalisme',
#   u'de_la',
#   u'compagnie',
#   u'\xc3',
#   u'toutes',
#   u'le',
#   u'\xc3\xa9tapes',
#   u'du',
#   u'processus',
#   u'cest',
#   u'un',
#   u'peu',
#   u'dispendieux',
#   u'mais',
#   u'\xc3\xa7a',
#   u'vaut',
#   u'linvestissement'],
#  [u'creak',
#   u'foundation',
#   u'deal',
#   u'asian',
#   u'senior',
#   u'inspector',
#   u'check',
#   u'beyond',
#   u'knowledge',
#   u'look',
#   u'structure',
#   u'engineer',
#   u'waste_time',
#   u'company',
#   u'doesnt',
#   u'responsibility',
#   u'try',
#   u'avoid'],
#  [u'jeremy',
#   u'luis',
#   u'prompt',
#   u'knowledgeable',
#   u'efficient',
#   u'professional',
#   u'answered_question',
#   u'left_clean',
#   u'couldnt'],
#  [u'corner',
#   u'house',
#   u'sunken',
#   u'slightly',
#   u'causing',
#   u'crack',
#   u'brick',
#   u'creating',
#   u'concern',
#   u'slab',
#   u'local',
#   u'estimate',
#   u'repair',
#   u'thousand',
#   u'dollar',
#   u'professional',
#   u'highly',
#   u'professional',
#   u'organization',
#   u'recommend',
#   u'else',
#   u'foundation_repair',
#   u'crew',
#   u'joe',
#   u'hawkins',
#   u'eric',
#   u'friday',
#   u'ne',
#   u'jordan',
#   u'kendell',
#   u'baldwin',
#   u'polite',
#   u'hardworking',
#   u'explained',
#   u'quickly',
#   u'experience'],
#  [u'top_notch',
#   u'service',
#   u'kitchen',
#   u'faucet',
#   u'piping',
#   u'replaced',
#   u'technician',
#   u'pablo',
#   u'outstanding',
#   u'prompt',
#   u'professional',
#   u'knowledgeable',
#   u'conscientious',
#   u'obvious',
#   u'take',
#   u'pride',
#   u'customer_service'],
#  [u'standard',
#   u'job',
#   u'courteous',
#   u'time',
#   u'finished',
#   u'sooner',
#   u'estimated'],
#  [u'standard_heating',
#   u'air_conditioning',
#   u'company',
#   u'repaired',
#   u'heat_pump',
#   u'job'],
#  [u'jeremy_kevin',
#   u'hard',
#   u'8',
#   u'hr',
#   u'house',
#   u'yard',
#   u'looked',
#   u'werent',
#   u'overall',
#   u'job'],
#  [u'jacob',
#   u'partner',
#   u'nick',
#   u'job',
#   u'site',
#   u'enthusiastic',
#   u'ability',
#   u'lift',
#   u'concrete',
#   u'pad',
#   u'dropped',
#   u'worrisome',
#   u'interior',
#   u'floor',
#   u'drop',
#   u'ten',
#   u'careful',
#   u'confident',
#   u'foam',
#   u'jacking',
#   u'fine',
#   u'inside',
#   u'jacob',
#   u'willing',
#   u'speak',
#   u'neighbor',
#   u'concrete',
#   u'concern'],
#  [u'technician',
#   u'dan',
#   u'deneve',
#   u'house',
#   u'couple',
#   u'hour',
#   u'hottest',
#   u'time',
#   u'prompt',
#   u'reliable',
#   u'affordable',
#   u'hand',
#   u'experience',
#   u'hvac',
#   u'company',
#   u'date',
#   u'highly_recommend'],
#  [u'matt',
#   u'carlos',
#   u'aaron',
#   u'waterproofing',
#   u'basement',
#   u'extremely',
#   u'nice',
#   u'hard',
#   u'professional',
#   u'courtesy',
#   u'time',
#   u'answer_question',
#   u'beyond',
#   u'help',
#   u'recommend',
#   u'friend_family',
#   u'neighbor'],
#  [u'mike',
#   u'team',
#   u'incredible',
#   u'job',
#   u'amazed',
#   u'result',
#   u'impressed',
#   u'attention_detail',
#   u'recommend',
#   u'type'],
#  [u'professional', u'competent', u'staff', u'hard', u'perfect'],
#  [u'pumped', u'concrete', u'gate', u'city', u'va', u'crew', u'top_notch'],
#  [u'disaster',
#   u'bought',
#   u'brought',
#   u'life',
#   u'couldnt_happier',
#   u'service',
#   u'staff',
#   u'knowledge',
#   u'outcome',
#   u'highly_recommend'],
#  [u'posting',
#   u'review',
#   u'crew',
#   u'brandon',
#   u'palmer',
#   u'danny',
#   u'kelly',
#   u'recognition',
#   u'job',
#   u'prompt_courteous',
#   u'extremely',
#   u'hard',
#   u'professional',
#   u'starting',
#   u'repair',
#   u'double',
#   u'wide',
#   u'concrete',
#   u'driveway',
#   u'ran',
#   u'major',
#   u'diligently',
#   u'solve',
#   u'finish_job',
#   u'personal',
#   u'satisfaction',
#   u'customer_service',
#   u'beyond',
#   u'believe',
#   u'crewscompanies',
#   u'resolve',
#   u'confronted',
#   u'started',
#   u'repair',
#   u'nonstop',
#   u'solved',
#   u'job',
#   u'correctly',
#   u'commend',
#   u'excellent',
#   u'recommend',
#   u'foundation_recovery_system',
#   u'gentleman',
#   u'recognized',
#   u'hard',
#   u'nominated',
#   u'wow',
#   u'service',
#   u'award',
#   u'grand',
#   u'prize',
#   u'ill',
#   u'spreading',
#   u'word',
#   u'foundation_recovery_system',
#   u'meet',
#   u'benefit',
#   u'type',
#   u'service'],
#  [u'hired',
#   u'wetproof',
#   u'crawlspace',
#   u'35',
#   u'home',
#   u'constantly',
#   u'water',
#   u'collecting',
#   u'worker',
#   u'timely',
#   u'courteous',
#   u'knowledgeable',
#   u'task',
#   u'job'],
#  [u'humdity',
#   u'mountain',
#   u'home',
#   u'ronnie',
#   u'whitaker',
#   u'tar_heel',
#   u'basement',
#   u'solution',
#   u'super',
#   u'job',
#   u'fixed',
#   u'follow',
#   u'system',
#   u'recommended',
#   u'people',
#   u'answering',
#   u'phone',
#   u'office',
#   u'courteous'],
#  [u'professional', u'service', u'outstanding', u'result', u'hire'],
#  [u'professional', u'service', u'outstanding', u'result', u'hire'],
#  [u'excellent_service',
#   u'polite',
#   u'worker',
#   u'left',
#   u'driveway',
#   u'looking',
#   u'recommend',
#   u'driveway',
#   u'lifting'],
#  [u'pat', u'tyler', u'nick', u'crew'],
#  [u'itg',
#   u'stand',
#   u'guy',
#   u'unprofessional',
#   u'job',
#   u'begin',
#   u'salesman',
#   u'pushy',
#   u'worker',
#   u'unprepared',
#   u'didnt',
#   u'material',
#   u'pay',
#   u'extra',
#   u'moving',
#   u'condensation',
#   u'line',
#   u'ac_unit',
#   u'due',
#   u'worker',
#   u'moving',
#   u'sump_pump',
#   u'location',
#   u'didnt',
#   u'properly',
#   u'seal',
#   u'pvc',
#   u'pipe',
#   u'week',
#   u'sealed',
#   u'pipe',
#   u'water',
#   u'basement',
#   u'installed',
#   u'system',
#   u'accommodate',
#   u'footer',
#   u'basement',
#   u'final',
#   u'product',
#   u'look',
#   u'unprofessional',
#   u'paper',
#   u'water',
#   u'vapor',
#   u'barrier',
#   u'coming',
#   u'apart',
#   u'seam',
#   u'48',
#   u'hour',
#   u'company',
#   u'doesnt',
#   u'respond',
#   u'concern',
#   u'money',
#   u'ran',
#   u'worker',
#   u'dropped',
#   u'cement',
#   u'bag',
#   u'driveway',
#   u'burst',
#   u'bag',
#   u'cement',
#   u'spot',
#   u'driveway',
#   u'unplugged',
#   u'freezer',
#   u'basement',
#   u'spoiling',
#   u'lot',
#   u'food',
#   u'warned',
#   u'unplug',
#   u'freezer',
#   u'worker',
#   u'outlet',
#   u'unplug',
#   u'freezer',
#   u'avoid',
#   u'company',
#   u'cost',
#   u'unprofessional',
#   u'star',
#   u'filing',
#   u'complaint',
#   u'try',
#   u'concern',
#   u'resolved',
#   u'favor',
#   u'avoid',
#   u'itg'],
#  [u'experience', u'look', u'amazing', u'scott', u'job'],
#  [u'highly_recommend',
#   u'wood',
#   u'jeremy_kevin',
#   u'installed',
#   u'foundation',
#   u'system',
#   u'fantastic_job',
#   u'clean',
#   u'quick',
#   u'answer_question',
#   u'throughout_process',
#   u'personable',
#   u'thanks_guy'],
#  [u'pleased',
#   u'quality',
#   u'cantey_foundation',
#   u'product',
#   u'especially',
#   u'pleased',
#   u'customer_service',
#   u'trey',
#   u'crew',
#   u'recently',
#   u'repair',
#   u'couldnt',
#   u'courteous',
#   u'crew',
#   u'treated',
#   u'property',
#   u'left',
#   u'neat',
#   u'clean'],
#  [u'trey',
#   u'crew',
#   u'prompt',
#   u'professional',
#   u'hard',
#   u'recommend',
#   u'crew',
#   u'drainage',
#   u'home'],
#  [u'hired',
#   u'rod_martin',
#   u'install',
#   u'egress_window',
#   u'noted',
#   u'significantly',
#   u'expensive',
#   u'competitor',
#   u'told',
#   u'due',
#   u'quality',
#   u'organization',
#   u'scheduled',
#   u'july',
#   u'27th',
#   u'egress_window',
#   u'25th',
#   u'engineer',
#   u'look',
#   u'started',
#   u'changed',
#   u'workhome',
#   u'schedule',
#   u'26th',
#   u'engineer',
#   u'scheduled',
#   u'8',
#   u'9',
#   u'27th',
#   u'wife',
#   u'waited',
#   u'home',
#   u'day',
#   u'promised',
#   u'soon',
#   u'arrived',
#   u'510',
#   u'pm',
#   u'company',
#   u'6',
#   u'pm',
#   u'send',
#   u'home',
#   u'rescheduled',
#   u'august',
#   u'7th',
#   u'dug',
#   u'huge',
#   u'hole',
#   u'window',
#   u'exposed',
#   u'foundation',
#   u'egress',
#   u'week',
#   u'ago',
#   u'heavy_rain',
#   u'minimum',
#   u'week',
#   u'schedule',
#   u'complete',
#   u'lose',
#   u'deposit',
#   u'hire',
#   u'else',
#   u'save',
#   u'project',
#   u'confidence',
#   u'unprofessional',
#   u'job',
#   u'rod_martin',
#   u'rarely',
#   u'write_review',
#   u'people',
#   u'cite',
#   u'rating',
#   u'throughout',
#   u'entire',
#   u'sale',
#   u'process'],
#  [u'absolute',
#   u'fraud',
#   u'week',
#   u'installation',
#   u'sump',
#   u'called',
#   u'customer_service',
#   u'informed',
#   u'week',
#   u'fix',
#   u'basement',
#   u'flooding',
#   u'steer',
#   u'fraudulent',
#   u'company'],
#  [u'learned',
#   u'owner',
#   u'helped',
#   u'company',
#   u'life',
#   u'believe',
#   u'intention',
#   u'construction',
#   u'business',
#   u'mistake',
#   u'care',
#   u'customer',
#   u'giving',
#   u'personal',
#   u'opportunity',
#   u'heartbeat'],
#  [u'brad',
#   u'personable',
#   u'funny',
#   u'knowledgeable',
#   u'hvac',
#   u'time_explain',
#   u'process',
#   u'wife',
#   u'thanks',
#   u'brad'],
#  [u'john',
#   u'donnie',
#   u'job',
#   u'repairing',
#   u'damage',
#   u'basement',
#   u'wall',
#   u'arrived_time',
#   u'excellent_job',
#   u'repair',
#   u'cleaned_nicely',
#   u'afterwards'],
#  [u'service',
#   u'performed',
#   u'technician',
#   u'bill',
#   u'hammer',
#   u'badger_basement',
#   u'system',
#   u'efficient',
#   u'time_explain'],
#  [u'amazing',
#   u'funny',
#   u'polite',
#   u'inform',
#   u'service',
#   u'team',
#   u'installation',
#   u'trained',
#   u'knowledgeable',
#   u'job',
#   u'topof',
#   u'line',
#   u'product'],
#  [u'impressed',
#   u'method',
#   u'company',
#   u'compared',
#   u'proposed',
#   u'contractor',
#   u'nasty',
#   u'crawlspace',
#   u'nicer',
#   u'basement'],
#  [u'jeremy_kevin',
#   u'job',
#   u'basement',
#   u'extra',
#   u'beyond',
#   u'help',
#   u'move',
#   u'job_cleaning',
#   u'left',
#   u'thank',
#   u'wood_basement_system'],
#  [u'jose',
#   u'lorenzana',
#   u'professional',
#   u'crew',
#   u'malik',
#   u'caesar',
#   u'installed',
#   u'drain',
#   u'channel',
#   u'sump_pump',
#   u'repaired',
#   u'vent',
#   u'hole',
#   u'concrete',
#   u'wall',
#   u'prompt_courteous',
#   u'communicative',
#   u'job',
#   u'excellent',
#   u'cleanup',
#   u'thank',
#   u'job'],
#  [u'overly',
#   u'aggressive',
#   u'sale',
#   u'tactic',
#   u'called',
#   u'estimate',
#   u'told',
#   u'unable',
#   u'phone',
#   u'person',
#   u'understand',
#   u'explained',
#   u'lady',
#   u'death',
#   u'family',
#   u'tied',
#   u'time',
#   u'persistent',
#   u'schedule',
#   u'appt',
#   u'saying',
#   u'doesnt',
#   u'cancel',
#   u'pushed',
#   u'scheduled',
#   u'appt',
#   u'reminder',
#   u'call',
#   u'day',
#   u'cancelled',
#   u'appt',
#   u'aggressive',
#   u'called',
#   u'person',
#   u'estimate',
#   u'trying',
#   u'meet',
#   u'called',
#   u'people',
#   u'office',
#   u'day',
#   u'trying',
#   u'reschedule',
#   u'appt',
#   u'told',
#   u'dealing',
#   u'death',
#   u'family',
#   u'time',
#   u'continue',
#   u'calling',
#   u'pressuring',
#   u'told',
#   u'time',
#   u'stop',
#   u'reported',
#   u'reading',
#   u'review',
#   u'believe',
#   u'shame',
#   u'customer_service',
#   u'skill',
#   u'bad',
#   u'pushed',
#   u'appt',
#   u'simply',
#   u'cancelled',
#   u'calm',
#   u'loss',
#   u'family',
#   u'experienced',
#   u'ready',
#   u'estimate',
#   u'people',
#   u'id',
#   u'call'],
#  [u'employee',
#   u'name',
#   u'brandon',
#   u'fired',
#   u'he',
#   u'unprofessional',
#   u'rude',
#   u'potential',
#   u'customer'],
#  [u'crook',
#   u'charged',
#   u'336',
#   u'snake',
#   u'toilet',
#   u'price',
#   u'gauge',
#   u'based',
#   u'town',
#   u'size',
#   u'house'],
#  [u'performed',
#   u'2014',
#   u'raise',
#   u'floor',
#   u'710000',
#   u'original',
#   u'salesman',
#   u'quoted',
#   u'fired',
#   u'stealing',
#   u'deposit',
#   u'install',
#   u'wrong',
#   u'material',
#   u'equipment',
#   u'told',
#   u'leave',
#   u'apparently',
#   u'fired',
#   u'shortly',
#   u'horrible',
#   u'installs',
#   u'trying',
#   u'steal',
#   u'none',
#   u'original',
#   u'drawing',
#   u'original',
#   u'issue',
#   u'remains',
#   u'3',
#   u'initial',
#   u'completion',
#   u'2',
#   u'jack',
#   u'werent',
#   u'supporting',
#   u'load',
#   u'simply',
#   u'knocked',
#   u'hand',
#   u'jack',
#   u'laying',
#   u'installers',
#   u'hand',
#   u'looking',
#   u'payment',
#   u'3',
#   u'numerous',
#   u'chance',
#   u'company',
#   u'sporadically',
#   u'send',
#   u'crew',
#   u'clue',
#   u'issue',
#   u'fix',
#   u'claim',
#   u'office',
#   u'didnt',
#   u'real',
#   u'information',
#   u'material',
#   u'tool',
#   u'nothing',
#   u'talk',
#   u'poorly',
#   u'company',
#   u'owner',
#   u'tried',
#   u'chance',
#   u'tried',
#   u'address',
#   u'23',
#   u'drop',
#   u'house',
#   u'1',
#   u'main',
#   u'reason',
#   u'contacted',
#   u'company',
#   u'begin',
#   u'fixing',
#   u'tell',
#   u'pay',
#   u'240000',
#   u'fix',
#   u'addressed',
#   u'extremely',
#   u'poor',
#   u'experience',
#   u'overall',
#   u'seek',
#   u'legal',
#   u'remedy',
#   u'claim',
#   u'court',
#   u'file',
#   u'suit',
#   u'stay',
#   u'contract',
#   u'pay',
#   u'3rd',
#   u'party',
#   u'inspect',
#   u'sign',
#   u'complete',
#   u'scope',
#   u'quoted'],
#  [u'company', u'dishonest', u'company', u'money', u'terrible', u'experience'],
#  [u'jeremy',
#   u'helper',
#   u'professional',
#   u'explained',
#   u'anchor',
#   u'wall',
#   u'yard',
#   u'plate',
#   u'ground'],
#  [u'basement_system_usa',
#   u'egress_window',
#   u'basement',
#   u'space',
#   u'bedroom',
#   u'step',
#   u'process',
#   u'pleasure',
#   u'contacted',
#   u'5',
#   u'company',
#   u'basement_system_usa',
#   u'sent',
#   u'sale_person',
#   u'look',
#   u'job',
#   u'giving',
#   u'quote',
#   u'setting',
#   u'financing',
#   u'scheduling',
#   u'job',
#   u'basement_system_usa',
#   u'sent',
#   u'crew',
#   u'led',
#   u'foreman',
#   u'named',
#   u'esteban',
#   u'crew',
#   u'inside_outside',
#   u'home',
#   u'home',
#   u'crew',
#   u'extremely',
#   u'professional',
#   u'left',
#   u'nothing',
#   u'inside',
#   u'home',
#   u'left',
#   u'noise',
#   u'couldnt',
#   u'tell',
#   u'recommend_company',
#   u'crew',
#   u'looking',
#   u'home'],
#  [u'bad', u'attitude'],
#  [u'giving',
#   u'process',
#   u'didnt',
#   u'smoothly',
#   u'hoped',
#   u'call',
#   u'mistake',
#   u'created',
#   u'ongoing',
#   u'thank',
#   u'basement_authority'],
#  [u'jacob',
#   u'crew',
#   u'job',
#   u'lifting',
#   u'front_porch',
#   u'job',
#   u'hour',
#   u'half',
#   u'attitude',
#   u'highly_recommend',
#   u'service'],
#  [u'jeremy_kevin', u'christoph', u'excellent', u'step', u'project'],
#  [u'afs',
#   u'provided',
#   u'professional',
#   u'sale',
#   u'service',
#   u'poly_level',
#   u'option',
#   u'lift',
#   u'stabilize',
#   u'garage_floor',
#   u'fallen',
#   u'five',
#   u'inch',
#   u'corner',
#   u'original',
#   u'technician',
#   u'run',
#   u'issue',
#   u'job',
#   u'enlisted',
#   u'help',
#   u'superior',
#   u'regrouped',
#   u'evaluated',
#   u'sent',
#   u'reinforcement',
#   u'successful',
#   u'raising',
#   u'slab',
#   u'advertised',
#   u'expectation',
#   u'met',
#   u'job',
#   u'completed',
#   u'afs',
#   u'highly_recommended',
#   u'comfortable',
#   u'referring',
#   u'friend_family',
#   u'service',
#   u'offer',
#   u'please',
#   u'dramatic',
#   u'picture',
#   u'situation',
#   u'special',
#   u'thank',
#   u'michael',
#   u'regan',
#   u'special',
#   u'attention',
#   u'unique',
#   u'situation'],
#  [u'friendly',
#   u'staff',
#   u'professional',
#   u'knowledgeable',
#   u'family',
#   u'owned'],
#  [u'crew',
#   u'amazing',
#   u'hard',
#   u'knowledgeable',
#   u'permanently',
#   u'fixed',
#   u'home',
#   u'piece',
#   u'mind'],
#  [u'wife',
#   u'preparing',
#   u'sell',
#   u'home',
#   u'leaky',
#   u'foundation',
#   u'finished',
#   u'basement',
#   u'thankfully',
#   u'scott_wilson',
#   u'afs',
#   u'crew',
#   u'quickly',
#   u'fixed',
#   u'warranty',
#   u'homeowner',
#   u'piece',
#   u'mind',
#   u'price',
#   u'offer',
#   u'thanks',
#   u'afs'],
#  [u'pipe',
#   u'fix',
#   u'central',
#   u'ac_unit',
#   u'tech',
#   u'diagnose',
#   u'immediately',
#   u'ready',
#   u'couple',
#   u'hour',
#   u'help',
#   u'front',
#   u'office',
#   u'consistently',
#   u'communicating',
#   u'job',
#   u'complete',
#   u'following',
#   u'finished',
#   u'prompt',
#   u'fixing',
#   u'unit',
#   u'24',
#   u'hour',
#   u'initially',
#   u'called'],
#  [u'left',
#   u'basement',
#   u'total',
#   u'mess',
#   u'looked',
#   u'worse',
#   u'sewer',
#   u'overflowed',
#   u'concrete',
#   u'dust',
#   u'repeated',
#   u'request',
#   u'clean',
#   u'met',
#   u'promise',
#   u'promise',
#   u'perform',
#   u'finally',
#   u'sent',
#   u'guy',
#   u'wet',
#   u'floor',
#   u'left',
#   u'10',
#   u'minute',
#   u'promise',
#   u'empty',
#   u'left_clean',
#   u'mess',
#   u'definitely_recommend'],
#  [u'disappointed',
#   u'told',
#   u'unit',
#   u'replacing',
#   u'1400',
#   u'blower',
#   u'motor',
#   u'replacement',
#   u'opinion',
#   u'faulty',
#   u'loose',
#   u'ductwork',
#   u'6000',
#   u'200',
#   u'math',
#   u'third',
#   u'opinion',
#   u'company'],
#  [u'appreciate',
#   u'extremely',
#   u'busy',
#   u'due',
#   u'heavy_rain',
#   u'spring',
#   u'summer',
#   u'waiting',
#   u'6',
#   u'week',
#   u'look',
#   u'home',
#   u'absolutely',
#   u'subsequent',
#   u'follow',
#   u'quote',
#   u'phone_call',
#   u'returned',
#   u'email',
#   u'edit',
#   u'glad',
#   u'eventually',
#   u'hear',
#   u'obviously',
#   u'miscommunication',
#   u'time',
#   u'reached',
#   u'found',
#   u'basement',
#   u'waterproofing',
#   u'solution'],
#  [u'pat', u'ricki'],
#  [u'frank',
#   u'giuditta',
#   u'service_technician',
#   u'he',
#   u'professional',
#   u'feel_confident',
#   u'provides',
#   u'advice',
#   u'thorough',
#   u'notifies',
#   u'eta',
#   u'stay',
#   u'job',
#   u'completed',
#   u'glad',
#   u'recommend',
#   u'business',
#   u'knowing',
#   u'provided',
#   u'service'],
#  [u'truly',
#   u'expert',
#   u'industry',
#   u'provided',
#   u'25',
#   u'warranty',
#   u'experience',
#   u'contractor'],
#  [u'water',
#   u'table',
#   u'little',
#   u'gallon',
#   u'come',
#   u'sump_pump',
#   u'5_minute',
#   u'battery',
#   u'installed',
#   u'past',
#   u'fall',
#   u'9',
#   u'month',
#   u'ago',
#   u'told',
#   u'installers',
#   u'wed',
#   u'alarm',
#   u'battery_backup',
#   u'power',
#   u'outage',
#   u'sound',
#   u'light',
#   u'sump_pump',
#   u'activated',
#   u'entirety',
#   u'hour',
#   u'power',
#   u'instead',
#   u'piece',
#   u'mind',
#   u'3',
#   u'battery',
#   u'worried',
#   u'sump',
#   u'pit',
#   u'overflow',
#   u'called',
#   u'rod_martin',
#   u'technician',
#   u'phone',
#   u'michael',
#   u'alarm',
#   u'sound',
#   u'floater',
#   u'hit',
#   u'level',
#   u'diagnose',
#   u'battery',
#   u'actually',
#   u'pay',
#   u'service',
#   u'charge',
#   u'120',
#   u'id',
#   u'expect',
#   u'service',
#   u'sump_pump',
#   u'battery',
#   u'technician',
#   u'didnt',
#   u'leave',
#   u'manual',
#   u'time',
#   u'install',
#   u'ive',
#   u'actually',
#   u'call',
#   u'info',
#   u'instead',
#   u'informed',
#   u'paying',
#   u'customer',
#   u'peace_mind',
#   u'update',
#   u'contacted',
#   u'day',
#   u'called',
#   u'travis',
#   u'manager',
#   u'trying',
#   u'complimentary',
#   u'diagnosis',
#   u'soonest',
#   u'week',
#   u'update',
#   u'week',
#   u'final',
#   u'update',
#   u'technician',
#   u'sump',
#   u'pit',
#   u'floater',
#   u'explained',
#   u'regarding',
#   u'battery_backup',
#   u'satisfaction',
#   u'answered_question',
#   u'peace_mind',
#   u'restored'],
#  [u'contacted',
#   u'guy',
#   u'2',
#   u'time',
#   u'time',
#   u'fill',
#   u'hvac',
#   u'unit',
#   u'freon',
#   u'charged',
#   u'555',
#   u'quick',
#   u'fee',
#   u'idea',
#   u'quick',
#   u'fee',
#   u'explanation',
#   u'time',
#   u'called',
#   u'month',
#   u'told',
#   u'electrical',
#   u'unit',
#   u'sent',
#   u'person',
#   u'told',
#   u'electrical',
#   u'unit',
#   u'receive',
#   u'99',
#   u'diagnoistics',
#   u'fee',
#   u'told',
#   u'diagnosed',
#   u'electrical',
#   u'called',
#   u'guy',
#   u'solve',
#   u'wallet'],
#  [u'crawlspace',
#   u'repaired',
#   u'72017',
#   u'past',
#   u'dealt',
#   u'stressed',
#   u'water',
#   u'moisture',
#   u'crawlspace',
#   u'initial_contact',
#   u'office_staff',
#   u'request',
#   u'quote',
#   u'submitted',
#   u'meeting',
#   u'corey',
#   u'discussing',
#   u'concern',
#   u'scope',
#   u'potential',
#   u'project',
#   u'receiving',
#   u'freenopressure',
#   u'estimate',
#   u'signing',
#   u'completed',
#   u'project',
#   u'tim',
#   u'crew',
#   u'throughout',
#   u'day',
#   u'extreme',
#   u'heat',
#   u'couldnt',
#   u'satisfied',
#   u'process',
#   u'streamlined',
#   u'day',
#   u'project',
#   u'except',
#   u'truck',
#   u'parked',
#   u'house',
#   u'continuously',
#   u'throughout',
#   u'entire',
#   u'day',
#   u'happy',
#   u'answer_question',
#   u'signing',
#   u'project',
#   u'peace_mind',
#   u'explained',
#   u'satisfied',
#   u'couldnt_pleased',
#   u'start_finish',
#   u'thank',
#   u'northland',
#   u'basement_system'],
#  [u'entire',
#   u'home',
#   u'insulated',
#   u'short',
#   u'day',
#   u'price',
#   u'energy',
#   u'bill',
#   u'lower',
#   u'couldve',
#   u'imagined',
#   u'definitely',
#   u'people'],
#  [u'gatlin',
#   u'beyond',
#   u'call',
#   u'duty',
#   u'servicing',
#   u'house',
#   u'spent',
#   u'day',
#   u'house',
#   u'addressing',
#   u'unforeseen',
#   u'issue',
#   u'pouring',
#   u'rain',
#   u'time',
#   u'gatlin',
#   u'company'],
#  [u'experience',
#   u'standard',
#   u'specifically',
#   u'technician',
#   u'dewayne',
#   u'franklin',
#   u'beyond',
#   u'ac_unit',
#   u'running',
#   u'correctly',
#   u'grateful',
#   u'hard',
#   u'keeping',
#   u'cool',
#   u'hot',
#   u'summer',
#   u'month',
#   u'thank'],
#  [u'amazing', u'professional'],
#  [u'thanks', u'jamie', u'matt', u'job'],
#  [u'tre', u'crew', u'customer_service', u'skill', u'idea', u'project'],
#  [u'dallas',
#   u'team',
#   u'time',
#   u'explained_detail',
#   u'job',
#   u'perform',
#   u'tirelessly',
#   u'job',
#   u'complete',
#   u'looked',
#   u'finished',
#   u'started',
#   u'gone',
#   u'happy_result'],
#  [u'met',
#   u'jamie',
#   u'beresford',
#   u'estimate',
#   u'total',
#   u'professional',
#   u'crawl_space',
#   u'sealed',
#   u'looking_forward',
#   u'result',
#   u'experience'],
#  [u'experience',
#   u'cantey_foundation',
#   u'specialist',
#   u'initial',
#   u'proposal',
#   u'completion',
#   u'informative',
#   u'professional_manner',
#   u'thank',
#   u'sixto',
#   u'lopez',
#   u'crew',
#   u'timely_manner',
#   u'job',
#   u'completed',
#   u'space',
#   u'left_clean',
#   u'started',
#   u'definitely_recommend',
#   u'cantey'],
#  [u'response',
#   u'company',
#   u'response',
#   u'hmm',
#   u'ive',
#   u'company',
#   u'wow',
#   u'lol',
#   u'youve',
#   u'employee',
#   u'feel',
#   u'surprised',
#   u'feel',
#   u'bad',
#   u'momica',
#   u'probably',
#   u'trying',
#   u'save',
#   u'job',
#   u'brainwashed',
#   u'worry',
#   u'service',
#   u'company',
#   u'treat',
#   u'individual',
#   u'adios',
#   u'day',
#   u'racist',
#   u'company',
#   u'potential',
#   u'customer',
#   u'remember',
#   u'week',
#   u'ago',
#   u'company',
#   u'racist',
#   u'remember',
#   u'hearing',
#   u'designer',
#   u'inappropriate',
#   u'joke',
#   u'black',
#   u'mocking',
#   u'black',
#   u'culture',
#   u'ethnic',
#   u'puerto',
#   u'rican',
#   u'dominican',
#   u'offensive',
#   u'heard',
#   u'caucasian',
#   u'employee',
#   u'office',
#   u'call',
#   u'appeared',
#   u'african',
#   u'american',
#   u'momica',
#   u'willingly',
#   u'sadly',
#   u'catered',
#   u'waited',
#   u'hand',
#   u'foot',
#   u'shocked',
#   u'called',
#   u'guessing',
#   u'name',
#   u'monica',
#   u'african',
#   u'american',
#   u'especially',
#   u'position',
#   u'degraded',
#   u'racist',
#   u'coworkers',
#   u'employee',
#   u'unprofessionally',
#   u'person',
#   u'black',
#   u'mama',
#   u'white',
#   u'aka',
#   u'mammy',
#   u'type',
#   u'nickname',
#   u'ridiculous',
#   u'day',
#   u'age',
#   u'especially',
#   u'predominantly',
#   u'white',
#   u'environment',
#   u'employee',
#   u'office',
#   u'call',
#   u'ridiculous',
#   u'call',
#   u'woman',
#   u'name',
#   u'deserves',
#   u'else',
#   u'funny',
#   u'degraded',
#   u'probably',
#   u'feel',
#   u'accept',
#   u'treatment',
#   u'reason',
#   u'people',
#   u'employee',
#   u'company',
#   u'view',
#   u'treat',
#   u'african',
#   u'american',
#   u'sly',
#   u'professional',
#   u'separating',
#   u'personal',
#   u'feeling',
#   u'yes',
#   u'non',
#   u'white',
#   u'help',
#   u'business',
#   u'customer',
#   u'people',
#   u'starting',
#   u'company',
#   u'change',
#   u'inappropriate',
#   u'ignorant',
#   u'unprofessional',
#   u'deserves',
#   u'treated',
#   u'disrespect',
#   u'hearing',
#   u'friend',
#   u'company',
#   u'hostile',
#   u'attitude',
#   u'employee',
#   u'apparent',
#   u'reasonwhen',
#   u'question',
#   u'regarding',
#   u'basement',
#   u'dime',
#   u'racist',
#   u'company',
#   u'wish',
#   u'0',
#   u'star',
#   u'shocked',
#   u'rating',
#   u'customer',
#   u'caucasian',
#   u'treated',
#   u'non',
#   u'white',
#   u'customer',
#   u'sense',
#   u'friend',
#   u'racist',
#   u'paid',
#   u'bbb',
#   u'grade',
#   u'continue',
#   u'treating',
#   u'people',
#   u'horrible'],
#  [u'felipe_crew',
#   u'job_installing',
#   u'crawl_space',
#   u'sump_pump',
#   u'quick',
#   u'efficient',
#   u'clean'],
#  [u'repair', u'team', u'professional', u'concrete', u'level'],
#  [u'luis',
#   u'perez',
#   u'team',
#   u'professional',
#   u'efficient',
#   u'quickly',
#   u'job',
#   u'matter',
#   u'hour',
#   u'considerate',
#   u'home',
#   u'intrusive',
#   u'leave',
#   u'found',
#   u'gained',
#   u'fantastic',
#   u'space',
#   u'storage',
#   u'added',
#   u'value',
#   u'home'],
#  [u'installation',
#   u'crew',
#   u'time',
#   u'quick',
#   u'efficient',
#   u'time',
#   u'product',
#   u'performed',
#   u'advertised',
#   u'post',
#   u'installation',
#   u'detailing',
#   u'clean',
#   u'superb'],
#  [u'installers',
#   u'hard',
#   u'completed',
#   u'job',
#   u'expected',
#   u'malik',
#   u'cesare',
#   u'jose',
#   u'exceptional',
#   u'highly_recommended'],
#  [u'absolutely',
#   u'company',
#   u'hvac',
#   u'plumbing',
#   u'birmingham',
#   u'dealing',
#   u'2',
#   u'plumbing',
#   u'company',
#   u'getting',
#   u'run',
#   u'7',
#   u'day',
#   u'called',
#   u'standard',
#   u'2',
#   u'day',
#   u'randy',
#   u'team',
#   u'fixed',
#   u'water',
#   u'leak',
#   u'concealed',
#   u'hvac',
#   u'trunk',
#   u'line',
#   u'hour',
#   u'professional_courteous',
#   u'job',
#   u'highly_recommend',
#   u'future',
#   u'hvac',
#   u'plumbing'],
#  [u'hard',
#   u'team',
#   u'finished',
#   u'basement',
#   u'day',
#   u'courteous',
#   u'professional',
#   u'glad',
#   u'basement_system'],
#  [u'business',
#   u'employ',
#   u'folk',
#   u'disrespect',
#   u'american',
#   u'astronaut',
#   u'online',
#   u'matthew',
#   u'robinson',
#   u'like',
#   u'argue',
#   u'folk',
#   u'online',
#   u'satellite',
#   u'existing',
#   u'like',
#   u'challenger',
#   u'astronaut',
#   u'death',
#   u'lie',
#   u'employing',
#   u'disrespectful',
#   u'jerk',
#   u'shouldnt',
#   u'proudly',
#   u'display',
#   u'engaging',
#   u'post',
#   u'consequence',
#   u'post',
#   u'online',
#   u'lowering',
#   u'brand',
#   u'employ',
#   u'jerk',
#   u'recourse',
#   u'business',
#   u'establishment',
#   u'employ',
#   u'degenerate',
#   u'jerk'],
#  [u'customer_service',
#   u'folk',
#   u'awesome',
#   u'install',
#   u'backup',
#   u'system',
#   u'house',
#   u'polite',
#   u'efficient',
#   u'gone',
#   u'time',
#   u'crazy',
#   u'rain',
#   u'system',
#   u'beeping',
#   u'matt',
#   u'drove',
#   u'immediately',
#   u'look',
#   u'incredibly',
#   u'polite',
#   u'professional',
#   u'folk',
#   u'earned',
#   u'business',
#   u'forward'],
#  [u'guy',
#   u'cut',
#   u'wonderful_job',
#   u'house',
#   u'line',
#   u'street',
#   u'replaced',
#   u'sump_pump',
#   u'installed',
#   u'day',
#   u'line',
#   u'mess',
#   u'combination',
#   u'steel',
#   u'concrete',
#   u'pvc',
#   u'dug',
#   u'sense',
#   u'wonderful_job',
#   u'respectful',
#   u'plant',
#   u'house',
#   u'noise',
#   u'toddler',
#   u'sleeping',
#   u'easy',
#   u'feat',
#   u'estimating',
#   u'time',
#   u'project',
#   u'2',
#   u'day',
#   u'replanted',
#   u'grass',
#   u'seed',
#   u'charm',
#   u'wonderful_job'],
#  [u'wow',
#   u'amazing',
#   u'job',
#   u'alex',
#   u'pacheco',
#   u'donnie',
#   u'rod_martin',
#   u'impressed',
#   u'professionalism',
#   u'extremely',
#   u'quality',
#   u'comprehensive',
#   u'job',
#   u'beyond',
#   u'happy'],
#  [u'left', u'system', u'maintenance', u'battery', u'replace', u'else'],
#  [u'thank',
#   u'level',
#   u'professionalism',
#   u'throughout_process',
#   u'installation',
#   u'support',
#   u'home',
#   u'individual',
#   u'contact',
#   u'demonstrated',
#   u'excellence',
#   u'customer_service',
#   u'installers',
#   u'juan',
#   u'jonathan',
#   u'austin',
#   u'arrived',
#   u'indicated',
#   u'completed',
#   u'skill',
#   u'thank'],
#  [u'ive',
#   u'read',
#   u'review',
#   u'cantey_foundation',
#   u'specialist',
#   u'added',
#   u'company',
#   u'interviewed',
#   u'dry',
#   u'crawlspace',
#   u'meeting',
#   u'jason',
#   u'hugg',
#   u'inspection',
#   u'consultation',
#   u'quote',
#   u'proceeded',
#   u'choose',
#   u'cantey_foundation',
#   u'perform',
#   u'confident',
#   u'job',
#   u'knowledgeable',
#   u'issue',
#   u'experiencing'],
#  [u'rod_martin',
#   u'job',
#   u'month',
#   u'stabilized',
#   u'250',
#   u'foot',
#   u'retaining',
#   u'wall',
#   u'raised',
#   u'residence',
#   u'total',
#   u'3',
#   u'structural',
#   u'damage',
#   u'extremely',
#   u'happy',
#   u'rod_martin',
#   u'people',
#   u'exceptional',
#   u'jack',
#   u'beagle',
#   u'system',
#   u'design',
#   u'specialist',
#   u'day',
#   u'assessed',
#   u'quoted',
#   u'job',
#   u'location',
#   u'time',
#   u'issue',
#   u'addressed',
#   u'jack',
#   u'addressed',
#   u'immediately',
#   u'start',
#   u'project',
#   u'jack',
#   u'touch',
#   u'installation',
#   u'crew',
#   u'jack',
#   u'excellent_job',
#   u'installation',
#   u'foreman',
#   u'rogelio',
#   u'gasper',
#   u'roge',
#   u'exceptional',
#   u'extremely',
#   u'hard',
#   u'kept',
#   u'updated',
#   u'crew',
#   u'schedule',
#   u'roge',
#   u'hand',
#   u'foreman',
#   u'run',
#   u'crew',
#   u'physical',
#   u'labor',
#   u'site',
#   u'helper',
#   u'jesus',
#   u'excellent',
#   u'worker',
#   u'ran',
#   u'excavator',
#   u'skill',
#   u'roge',
#   u'installation',
#   u'crew',
#   u'exactly',
#   u'cleaned',
#   u'site',
#   u'happy',
#   u'roge',
#   u'definitely_recommend',
#   u'rod_martin_complete_basement',
#   u'system',
#   u'reputable',
#   u'capable',
#   u'business',
#   u'quality',
#   u'day',
#   u'age',
#   u'excellent_service',
#   u'provide',
#   u'ordinary',
#   u'similar',
#   u'definitely',
#   u'chose',
#   u'perry'],
#  [u'frank',
#   u'service',
#   u'comprehensive',
#   u'doublesump',
#   u'system',
#   u'french_drain',
#   u'home',
#   u'patient',
#   u'real',
#   u'problemsolver',
#   u'system',
#   u'continues'],
#  [u'frank',
#   u'giuditta',
#   u'yearly',
#   u'maintenance',
#   u'system',
#   u'knowledgeable',
#   u'professional',
#   u'team',
#   u'question_concern',
#   u'system',
#   u'frank',
#   u'time',
#   u'answer',
#   u'explain',
#   u'issue',
#   u'brought',
#   u'thorough',
#   u'explanation',
#   u'idea',
#   u'obvious',
#   u'experience',
#   u'confidence',
#   u'thankyou',
#   u'frank',
#   u'help',
#   u'youre',
#   u'asset',
#   u'company',
#   u'karen',
#   u'bruno'],
#  [u'aubrey',
#   u'oscar',
#   u'frank',
#   u'house',
#   u'support',
#   u'beam',
#   u'3',
#   u'jack',
#   u'fix',
#   u'sagging',
#   u'floor',
#   u'prompt',
#   u'product',
#   u'walked',
#   u'process',
#   u'professional'],
#  [u'relied',
#   u'scott_wilson',
#   u'team',
#   u'afs',
#   u'insured',
#   u'home',
#   u'foundation',
#   u'numerious',
#   u'deliver',
#   u'fast',
#   u'competant',
#   u'afrodable',
#   u'service',
#   u'customer',
#   u'john',
#   u'turner',
#   u'owner',
#   u'turnner',
#   u'insurance',
#   u'agnecy'],
#  [u'happy',
#   u'job',
#   u'moreover',
#   u'impressed',
#   u'customer_service',
#   u'lady',
#   u'phone',
#   u'appointment',
#   u'jason',
#   u'explained',
#   u'procedure',
#   u'answered_question',
#   u'technician',
#   u'courteous',
#   u'professional',
#   u'experience',
#   u'company'],
#  [u'pipework',
#   u'responsive',
#   u'quick',
#   u'answer',
#   u'request',
#   u'emergency',
#   u'saturday',
#   u'technical',
#   u'home',
#   u'hour',
#   u'call',
#   u'call',
#   u'6a',
#   u'product',
#   u'insanely',
#   u'overpriced',
#   u'quoted',
#   u'nearly',
#   u'6k',
#   u'replace',
#   u'water',
#   u'heater',
#   u'vendor',
#   u'quoted',
#   u'fraction',
#   u'cost',
#   u'power',
#   u'vent',
#   u'found',
#   u'professional',
#   u'managed',
#   u'permitting',
#   u'process',
#   u'township',
#   u'unfortunatly',
#   u'cost',
#   u'99',
#   u'plus',
#   u'tax',
#   u'overpriced',
#   u'quote',
#   u'unfortunatly',
#   u'couldnt',
#   u'recommend',
#   u'based',
#   u'experience'],
#  [u'jose', u'crew', u'wonderful_job', u'explained', u'completely_satisfied'],
#  [u'wood',
#   u'waterproof',
#   u'34',
#   u'basement',
#   u'2010',
#   u'beautifully',
#   u'kind',
#   u'weather',
#   u'experienced',
#   u'flooding',
#   u'stayed',
#   u'dry',
#   u'except',
#   u'failed',
#   u'waterproof',
#   u'juan',
#   u'anthony',
#   u'professional',
#   u'guy',
#   u'prompt',
#   u'nice',
#   u'job',
#   u'94',
#   u'plus',
#   u'degree',
#   u'cleaned_nicely',
#   u'finished',
#   u'juan',
#   u'explained',
#   u'question_concern',
#   u'experience',
#   u'beginning',
#   u'thank',
#   u'wood_basement_system',
#   u'juan',
#   u'anthony'],
#  [u'basement',
#   u'completely',
#   u'waterproofed',
#   u'finished',
#   u'ago',
#   u'basement_system',
#   u'replace',
#   u'dehumidifier',
#   u'reached',
#   u'life',
#   u'ahead',
#   u'scheduled',
#   u'day',
#   u'additional',
#   u'duct',
#   u'service_technician',
#   u'frank',
#   u'tool',
#   u'material',
#   u'frank',
#   u'arranged',
#   u'schedule',
#   u'especially',
#   u'fit',
#   u'following',
#   u'friday',
#   u'install',
#   u'dehumidifier',
#   u'complete',
#   u'annual',
#   u'servicecheck',
#   u'waterproofing',
#   u'system',
#   u'friday',
#   u'frank',
#   u'called',
#   u'time',
#   u'progress',
#   u'eta',
#   u'finally',
#   u'arrived',
#   u'530',
#   u'stayed',
#   u'830',
#   u'completing',
#   u'job',
#   u'ok',
#   u'leaving',
#   u'wrong',
#   u'matter',
#   u'deal',
#   u'frank',
#   u'talking',
#   u'attitude',
#   u'professionalism',
#   u'definitely',
#   u'beyond',
#   u'thanks',
#   u'frank',
#   u'ne',
#   u'basement_system',
#   u'call'],
#  [u'northland',
#   u'crew',
#   u'fine',
#   u'job_installing',
#   u'basement',
#   u'drainage_system',
#   u'arrived',
#   u'specified',
#   u'time',
#   u'thru',
#   u'dayto',
#   u'complete',
#   u'project',
#   u'single',
#   u'day',
#   u'fine',
#   u'job_cleaning',
#   u'finish',
#   u'project',
#   u'guy',
#   u'pleasant',
#   u'knowledgeable',
#   u'answered_question'],
#  [u'assessment',
#   u'installation',
#   u'job',
#   u'explanation',
#   u'phase',
#   u'job',
#   u'crew',
#   u'supervisor',
#   u'outstanding_job',
#   u'representing',
#   u'company',
#   u'value'],
#  [u'emailed', u'phoned', u'responsequote'],
#  [u'sam',
#   u'home',
#   u'ass',
#   u'damage',
#   u'provide',
#   u'written',
#   u'estimate',
#   u'punctual',
#   u'knowledgeable',
#   u'courteous',
#   u'impressed',
#   u'company'],
#  [u'bought_house',
#   u'ago',
#   u'money',
#   u'insulate',
#   u'attic',
#   u'looked',
#   u'company',
#   u'week',
#   u'internet',
#   u'3',
#   u'company',
#   u'called',
#   u'estimate',
#   u'late',
#   u'appointment',
#   u'he',
#   u'crossed',
#   u'list',
#   u'leaf',
#   u'booth',
#   u'company',
#   u'knowledgable',
#   u'mike',
#   u'home_environment_solution',
# ...
#   u'extremely',
#   u'limited',
#   u'income',
#   u'product',
#   u'halco',
#   u'forth',
#   u'exactly',
#   u'paying',
#   u'customer',
#   u'received',
#   u'thats',
#   u'call',
#   u'ethic',
#   u'moral',
#   u'grateful',
#   u'empire',
#   u'york',
#   u'despite',
#   u'poor'],
#  [u'gsm',
#   u'probably',
#   u'cheapest',
#   u'worth',
#   u'money',
#   u'maintenance',
#   u'visit',
#   u'michael',
#   u'nice',
#   u'guy',
#   u'importantly',
#   u'ive',
#   u'gsm',
#   u'top_notch'],
#  [u'referred',
#   u'drying',
#   u'company',
#   u'neighbor',
#   u'similar',
#   u'seeking',
#   u'blown',
#   u'cellulose',
#   u'floor',
#   u'noise',
#   u'suppressor',
#   u'representative',
#   u'home',
#   u'day',
#   u'option',
#   u'detailed',
#   u'information',
#   u'found',
#   u'representative',
#   u'knowledgeable',
#   u'aspect',
#   u'insulation',
#   u'provided',
#   u'estimate',
#   u'choice',
#   u'blown',
#   u'cellulose',
#   u'found',
#   u'estimate',
#   u'reasonable',
#   u'drew',
#   u'contract',
#   u'day',
#   u'week',
#   u'estimated',
#   u'start',
#   u'date',
#   u'day',
#   u'complete',
#   u'job',
#   u'happy',
#   u'stated',
#   u'job',
#   u'week',
#   u'job',
#   u'requiring',
#   u'crew',
#   u'coordinated',
#   u'crew',
#   u'day',
#   u'hour',
#   u'complete',
#   u'job',
#   u'day',
#   u'involved',
#   u'knowledgeable',
#   u'courteous',
#   u'getting',
#   u'estimate',
#   u'cleaning',
#   u'company',
#   u'recommend',
#   u'friend',
#   u'neighbor'],
#  [u'jeremy',
#   u'tom',
#   u'job_installing',
#   u'drain',
#   u'system',
#   u'garage',
#   u'prone',
#   u'flooding',
#   u'rain',
#   u'collecting',
#   u'driveway',
#   u'finished',
#   u'system',
#   u'look',
#   u'neat',
#   u'professional'],
#  [u'husband',
#   u'greg',
#   u'100',
#   u'pleased',
#   u'product',
#   u'service',
#   u'basement_system_usa',
#   u'job',
#   u'flexi',
#   u'span',
#   u'wall',
#   u'crack',
#   u'repair',
#   u'look',
#   u'clean',
#   u'neat',
#   u'warranty',
#   u'call',
#   u'question',
#   u'courteous',
#   u'informative',
#   u'helpful',
#   u'highly_recommend'],
#  [u'pleased',
#   u'professionalism',
#   u'nick',
#   u'barron',
#   u'crew',
#   u'moment',
#   u'arrived',
#   u'job',
#   u'specification',
#   u'nick',
#   u'crew',
#   u'uniformly',
#   u'polite',
#   u'respectful',
#   u'space',
#   u'property',
#   u'cleaned',
#   u'completely',
#   u'nick',
#   u'crew',
#   u'exceeded_expectation',
#   u'completing',
#   u'day',
#   u'quality',
#   u'care',
#   u'process'],
#  [u'jeremy',
#   u'thomas',
#   u'helpful',
#   u'fixed',
#   u'leak',
#   u'literally',
#   u'5_minute',
#   u'thanks'],
#  [u'myra',
#   u'pleased',
#   u'crawl_space',
#   u'insulated',
#   u'properly',
#   u'nice',
#   u'dry',
#   u'juan',
#   u'daniell',
#   u'john',
#   u'professional_courteous',
#   u'friendly',
#   u'respectful',
#   u'pleased',
#   u'highly_recommend'],
#  [u'company',
#   u'fantastic',
#   u'sale',
#   u'bid',
#   u'crew',
#   u'marcus',
#   u'shaq',
#   u'amazing',
#   u'job',
#   u'cannot',
#   u'wonderful',
#   u'appreciated',
#   u'effort',
#   u'time',
#   u'answer_question',
#   u'knowledgeable',
#   u'lot',
#   u'dirt',
#   u'left',
#   u'offered',
#   u'haul',
#   u'foundation',
#   u'window',
#   u'beyond',
#   u'grateful',
#   u'highly_recommend',
#   u'company',
#   u'crew',
#   u'thanks',
#   u'foundation_recovery_system'],
#  [u'charlie', u'excellent', u'technician'],
#  [u'spent',
#   u'month',
#   u'chasing',
#   u'guy',
#   u'finish_job',
#   u'supposed',
#   u'1',
#   u'week',
#   u'wouldnt',
#   u'day',
#   u'week',
#   u'bad',
#   u'situation',
#   u'stressful',
#   u'steve',
#   u'listen',
#   u'brick',
#   u'foundation',
#   u'sent',
#   u'picture',
#   u'email',
#   u'etc',
#   u'added',
#   u'money',
#   u'time',
#   u'project',
#   u'finishing',
#   u'job',
#   u'stopped',
#   u'12',
#   u'foot',
#   u'short',
#   u'contract',
#   u'call',
#   u'weatherproofing',
#   u'saying',
#   u'job',
#   u'difficult',
#   u'required',
#   u'measure',
#   u'thats',
#   u'money',
#   u'sign',
#   u'change',
#   u'contract',
#   u'literally',
#   u'spent',
#   u'entire',
#   u'life',
#   u'saving',
#   u'project',
#   u'nightmare',
#   u'clarke',
#   u'homework',
#   u'spring',
#   u'word',
#   u'mouth',
#   u'hire',
#   u'contractor',
#   u'finish_job',
#   u'foundation'],
#  [u'chris',
#   u'meachams',
#   u'repaired',
#   u'propane',
#   u'fireplace',
#   u'excellent_job',
#   u'prompt',
#   u'personable',
#   u'professional',
#   u'experienced',
#   u'diagnosed',
#   u'repaired',
#   u'fireplace',
#   u'reasonable',
#   u'time',
#   u'time_explain',
#   u'issue',
#   u'repair',
#   u'continue',
#   u'recommend',
#   u'meachams',
#   u'friend',
#   u'energy'],
#  [u'experience',
#   u'clark',
#   u'basement_system',
#   u'fantastic',
#   u'getting',
#   u'hold',
#   u'super',
#   u'easy',
#   u'quote',
#   u'thorough',
#   u'comprehensive',
#   u'chris',
#   u'answered_question',
#   u'patient',
#   u'easy',
#   u'understand',
#   u'manner',
#   u'repair',
#   u'extremely',
#   u'matt',
#   u'clean',
#   u'helpful',
#   u'explaining',
#   u'job',
#   u'repair',
#   u'complete',
#   u'highly_recommend',
#   u'clark',
#   u'basement_system',
#   u'foundation_repair'],
#  [u'halco',
#   u'company',
#   u'family',
#   u'glad',
#   u'chance',
#   u'peoplethey',
#   u'treat',
#   u'employee'],
#  [u'gsm_service',
#   u'reputation',
#   u'overly',
#   u'priced',
#   u'replacement',
#   u'hvac',
#   u'system',
#   u'found',
#   u'pricing',
#   u'inline',
#   u'local',
#   u'competitor',
#   u'real',
#   u'value',
#   u'found',
#   u'dealing',
#   u'gsm_service',
#   u'quality',
#   u'follow',
#   u'service',
#   u'local',
#   u'zoning',
#   u'inspector',
#   u'signed',
#   u'afterinstallation',
#   u'inspection',
#   u'noted',
#   u'extra',
#   u'care',
#   u'benefit',
#   u'system',
#   u'gsm',
#   u'install',
#   u'stated',
#   u'whomever',
#   u'install',
#   u'company',
#   u'quality',
#   u'gsm_service',
#   u'charlie',
#   u'service_tech',
#   u'visited',
#   u'annual',
#   u'check',
#   u'punctual',
#   u'professional',
#   u'friendly',
#   u'pleased',
#   u'aspect',
#   u'relationship',
#   u'company',
#   u'recommend',
#   u'product',
#   u'installation',
#   u'service'],
#  [u'excellent_service',
#   u'heater',
#   u'wasnt',
#   u'repairman',
#   u'ryan',
#   u'promptly',
#   u'day',
#   u'fixed',
#   u'decent',
#   u'price',
#   u'happily',
#   u'warm'],
#  [u'front',
#   u'step',
#   u'patio',
#   u'7',
#   u'home',
#   u'settled',
#   u'inch',
#   u'sell',
#   u'house',
#   u'issue',
#   u'checked',
#   u'replacing',
#   u'concrete',
#   u'2',
#   u'contractor',
#   u'suggested',
#   u'try',
#   u'raising',
#   u'concrete',
#   u'shape',
#   u'considered',
#   u'mud',
#   u'jacking',
#   u'obvious',
#   u'bore',
#   u'hole',
#   u'filled',
#   u'friend',
#   u'recommended',
#   u'badger_basement',
#   u'poly',
#   u'lift',
#   u'method',
#   u'watched',
#   u'video',
#   u'process',
#   u'looked',
#   u'pretty',
#   u'impressive',
#   u'free',
#   u'estimateevaluation',
#   u'assured',
#   u'lifted',
#   u'satisfaction',
#   u'scheduled',
#   u'fix',
#   u'guy',
#   u'hour',
#   u'satisfaction',
#   u'process',
#   u'saved',
#   u'cost',
#   u'replacing',
#   u'concrete',
#   u'bit',
#   u'particular',
#   u'look',
#   u'realist',
#   u'looked',
#   u'left',
#   u'soi',
#   u'happy'],
#  [u'\xe2\u20ac\u201c',
#   u'recommended',
#   u'home',
#   u'thursday',
#   u'september',
#   u'11th',
#   u'friday',
#   u'september',
#   u'12th',
#   u'saturday',
#   u'september',
#   u'13th',
#   u'install',
#   u'system',
#   u'stabilize',
#   u'basement',
#   u'wall',
#   u'cover',
#   u'bright_wall',
#   u'white',
#   u'board',
#   u'install',
#   u'sump_pump',
#   u'\xe2\u20ac\xa2',
#   u'scheduled',
#   u'2',
#   u'day',
#   u'thursday',
#   u'friday',
#   u'8',
#   u'\xe2\u20ac\u201c',
#   u'5',
#   u'pm',
#   u'hour',
#   u'late',
#   u'day',
#   u'beyond',
#   u'5',
#   u'pm',
#   u'day',
#   u'\xc2\xbd',
#   u'day',
#   u'saturday',
#   u'\xe2\u20ac\xa2',
#   u'bright_wall',
#   u'white',
#   u'board',
#   u'window',
#   u'stopped',
#   u'board',
#   u'4',
#   u'inch',
#   u'short',
#   u'window',
#   u'\xe2\u20ac\xa2',
#   u'sump_pump',
#   u'installed',
#   u'location',
#   u'requested',
#   u'\xe2\u20ac\xa2',
#   u'sloppy',
#   u'plumbing',
#   u'left',
#   u'hole',
#   u'concrete',
#   u'wall',
#   u'finish',
#   u'\xe2\u20ac\xa2',
#   u'left',
#   u'outside',
#   u'plumbing',
#   u'sump_pump',
#   u'finish',
#   u'\xe2\u20ac\xa2',
#   u'ran',
#   u'discharge_line',
#   u'sump',
#   u'ground',
#   u'ground',
#   u'leaving',
#   u'1',
#   u'\xc2\xbd\xe2\u20ac\x9d',
#   u'pvc',
#   u'plumbing',
#   u'pipe',
#   u'front',
#   u'house',
#   u'\xe2\u20ac\xa2',
#   u'notified',
#   u'sheetrock',
#   u'wall',
#   u'busted',
#   u'tool',
#   u'repaired',
#   u'\xe2\u20ac\xa2',
#   u'left',
#   u'mess',
#   u'sheetrock',
#   u'hydraulic',
#   u'fluid',
#   u'floor',
#   u'clean',
#   u'\xe2\u20ac\xa2',
#   u'original',
#   u'quote',
#   u'miss',
#   u'figured',
#   u'charging',
#   u'deposit',
#   u'5000',
#   u'\xe2\u20ac\xa2',
#   u'concrete',
#   u'wall',
#   u'sump',
#   u'rough',
#   u'uneven'],
#  [u'jeremy',
#   u'tom',
#   u'installed',
#   u'26',
#   u'wall_anchor',
#   u'basement',
#   u'job',
#   u'satisfied'],
#  [u'michael', u'home', u'time', u'friendly_professional'],
#  [u'hello',
#   u'estaben',
#   u'house',
#   u'touch',
#   u'window',
#   u'javier',
#   u'installed',
#   u'week',
#   u'ago',
#   u'drain',
#   u'sunhouse',
#   u'window',
#   u'current',
#   u'sump',
#   u'system_installed',
#   u'estaben',
#   u'crew',
#   u'removed',
#   u'sealant',
#   u'bottom',
#   u'allow',
#   u'drainage',
#   u'rain',
#   u'excessive',
#   u'storm',
#   u'dry',
#   u'bigger',
#   u'storm',
#   u'truly',
#   u'current',
#   u'configuration',
#   u'crew',
#   u'house',
#   u'polite',
#   u'helpful',
#   u'estaben',
#   u'mentioned',
#   u'getting',
#   u'pump',
#   u'help',
#   u'drainage',
#   u'start',
#   u'filling',
#   u'hand',
#   u'emergency',
#   u'hurricane',
#   u'day',
#   u'day',
#   u'rain',
#   u'wife',
#   u'satisfied',
#   u'installation',
#   u'hope',
#   u'water',
#   u'house',
#   u'time',
#   u'multiday',
#   u'storm',
#   u'ill',
#   u'reserve',
#   u'final',
#   u'star',
#   u'hold',
#   u'storm',
#   u'stay',
#   u'tuned'],
#  [u'horrible',
#   u'company',
#   u'ass',
#   u'foundation',
#   u'expected',
#   u'naive',
#   u'trusted',
#   u'people',
#   u'5',
#   u'ibeams',
#   u'installed',
#   u'basement',
#   u'northside',
#   u'ago',
#   u'4',
#   u'month',
#   u'discovered',
#   u'crack',
#   u'bowing',
#   u'opposite',
#   u'wall',
#   u'east',
#   u'south',
#   u'thrasher',
#   u'4',
#   u'ibeams',
#   u'resolve_issue',
#   u'bowing',
#   u'foundation',
#   u'cracking',
#   u'happening',
#   u'terrible',
#   u'company',
#   u'theyre',
#   u'money',
#   u'creating',
#   u'larger',
#   u'issue',
#   u'shotty',
#   u'workmanship'],
#  [u'crew',
#   u'crawl_space',
#   u'juan',
#   u'mike',
#   u'daniell',
#   u'fantastic',
#   u'professional',
#   u'diligently',
#   u'cheerfully',
#   u'professionally',
#   u'kept',
#   u'clean',
#   u'except',
#   u'improved',
#   u'crawl_space',
#   u'sign',
#   u'time',
#   u'tell',
#   u'worth',
#   u'cost',
#   u'happy',
#   u'install',
#   u'crew'],
#  [u'jeremy', u'tom', u'outstanding_job', u'home', u'professional', u'beyond'],
#  [u'purchased',
#   u'ductless',
#   u'heat_pump',
#   u'process',
#   u'professional',
#   u'install',
#   u'tech',
#   u'job_installing',
#   u'unit',
#   u'kept_informed',
#   u'highly_recommend',
#   u'heating_air',
#   u'purchase',
#   u'installs'],
#  [u'montrae',
#   u'pleasant',
#   u'knowledgeable',
#   u'annual',
#   u'sumppump',
#   u'service',
#   u'appointment',
#   u'helped_understand',
#   u'waterproofing',
#   u'system_installed',
#   u'previous',
#   u'owner',
#   u'recommendation',
#   u'additional',
#   u'waterproofing',
#   u'measure',
#   u'prevent',
#   u'water_damage',
#   u'home',
#   u'foundation',
#   u'\xef\xbb\xbf'],
#  [u'november',
#   u'29',
#   u'2015',
#   u'water',
#   u'appeared',
#   u'nearly',
#   u'2',
#   u'initial',
#   u'repair',
#   u'wall',
#   u'installation',
#   u'interior',
#   u'weeping',
#   u'tile',
#   u'system',
#   u'house',
#   u'immediately',
#   u'feared',
#   u'worst',
#   u'system',
#   u'compromised',
#   u'immediately',
#   u'called',
#   u'main',
#   u'rob',
#   u'investigate',
#   u'determine',
#   u'cause',
#   u'confident',
#   u'clarkes',
#   u'system',
#   u'cause',
#   u'determined',
#   u'scheduled',
#   u'visit',
#   u'time',
#   u'steve',
#   u'salesman',
#   u'infra',
#   u'red',
#   u'camera',
#   u'didnt',
#   u'determine',
#   u'source',
#   u'plumbing',
#   u'leak',
#   u'related',
#   u'shower',
#   u'needle',
#   u'relieved',
#   u'source',
#   u'wasnt',
#   u'related',
#   u'clarkes',
#   u'installation',
#   u'discovery',
#   u'process',
#   u'rob',
#   u'steve',
#   u'concerned',
#   u'courteous',
#   u'polite',
#   u'started',
#   u'emotional',
#   u'experience',
#   u'rob',
#   u'steves',
#   u'confidence',
#   u'product',
#   u'installation',
#   u'process',
#   u'confirmed',
#   u'experience',
#   u'sale',
#   u'support',
#   u'reaffirms',
#   u'mind',
#   u'chose',
#   u'solution',
#   u'company',
#   u'people',
#   u'gunar',
#   u'zenaitis'],
#  [u'called',
#   u'morning',
#   u'day',
#   u'thanksgiving',
#   u'technician',
#   u'zach',
#   u'afternoon',
#   u'professional',
#   u'honest',
#   u'explained',
#   u'diagnosis',
#   u'suggested',
#   u'repair',
#   u'improvement',
#   u'option',
#   u'service',
#   u'fast',
#   u'quality',
#   u'zach',
#   u'doubletripe',
#   u'checked',
#   u'couldnt_happier',
#   u'highly_recommend',
#   u'pipework',
#   u'service'],
#  [u'hi',
#   u'mike',
#   u'tried',
#   u'reach',
#   u'yesterday',
#   u'office',
#   u'reason',
#   u'speak',
#   u'express',
#   u'gratitude',
#   u'installation',
#   u'triple_safe',
#   u'sump_pump',
#   u'system',
#   u'vertical',
#   u'sanidry_dehumidifier',
#   u'flooring',
#   u'system_installed',
#   u'hitch',
#   u'friday',
#   u'nov',
#   u'13th',
#   u'promised',
#   u'company',
#   u'found',
#   u'crew',
#   u'meticulous',
#   u'courteous',
#   u'arrived_time',
#   u'didnt',
#   u'finish',
#   u'8',
#   u'oclock',
#   u'evening',
#   u'basement',
#   u'left',
#   u'tip',
#   u'top',
#   u'shape',
#   u'trace',
#   u'debris',
#   u'speck',
#   u'dust',
#   u'thoroughly',
#   u'professional',
#   u'start_finish',
#   u'crew',
#   u'foreman',
#   u'especially',
#   u'professional',
#   u'doubt',
#   u'tiring',
#   u'day',
#   u'time',
#   u'required',
#   u'explain',
#   u'scope',
#   u'proper',
#   u'operation',
#   u'maintenance',
#   u'system',
#   u'equipment',
#   u'look',
#   u'reliable',
#   u'lasting',
#   u'havent',
#   u'occasion',
#   u'write',
#   u'letter',
#   u'past',
#   u'company',
#   u'ive',
#   u'hired',
#   u'live',
#   u'promise',
#   u'exceptional',
#   u'compelled',
#   u'please',
#   u'accept',
#   u'thanks',
#   u'job',
#   u'please',
#   u'pas',
#   u'gratitude',
#   u'crew',
#   u'beyond',
#   u'call',
#   u'duty',
#   u'please',
#   u'hesitate',
#   u'email',
#   u'referral',
#   u'testimonial',
#   u'id',
#   u'proud',
#   u'recommend',
#   u'basement_system',
#   u'quebec',
#   u'looking',
#   u'professional',
#   u'basement',
#   u'waterproofing',
#   u'regard',
#   u'boisbriand',
#   u'qc'],
#  [u'juan',
#   u'team',
#   u'mike',
#   u'daniell',
#   u'wood_basement',
#   u'excellent_job',
#   u'repair',
#   u'installing',
#   u'sump_pump',
#   u'basement',
#   u'friendly_courteous',
#   u'informative',
#   u'repair',
#   u'job',
#   u'recommend',
#   u'looking',
#   u'professional',
#   u'fixing',
#   u'basement',
#   u'water',
#   u'leak'],
#  [u'highly_recommend',
#   u'buck',
#   u'buckleys',
#   u'total',
#   u'basement',
#   u'finishing',
#   u'excellent_job',
#   u'basement',
#   u'rec',
#   u'job',
#   u'finished',
#   u'time',
#   u'staff',
#   u'easy',
#   u'love',
#   u'result',
#   u'laurie',
#   u'rod',
#   u'baker',
#   u'berlin',
#   u'wi'],
#  [u'complete_basement',
#   u'remodel',
#   u'including',
#   u'building',
#   u'floorroom',
#   u'existing',
#   u'indoor',
#   u'pool',
#   u'buck',
#   u'team',
#   u'professional',
#   u'skillful',
#   u'reliable',
#   u'team',
#   u'remodeling',
#   u'project',
#   u'weve',
#   u'financing',
#   u'breaking',
#   u'2',
#   u'phase',
#   u'covered',
#   u'2yrs',
#   u'affordable',
#   u'stating',
#   u'customer',
#   u'happy',
#   u'willing',
#   u'whatever',
#   u'achieve',
#   u'excellent',
#   u'team',
#   u'highly',
#   u'skilled',
#   u'worker',
#   u'highly_recommend'],
#  [u'experience',
#   u'wood_basement',
#   u'montrae_montgomery',
#   u'satisfying',
#   u'time',
#   u'check',
#   u'entire',
#   u'basement',
#   u'inspect',
#   u'pump',
#   u'battery',
#   u'filter',
#   u'highly_recommend_wood_basement',
#   u'system',
#   u'market',
#   u'service'],
#  [u'gsm',
#   u'customer',
#   u'positive',
#   u'professional',
#   u'experience',
#   u'honest',
#   u'trust',
#   u'knowledge',
#   u'training'],
#  [u'company',
#   u'provided',
#   u'excellent_service',
#   u'sump_pump',
#   u'installed',
#   u'called',
#   u'look',
#   u'moving',
#   u'drain',
#   u'sump_pump',
#   u'flowed',
#   u'sidewalk',
#   u'matt_johnson',
#   u'finding',
#   u'solution',
#   u'change',
#   u'quickly',
#   u'kept_informed',
#   u'step',
#   u'happy',
#   u'company',
#   u'matt',
#   u'suggestion',
#   u'help',
#   u'future',
#   u'definitely',
#   u'calling',
#   u'tar_heel_basement_system'],
#  [u'thomas',
#   u'jeremy',
#   u'crew',
#   u'basement',
#   u'wall',
#   u'perfect',
#   u'polite',
#   u'explained',
#   u'started',
#   u'finish_job',
#   u'yard',
#   u'drilled'],
#  [u'nate',
#   u'quickly',
#   u'existing',
#   u'dated',
#   u'pump',
#   u'updated',
#   u'day',
#   u'patience',
#   u'answer',
#   u'multitude',
#   u'question',
#   u'feel',
#   u'protected',
#   u'basement',
#   u'flooding',
#   u'call'],
#  ...]
