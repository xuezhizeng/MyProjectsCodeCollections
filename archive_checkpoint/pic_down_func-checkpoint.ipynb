# %%
import concurrent.futures
import requests
import os

from time import time, ctime
import pandas as pd

from picDown import download_image, batch

# %%
csv = 'boss_urls.csv'
direct = 'bossPics'

# %%
df=pd.read_csv(csv)
df.shape
# Out:
# (14362, 3)

# %%
# df['URL'].value_counts().head()

# %% [markdown]
# #### most pics like this

# %% [markdown]
# //cdn6.f-cdn.com/img/unknown.png
#
# ![title](//cdn6.f-cdn.com/img/unknown.png)

# %%
df.shape[0]-df['URL'].value_counts()[0]-df['URL'].value_counts()[1]
# Out:
# 4205

# %% [markdown]
# ### : about 30% pics meaningful

# %%
4205.0/df.shape[0]*100
# Out:
# 29.278651998328925

# %%
gdf=df[-(df['URL'].str.contains('None') | df['URL'].str.contains('//cdn6.f-cdn.com/img/unknown.png')\
            |df['URL'].isnull())]
gdf.shape
# Out:
# (4204, 3)

# %%
try:
    os.mkdir(direct)
except:
    print 'exists'
# Out:
# exists

# %%
gdf = gdf[['ID','URL']]

# %% [markdown]
# ### apply diff

# %%
# direct='img_'+str(choose)
df=gdf
nn=df.shape[0]
print nn,' pics'

#apply diff
folder = pd.DataFrame(os.listdir(direct), columns=['name'])
folder = folder[folder['name'].str.contains('.jpg')]
print folder.shape

df['parse']=df['ID']
folder['parse']=folder['name'].apply(lambda x: int(x.split('_')[0]))

joind=df.set_index('parse').join(folder.set_index('parse'),)
print joind.shape

new_df = joind[joind['name'].isnull()][['ID','URL']]
print new_df.shape

nnn=new_df.shape[0]
print 'getiing ',nnn,'diff new pics!'

gdf=new_df
# Out:
# 4204  pics
# (2732, 1)
# (4204, 3)
# (1472, 2)
# getiing  1472 diff new pics!

# %%
want=[]
for i in range(gdf.shape[0]):
    tmp = gdf.iloc[i,:].tolist()
    try:
        want.append([tmp[0], "http:"+tmp[1], direct])
    except Exception as e:
        print e
        print tmp
#     break
len(want)
# Out:
# 1472

# %%
batch(download_image, want)
# Out:
# X3 X4 [1379097]
# X3 X4 [1287256]
# X3 X4 [1102551]
# X3 X4 [251860]
# X3 X4 [1221214]
# X3 X4 [517461]
# X3 X4 [960145]
# X3 X4 [167697]
# X3 X4 [1072040]
# X3 X4 [1571254]
# X3 X4 [1414936]
# X3 X4 [841756]
# X3 X4 [695361]
# X3 X4 [317622]
# X3 X4 [1057053]
# X3 X4 [1276779]
# X3X3  X4X4  [1484779][397276]
#
# X3 X4 [1174063]
# X3 X4 [850702]
# X3 X4 [1138261]
# X3 X4 [1381686]
# X3 X4 [145682]
# X3 X4 [367516]
# X3 X4 X3[1326471]
# X4 [1525696]
# X3 X4 [1391778]
# X3 X4 [642526]
# X3 X4 [1538925]
# X3 X4 [573813]
# X3 X4 [392602]
# X3 X4 [1350515]
# X3 X4 [1319852]
# X3 X4 [1359077]
# X3 X4 [1004897]
# X3 X4 [1551990]
# X3 X4 [1523547]
# X3 X4 [262935]
# X3 X4 [172815]
# X3 X4 [917466]
# X3 X4 [79113]
# X3 X4 [155228]
# X3 X4 [1040552]
# X3 X4 [374785]
# X3 X4 [353254]
# X3 X4 [1070832]
# X3 X4 [1249693]
# X3 X4 [265371]
# X3 X4 [1513906]
# X3 X4 [1044091]
# X3 X4 [1460083]
# X3 X4 [1202329]X3
#  X4 [94319]
# X3 X4 [1487972]
# X3 X4 [1436751]
# X3 X4 [1454283]
# X3 X4 [1571392]
# X3 X4 [1289184]
# X3 X4 [283492]
# X3 X4 [682533]
# X3 X4 [1546710]
# X3 X4 [1546274]
# X3 X4 [170200]
# X3 X4 [872467]
# X3 X4 [810320]
# X3 X4 [665250]
# X3 X4 [1096420]
# X3 X4 [1338223]
# X3 X4 [1468919]
# X3 X4 [1350949]
# X3 X4 [1340716]
# X3 X3 X4X4  [103868][990595]
#
# X3 X4 [770316]
# X3 X4 [1233992]
# X3 X4 [105282]
# X3 X4 [1048076]
# X3 X4 [320772]
# X3 X4 [194151]
# X3 X4 [1413294]
# X3 X4 [713396]
# X3 X4 [1316956]
# X3 X4 [309980]
# X3 X4 [123504]
# X3 X4 [290821]
# X3 X4 [1490089]
# X3 X4 [1354255]
# X3 X4 [477007]
# X3 X4 [557998]
# X3 X4 [500721]
# X3 X4 [1375859]
# X3 X4 [934401]
# X3 X4 [703392]
# X3 X4 [1031985]
# X3 X4 [145026]
# X3 X4 [1490935]
# X3 X4 [1465590]
# X3 X4 [526042]
# X3 X4 [440403]
# X3 X4 [276852]
# X3 X4 [1313426]
# X3 X4 [1267942]
# X3 X4 [395238]
# X3 X4 [463875]
# X3 X4 [423255]
# X3 X4 [43127]
# X3 X4 [662724]
# X3 X4 [1303301]
# X3 X4 [403951]
# X3 X4 [874512]
# X3 X4 [1032123]
# X3 X4 [113990]
# X3 X4 [1266872]
# X3 X4 [700839]
# X3 X4 [174582]
# X3 X4 [647954]
# X3 X3X4  [1458438]X4
#  [1359063]
# X3 X4 [550081]
# X3 X4 [360272]
# X3 X4 [1437886]
# X3 X4 [446576]
# X3 X4 [273376]
# X3 X4 [1160379]
# X3 X4 [180840]
# X3 X4 [445826]
# X3 X4 [1534152]
# X3 X4 [1441735]
# X3 X4 [156327]
# X3 X4 [203513]
# X3 X4 [505999]
# X3 X4 [559958]
# X3 X4 [1156468]
# X3 X4 [791804]
# X3 X4 [1419354]
# X3 X4 [94686]
# X3 X4 [354942]
# X3 X4 [1493485]
# X3 X4 [518023]
# X3 X4 [1548436]
# X3 X4 [541561]
# X3 X4 [1320595]
# X3 X4 [1560852]
# X3 X4 [882859]
# X3 X4 [71551]
# X3 X4 [1301426]
# X3 X4 [1561531]
# X3 X4 [582069]
# X3 X4 [396611]
# X3 X4 [305013]
# X3 X4 [1491988]
# X3 X4 [1536618]
# X3 X4 [340848]
# X3 X4 [1353326]
# X3 X4 [797682]
# X3 X4 [955351]
# X3 X4 [1077211]
# X3 X4 [1428378]
# X3 X4 [417679]
# X3 X4 [284593]
# X3 X4 [1351194]
# X3 X4 [347381]
# X3 X4 [1548606]
# X3 X4 [1544962]
# X3 X4 [1174790]
# X3 X4 [116974]
# X3 X4 [1084335]
# X3 X4 [1145090]
# X3 X4 [996522]
# X3 X4 [1460038]
# X3 X4 [1225888]
# X3 X4 [123869]
# X3 X4 [871633]
# X3 X4 [1538080]
# X3 X4 [1590905]
# X3 X4 [1462968]
# X3 X4 [1411760]
# X3 X4 [726571]
# X3 X4 [355203]
# X3 X4 [414966]
# X3 X4 [743414]
# X3 X4 [505560]
# X3 X4 [106977]
# X3 X4 [220825]
# X3 X4 [561456]
# X3 X4 [1341642]
# X3 X4 [84670]
# X3 X4 [559344]
# X3 X4 [1588256]
# X3 X4 [657095]
# X3 X4 [1250917]
# X3 X4 [339741]
# X3 X4 [843220]
# X3 X4 [247402]
# X3 X4 [546100]
# X3 X4 [842442]
# X3 X4 [593234]
# X3 X4 [1527860]
# X3 X4 [957285]
# X3 X4 [453463]
# X3 X4 [1036652]
# X3 X4 [5814]
# X3 X4 [304137]
# X3 X4 [1473425]
# X3 X4 [1047271]
# X3 X4 [1322139]
# X3 X4 [114017]
# X3 X4 [872397]
# X3 X4 [680246]
# X3 X4 [863283]
# X3 X4 [240521]
# X3 X4 [1388921]
# X3 X4 [524253]
# X3 X4 [852492]
# X3 X4 [1455510]
# X3 X4 [1261509]
# X3 X4 [1285860]
# X3 X4 [1563164]
# X3 X4 [1016390]
# X3 X4 [1407701]
# X3 X4 [273043]
# X3 X4 [1280296]
# X3 X4 [318693]
# X3 X4 [1253471]
# X3 X4 [1166873]
# X3 X4 [1418862]
# X3 X4 [1110034]
# X3 X4 [1093946]
# X3 X4 [1456470]
# X3 X4 [128289]
# X3 X4 [52636]
# X3 X4 [1546681]
# X3 X4 [337949]
# X3 X4 [1433084]
# X3 X4 [543438]
# X3 X4 [361033]
# X3 X4 [1189152]
# X3 X4 [173076]
# X3 X4 [1332651]
# X3 X4 [440621]
# X3 X4 [306684]
# X3 X4 [714005]
# X3 X4 [34205]
# X3 X4 [1217417]
# X3 X4 [1258912]
# X3 X4 [430141]
# X3 X4 [1487259]
# X3X3  X4X4  [933652][862465]
#
# X3 X4 [242523]
# X3 X4 [1347944]
# X3X3  X4X4  [1459628][255590]
#
# X3 X4 [1317169]
# X3 X4 [1507691]
# X3 X4 [832189]
# X3 X4 [1308481]
# X3 X4 [879106]
# X3 X4 [603055]
# X3 X4 [1565379]
# X3 X4 [1556598]
# X3 X4 [1416496]
# X3 X4 [769029]
# X3 X4 [1261713]
# X3 X4 [1029309]
# X3 X4 [709922]
# X3 X4 [862378]
# X3 X4 [705040]
# X3 X4 [1170068]
# X3 X4 [645106]
# X3 X4 [1571298]
# X3 X4 [199729]
# X3 X4 [1427554]
# X3 X4 [603772]X3
#  X4 [321845]
# X3 X4 [1335864]
# X3 X4 [1278630]
# X3 X4 [305070]
# X3 X4 [933609]
# X3 X4 [1127745]
# X3 X4 [689597]
# X3 X4 [1380633]
# X3 X4 [1022136]
# X3 X4 [816158]
# X3 X4 [1090175]
# X3 X4 [1290513]
# X3 X4 [1288766]
# X3 X4 [1283798]
# X3 X4 [387466]
# X3 X4 [535033]
# X3 X4 [1593928]
# X3 X4 [1501444]
# X3 X4 [612913]
# X3 X4 [1055932]
# X3 X4 [1505565]
# X3 X4 [532538]
# X3 X4 [1338937]
# X3 X4 [659392]
# X3 X4 [552690]
# X3 X4 [819131]
# X3 X4 [1104543]
# X3 X4 [416182]
# X3 X4 [1448343]
# X3 X4 [622619]
# X3 X4 [1573270]
# X3 X4 [1335260]
# X3 X4 [1310684]
# X3 X4 [1425597]
# X3 X4 [879792]
# X3 X4 [1127240]
# X3 X4 [1391623]
# X3 X4 [539074]
# X3 X4 [751415]
# X3 X4 [931697]
# X3 X4 [1449997]
# X3 X4 [716778]
# X3 X4 [1512924]
# X3 X4 [1419263]
# X3 X4 [159738]
# X3 X4 [440468]
# X3 X4 [777588]
# X3 X4 [443757]
# X3 X4 [1276349]
# X3 X4 [1457893]
# X3 X4 [358398]
# X3 X4 [1321816]
# X3 X4 [78516]
# X3 X4 [1470672]
# X3 X4 [1176493]
# X3 X4 [808679]
# X3 X4 [127799]
# X3 X4 [1027830]
# X3 X4 [996944]
# X3 X4 [699270]
# X3 X4 [1110948]
# X3 X4 [699943]
# X3 X4 [578500]
# X3 X4 [1020278]
# X3 X4 [726733]
# X3 X4 [305776]
# X3 X4 [1229985]
# X3 X4 [1588491]
# X3 X4 [1073220]
# X3 X4 [1593871]
# X3 X4 [810565]
# X3 X4 [1585244]
# X3 X4 [1076845]
# X3 X4 [1527089]
# X3 X4X3  X3[24425]X4
#  X4 [211194][870648]
#
# X3 X4 [334976]
# X3 X4 [1549390]
# X3 X4 [1336339]
# X3 X4 [18161]
# X3 X4 [1373263]
# X3 X4 [728923]
# X3 X4 [1511844]
# X3 X4 [1120459]
# X3 X4 [232723]
# X3 X4 [1059491]
# X3 X4 [1531834]
# X3 X4 [111084]
# X3 X4 [523814]
# X3 X4 [1149078]
# X3 X4 [1117921]
# X3 X4 [1394143]
# X3 X4 [516583]
# X3 X4 [1437435]
# X3 X4 [532616]
# X3 X4 [1565131]
# X3 X4 [1078895]
# X3 X4 [4555]
# X3 X4 [1372013]
# X3 X4 [1116045]
# X3 X4 [1500496]
# X3 X4 [81608]
# X3 X4 [1588618]
# X3 X4 [862111]
# X3 X4 [1015907]
# X3 X4 [1567873]
# X3 X4 [995007]
# X3 X4 [253643]
# X3 X4 [244553]
# X3 X4 [457450]
# X3 X4 [197359]
# X3 X4 [987387]
# X3 X4 [1375903]
# X3 X4 [1044074]
# X3 X4 [94412]
# X3 X4 [1420442]
# X3 X4 [139226]
# X3 X4 [1413735]
# X3 X4 [925568]
# X3 X4 [863319]
# X3 X4 [222675]
# X3 X4 [1359249]
# X3 X4 [942049]
# X3 X4 [904960]
# X3 X4 [711823]
# X3 X4 [538906]
# X3 X4 [103101]
# X3 X4 [1592821]
# X3 X4 [1028509]
# X3 X4 [821259]
# X3 X4 [1061161]
# X3 X4 [178278]
# X3 X4 [1571366]
# X3 X4 [975823]
# X3 X4 [965731]
# X3 X4 [79386]
# X3 X4 [672678]
# X3 X4 [476158]
# X3 X4 [1041944]
# X3 X4 [948081]
# X3 X4 [1503568]
# X3 X4 [119846]
# X3 X4 [490258]
# X3 X4 [1464945]
# X3 X4 [1264106]
# X3 X4 [758947]
# X3 X4 [876472]
# X3 X4 [1388169]
# X3 X4 [796335]
# X3 X4 [710042]
# X3 X4 [827890]
# X3 X4 [1431074]
# X3 X4 [1481136]
# X3 X4 [1246367]
# X3 X4 [672192]
# X3 X4 [1355754]
# X3 X4 [1257856]
# X3 X4 [1201815]
# X3 X4 [969847]
# X3 X4 [1441973]
# X3 X4 [1491671]
# X3 X4 [862548]
# X3 X4 [1491238]
# X3 X4 [529610]
# X3 X4 [1515760]
# X3 X4 [151415]
# X3 X4 [167664]
# X3 X4 [687403]
# X3 X4 [1571546]
# X3 X4 [1389923]
# X3 X4 [167324]
# X3 X4 [1566612]
# X3 X4 [831474]
# X3 X4 [1248606]
# X3 X4 [1488835]
# X3 X4 [1156809]
# X3 X4 [1104338]
# X3 X4 [1131710]
# X3 X4 [1054951]
# X3 X4 [535987]
# X3 X4 [518334]
# X3 X4 [1016129]
# X3 X4 [107903]
# X3 X4 [1283019]
# X3 X4 [1460074]
# X3 X4 [1437740]
# X3 X4 [171239]
# X3 X4 [1124529]
# X3 X4 [1353115]
# X3 X4 [483714]
# X3 X4 [909745]
# X3 X4 [1438089]
# X3 X4 [1553750]
# X3 X4 [209751]
# X3 X4 [305157]
# X3 X4 [550541]
# X3 X4 [1576404]
# X3 X4 [1042120]
# X3 X4 [758225]
# X3 X4 [1131938]
# X3 X4 [677906]
# X3 X4 [72637]
# X3 X4 [356500]
# X3 X4 [231319]
# X3 X4 [610142]
# X3 X4 [1042751]
# X3 X4 [1341294]
# X3 X4 [1234757]
# X3 X4 [1185987]
# X3 X4 [1563326]
# X3 X4 [1163441]
# X3 X4 [1365355]
# X3 X4 [1497574]
# X3 X4 [859821]
# X3 X4 [871966]
# X3 X4 [1253550]
# X3 X4 [567708]
# X3 X4 [1267821]
# X3 X4 [748671]
# X3 X4 [688012]
# X3 X4 [1267755]
# X3 X4 [714999]
# X3 X4 [84353]
# X3 X4 [1389804]
# X3 X4X3  [705608]X4
#  [1170582]
# X3 X4 [626962]
# X3 X4 [818410]
# X3 X4 [771126]
# X3 X4 [375547]
# X3 X4 [681246]
# X3 X4 [845912]
# X3 X4 [1556156]
# X3 X4 [80870]
# X3 X4 [977835]
# X3 X4 [1339516]
# X3 X4 [484419]
# X3 X4 [177697]
# X3 X4 [25283]
# X3 X4 [375260]
# X3 X4 [309431]
# X3 X4 [1419483]
# X3 X4 [1452229]
# X3 X4 [48591]
# X3 X4 [101320]
# X3 X4 [1543413]
# X3 X4 [1371702]
# X3 X4 [417345]
# X3 X4 [1157809]
# X3 X4 [499069]
# X3 X4 [1008298]
# X3 X4 [747874]
# X3 X4 [1339240]
# X3 X4 [1319246]
# X3 X4 [1585713]
# X3 X4 [73779]
# X3 X4 [1472402]
# X3 X4 [1234117]
# X3 X4 [272981]
# X3 X4 [817347]
# X3 X4 [1169860]
# X3 X4 [685190]
# X3X3 X4 [1029461]
#  X4 [1090791]
# X3 X4 [1577127]
# X3 X4 [614136]
# X3 X4 [1084572]
# X3 X4 [1027658]
# X3 X4 [1019980]
# X3 X4 [481257]
# X3 X4 [1540753]
# X3 X4 [739648]
# X3 X4 [1057003]
# X3 X4 [1337497]
# X3 X4 [45145]
# X3 X4 [1270814]
# X3 X4 [1009457]
# X3 X4 [1171215]
# X3 X4 [358981]
# X3 X4 [1081574]
# X3 X4 [241554]
# X3 X4 [531894]
# X3 X4 [256183]
# X3 X4 [618978]
# X3 X4 [1415007]
# X3 X4 [88025]
# X3 X4 [1348985]
# X3 X4 [1344800]
# X3 X4 [1278719]
# X3 X4 [26631]
# X3 X4 [649658]
# X3 X4 [1299067]
# X3 X4 [1387218]
# X3 X4 [345095]
# X3 X4 [1369902]
# X3 X4 [1544825]
# X3 X4 [1367024]
# X3 X4 [892031]
# X3 X4 [427763]
# X3 X4 [1207445]
# X3 X4 [1345582]
# X3 X4 [891634]
# X3 X4 [589141]
# X3 X4 [771992]
# X3 X4 [569937]
# X3 X4 [269985]
# X3 X4 [1346706]
# X3 X4 [965588]
# X3 X4 [803277]
# X3 X4 [1294303]
# X3 X4 [1272772]
# X3 X4 [190590]
# X3 X4 [1463171]
# X3 X4 [971049]
# X3 X4 [1538014]
# X3 X4 [849205]
# X3 X4 [1354422]
# X3 X4 [1522582]
# X3 X4 [853676]
# X3 X4 [1488312]
# X3 X4 [1389476]
# X3 X4 [1007389]
# X3 X4 [647256]
# X3 X4 [55072]
# X3 X4 [1590477]
# X3 X4 [757426]
# X3 X4 [230886]
# X3 X4 [443937]
# X3 X4 [649935]
# X3 X4 [1431189]
# X3 X4 [117748]
# X3 X4 [599332]
# X3 X4 [1067570]
# X3 X4 [1323982]
# X3 X4 [533875]
# X3 X4 [740204]
# X3 X4 [958481]
# X3 X4 [1166348]
# X3 X4 [746801]
# X3 X4 [1143528]
# X3 X4 [137144]
# X3 X4 [1014985]
# X3 X4 [1522893]
# X3 X4 [649363]
# X3 X4 [1484020]
# X3 X4 [1171112]
# X3 X4 [126302]
# X3 X4 [1343169]
# X3 X4 [1370337]
# X3 X4 [1558379]
# X3 X4 [1234795]
# X3 X4 [1106905]
# X3 X4 [1096245]
# X3 X4 [830750]
# X3 X4 [105765]
# X3 X4 [252925]
# X3 X4 [583927]
# X3 X4 [1056899]
# X3 X4 [1074608]
# X3 X4 [1157893]
# X3 X4 [270766]
# X3 X4 [1494000]
# X3 X4 [1156817]
# X3 X4 [100169]
# X3 X4 [1413494]
# X3 X4 [1356559]
# X3 X4 [796221]
# X3 X4 [384752]
# X3 X4 [1289422]
# X3 X4 [1130637]
# X3 X4 [467847]
# X3 X4 [235887]
# X3 X4 [793441]
# X3 X4 [526398]
# X3 X4 [766596]
# X3 X4 [1569072]
# X3 X4 [1304742]
# X3 X4 [1445656]
# X3 X4 [1323093]
# X3 X4 [1585305]
# X3 X4 [1055274]
# X3 X4 [661853]
# X3 X4 [1373911]
# X3 X4 [353986]
# X3 X4 [1549837]
# X3 X4 [671521]
# X3 X4 [398962]
# X3 X4 [541442]
# X3 X4 [401493]
# X3 X4 [1356888]
# X3 X4 [223451]
# X3 X4 [598753]
# X3 X4 [325400]
# X3 X4 X3[1315342]
#  X4 [720288]
# X3 X4 [232540]
# imges  1472   used  181.31 s Sep 20 12:09:10 2017

# %%
# download_image(want[2])
