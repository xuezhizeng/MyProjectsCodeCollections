# %%
# !ls
# Out:
# catDog_test		       idFace.ipynb
# cat_dog_main.ipynb	       landmarks.ipynb
# cat_dog_report.ipynb	       openface.ipynb
# chopHead256_real_soyoung_pics  real_soyoung_pics
# chop_control.ipynb	       shape_predictor_68_face_landmarks.dat
# chop_face_soyoung.ipynb        soyoung_test
# facial_landmarks.py

# %%
from time import time
start=time()
start


# !/root/openface/util/align-dlib.py \
real_soyoung_pics/img_4 align \
outerEyesAndNose \
chopHead256_real_soyoung_pics \
--size 256

end=time()-start
end
# Out:
# === real_soyoung_pics/img_4/632845_android20160727093929373.jpg ===
# === real_soyoung_pics/img_4/612320_web20160914103755135.jpg ===
# === real_soyoung_pics/img_4/612715_web20161024141247836.jpg ===
# === real_soyoung_pics/img_4/612954_android20151106133219160.jpg ===
# === real_soyoung_pics/img_4/632950_android20160426182528188.jpg ===
# === real_soyoung_pics/img_4/632812_android20161214150531331.jpg ===
# === real_soyoung_pics/img_4/633010_android20170112164354692.jpg ===
# === real_soyoung_pics/img_4/612646_ios20160707185048751.jpg ===
# === real_soyoung_pics/img_4/622824_ios20160415033249813.jpg ===
# === real_soyoung_pics/img_4/632873_ios20170509143915522.jpg ===
# === real_soyoung_pics/img_4/622346_web20170619134421663.jpg ===
# === real_soyoung_pics/img_4/632754_ios20161205195601425.jpg ===
# === real_soyoung_pics/img_4/633132_ios20160504150340463.jpg ===
# === real_soyoung_pics/img_4/612886_ios20170220141020158.jpg ===
# ...
