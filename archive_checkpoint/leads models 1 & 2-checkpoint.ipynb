# %%
import pandas as pd

# %%
# %%time
df=pd.read_csv('./data.csv.csv')
df.shape
# Out:
# CPU times: user 2.14 s, sys: 96 ms, total: 2.24 s
# Wall time: 2.47 s
# <string>:2: DtypeWarning: Columns (32) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
df.shape
# Out:
# (361135, 43)

# %%
pd.options.display.max_columns=1000
df.head()
# Out:
#              Service Type             Association   Zip        City  \
# 0  Basement Waterproofing  Basement Systems, Inc.  1062    Florence
# 1  Basement Waterproofing  Basement Systems, Inc.  1450      Groton
# 2  Basement Waterproofing  Basement Systems, Inc.  1460   Littleton
# 3  Basement Waterproofing  Basement Systems, Inc.  1469    Townsend
# 4  Basement Waterproofing  Basement Systems, Inc.  1545  Shrewsbury
#
#   State Full Name                     Company Country  Elevation   Latitude  \
# 0   massachusetts     Leader Basement Systems      US        140  42.330067
# 1   massachusetts  Northeast Basement Systems      US         40  42.616190
# 2   massachusetts  Northeast Basement Systems      US         40  42.537958
# 3   massachusetts    DryZone Basement Systems      US         40  42.659557
# 4   massachusetts     Leader Basement Systems      US        475  42.286780
#
#    Longitude  Air_Temp_Max (degF)  Air_Temp_Min (degF)  Avg_Temp_C  \
# ...

# %%
# df['State Full Name'].value_counts()

# %%
print (dir(df.groupby('State Full Name')))
# Out:
# ['Association', 'Avg_Temp_C', 'Avg_Temp_F', 'City', 'Company', 'Country', 'Dt', 'Elevation', 'Latitude', 'Longitude', 'Population', 'Price', 'Region', 'Source', 'Status', 'Validation', 'Zip', '__bytes__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__format__', '__getattr__', '__getattribute__', '__getitem__', '__hash__', '__init__', '__iter__', '__len__', '__module__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__unicode__', '__weakref__', '_add_numeric_operations', '_agg_doc', '_aggregate', '_aggregate_generic', '_aggregate_item_by_item', '_aggregate_multiple_funcs', '_apply_filter', '_apply_to_column_groupbys', '_apply_whitelist', '_assure_grouper', '_block_agg_axis', '_builtin_table', '_choose_path', '_concat_objects', '_constructor', '_cumcount_array', '_cython_agg_blocks', '_cython_agg_general', '_cython_table', '_cython_transform', '_decide_output_index', '_def_str', '_define_paths', '_d
# ...

# %%
df1 = df.groupby('State Full Name').mean()
df1.shape
# Out:
# (51, 32)

# %%
(df['Zip'].isnull()).sum()
# Out:
# 0

# %%
df2 = df.groupby('State Full Name').count()[['Zip']]

# %%
df2.columns=['Leed Count']

# %%
df3 = pd.concat([df2, df1], axis=1)
df3.shape
# Out:
# (51, 33)

# %%
df3.columns
# Out:
# Index([u'Leed Count', u'Zip', u'Elevation', u'Latitude', u'Longitude',
#        u'Air_Temp_Max (degF)', u'Air_Temp_Min (degF)', u'Avg_Temp_C',
#        u'Avg_Temp_F', u'Precipitation Increment (in)',
#        u'Soil Moisture Percent -2in (pct) Mean of Hourly Values',
#        u'Soil Moisture Percent -4in (pct) Mean of Hourly Values',
#        u'Soil Temperature Observed -2in (degF) Mean of Hourly Values',
#        u'Soil Temperature Observed -4in (degF) Mean of Hourly Values',
#        u'Population', u'Male Population', u'Female Population',
#        u'Asian Population', u'Hawaiian Population', u'Hispanic.Population',
#        u'Indian Population', u'Other Population', u'White Population',
#        u'Black Population', u'Avarage House Value', u'Households Per Zipcode',
#        u'Income Per Household', u'Is Mobile', u'Persons Per Household',
#        u'Price', u'Received Month', u'Received Year', u'Validation'],
#       dtype='object')

# %%
df3.head(6)
# Out:
#                  Leed Count           Zip    Elevation   Latitude   Longitude  \
# State Full Name
# alabama                5725  35520.220611   548.658865  33.547367  -86.741859
# alaska                   18  99600.500000     0.000000  61.122270 -149.152615
# arizona                  81  85407.975309  1900.716049  33.437762 -111.686711
# arkansas                611  72371.153846   615.656301  35.426602  -92.654737
# california             1845  93143.185366   206.472087  36.044025 -120.247571
# colorado              11996  80364.622041  5413.569023  39.599495 -105.010547
#
#                  Air_Temp_Max (degF)  Air_Temp_Min (degF)  Avg_Temp_C  \
# State Full Name
# alabama                    81.364968            34.844593   18.384563
# alaska                     51.764706            -0.658824  -16.286667
# arizona                    84.635135            34.387467   14.892986
# arkansas                   84.162257            40.052701   16.731950
# ...

# %%
# df3.to_csv('StatsByState.csv')

# %%
df3.index
# Out:
# Index([u'alabama', u'alaska', u'arizona', u'arkansas', u'california',
#        u'colorado', u'connecticut', u'delaware', u'district of columbia',
#        u'florida', u'georgia', u'hawaii', u'idaho', u'illinois', u'indiana',
#        u'iowa', u'kansas', u'kentucky', u'louisiana', u'maine', u'maryland',
#        u'massachusetts', u'michigan', u'minnesota', u'mississippi',
#        u'missouri', u'montana', u'nebraska', u'nevada', u'new hampshire',
#        u'new jersey', u'new mexico', u'new york', u'north carolina',
#        u'north dakota', u'ohio', u'oklahoma', u'oregon', u'pennsylvania',
#        u'rhode island', u'south carolina', u'south dakota', u'tennessee',
#        u'texas', u'utah', u'vermont', u'virginia', u'washington',
#        u'west virginia', u'wisconsin', u'wyoming'],
#       dtype='object', name=u'State Full Name')

# %%
df3.loc['georgia',:]
# Out:
# Leed Count                                                      12892.000000
# Zip                                                             30285.378141
# Elevation                                                         976.697409
# Latitude                                                           33.831454
# Longitude                                                         -84.218670
# Air_Temp_Max (degF)                                                85.196086
# Air_Temp_Min (degF)                                                44.192855
# Avg_Temp_C                                                         20.507408
# Avg_Temp_F                                                         68.913334
# Precipitation Increment (in)                                        4.670802
# Soil Moisture Percent -2in (pct) Mean of Hourly Values             11.178630
# Soil Moisture Percent -4in (pct) Mean of Hourly Values             15.959037
# ...

# %%
# df['City'].value_counts(dropna=False)

# %%
# df['Zip'].value_counts()

# %%
df_c = df.groupby('City').mean()
df_c.shape
# Out:
# (10386, 32)

# %%
a = df.groupby('City').count()[['Zip']]
a.columns=['Count']
df_c = pd.concat([a, df_c], axis=1)
df_c.shape
# Out:
# (10386, 33)

# %%
y_c=df_c.pop('Count')

# %%
df_c.columns
# Out:
# Index([u'Zip', u'Elevation', u'Latitude', u'Longitude', u'Air_Temp_Max (degF)',
#        u'Air_Temp_Min (degF)', u'Avg_Temp_C', u'Avg_Temp_F',
#        u'Precipitation Increment (in)',
#        u'Soil Moisture Percent -2in (pct) Mean of Hourly Values',
#        u'Soil Moisture Percent -4in (pct) Mean of Hourly Values',
#        u'Soil Temperature Observed -2in (degF) Mean of Hourly Values',
#        u'Soil Temperature Observed -4in (degF) Mean of Hourly Values',
#        u'Population', u'Male Population', u'Female Population',
#        u'Asian Population', u'Hawaiian Population', u'Hispanic.Population',
#        u'Indian Population', u'Other Population', u'White Population',
#        u'Black Population', u'Avarage House Value', u'Households Per Zipcode',
#        u'Income Per Household', u'Is Mobile', u'Persons Per Household',
#        u'Price', u'Received Month', u'Received Year', u'Validation'],
#       dtype='object')

# %%
y_c.name='Leads Number'

# %%
pd.concat([y_c,df_c[df_c.columns[4:]]], axis=1)
# Out:
#               Leads Number  Air_Temp_Max (degF)  Air_Temp_Min (degF)  \
# City
# Aaronsburg               2            81.500000            26.000000
# Abbeville               17            81.266667            32.948667
# Abbotsford               8            88.200000            46.600000
# Abbottstown              2            57.000000            27.775000
# Abbyville                3            82.000000            28.333333
# Abercrombie              4            78.000000            20.333333
# Aberdeen                53            75.934783            23.366809
# Abilene                 34            89.382353            41.001765
# Abingdon                93            80.700000            34.843375
# Abington               103            75.303571            30.062364
# Abrams                  11            70.428571            21.857143
# Absecon                 53             0.000000             0.000000
# ...

# %%
df_c[df_c.columns[4:]]
# Out:
#               Air_Temp_Max (degF)  Air_Temp_Min (degF)  Avg_Temp_C  \
# City
# Aaronsburg              81.500000            26.000000   10.425500
# Abbeville               81.266667            32.948667   19.349143
# Abbotsford              88.200000            46.600000   12.440000
# Abbottstown             57.000000            27.775000    0.000000
# Abbyville               82.000000            28.333333    0.000000
# Abercrombie             78.000000            20.333333    8.625500
# Aberdeen                75.934783            23.366809    9.552481
# Abilene                 89.382353            41.001765   26.023833
# Abingdon                80.700000            34.843375   14.812550
# Abington                75.303571            30.062364   12.508453
# Abrams                  70.428571            21.857143   12.736500
# Absecon                  0.000000             0.000000   12.839250
# Accokeek                80.500000            14.726000   17.403500
# ...

# %%
df2.columns=['Leed Count']

# %%
df_z = df.groupby('Zip').mean()
df_z.shape
# Out:
# (19655, 31)

# %%
df_c=df_c.fillna(0)

# %%
df_c.head()
# Out:
#                       Zip    Elevation   Latitude  Longitude  \
# City
# Aaronsburg   16820.000000   745.000000  40.910552 -77.406999
# Abbeville    30407.058824   585.470588  33.879768 -82.762148
# Abbotsford   54405.000000   997.000000  44.974307 -90.297512
# Abbottstown  17301.000000   520.000000  39.894532 -76.973261
# Abbyville    67510.000000  1530.000000  38.006416 -98.206288
#
#              Air_Temp_Max (degF)  Air_Temp_Min (degF)  Avg_Temp_C  Avg_Temp_F  \
# City
# Aaronsburg             81.500000            26.000000   10.425500   50.765900
# Abbeville              81.266667            32.948667   19.349143   66.828457
# Abbotsford             88.200000            46.600000   12.440000   54.392000
# Abbottstown            57.000000            27.775000    0.000000    0.000000
# Abbyville              82.000000            28.333333    0.000000    0.000000
#
#              Precipitation Increment (in)  \
# City
# Aaronsburg                       4.285000
# ...

# %%
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.cross_validation import cross_val_score
# %matplotlib inline
# Out:
# /home/saya/anaconda2/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
model_c = RandomForestRegressor()
model_c
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
model_c.fit(df_c, y_c)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
# cross_val_score?

# %%
# cross_val_score(RandomForestRegressor(), X=df_c, y=y_c, cv=5, scoring='mean_squared_error')

# %%
# cross_val_score?

# %%
model_c.feature_importances_
# Out:
# array([ 0.0279568 ,  0.06975508,  0.01099153,  0.03531664,  0.01891089,
#         0.01413721,  0.00482387,  0.00395314,  0.00963933,  0.0349003 ,
#         0.01619628,  0.00715671,  0.00327909,  0.00581398,  0.0079229 ,
#         0.00395293,  0.05908343,  0.02768753,  0.01202806,  0.00649481,
#         0.00450252,  0.05104605,  0.05584196,  0.02159555,  0.11601721,
#         0.02978365,  0.09150782,  0.08883582,  0.02863102,  0.0104254 ,
#         0.06879009,  0.0530224 ])

# %%
plt.figure(figsize=[12, 9])
pl = pd.Series(model_c.feature_importances_, index=df_c.columns)
pl=pl.sort_values()
pd.Series(pl).plot(kind='barh')

# %%
df_c.columns
# Out:
# Index([u'Zip', u'Elevation', u'Latitude', u'Longitude', u'Air_Temp_Max (degF)',
#        u'Air_Temp_Min (degF)', u'Avg_Temp_C', u'Avg_Temp_F',
#        u'Precipitation Increment (in)',
#        u'Soil Moisture Percent -2in (pct) Mean of Hourly Values',
#        u'Soil Moisture Percent -4in (pct) Mean of Hourly Values',
#        u'Soil Temperature Observed -2in (degF) Mean of Hourly Values',
#        u'Soil Temperature Observed -4in (degF) Mean of Hourly Values',
#        u'Population', u'Male Population', u'Female Population',
#        u'Asian Population', u'Hawaiian Population', u'Hispanic.Population',
#        u'Indian Population', u'Other Population', u'White Population',
#        u'Black Population', u'Avarage House Value', u'Households Per Zipcode',
#        u'Income Per Household', u'Is Mobile', u'Persons Per Household',
#        u'Price', u'Received Month', u'Received Year', u'Validation'],
#       dtype='object')

# %%
to_remove=[
    'Zip','Is Mobile','Received Month','Validation','Received Year','Elevation','White Population','Black Population',
    'Latitude', 'Longitude','Price'
]

# %%
df_cc = df_c[list(set(df_c.columns)-set(to_remove))]
df_cc.shape
# Out:
# (10386, 21)

# %%
model_cc=RandomForestRegressor()
model_cc
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
# %%time
model_cc.fit(df_cc, y_c)
# Out:
# CPU times: user 1.32 s, sys: 0 ns, total: 1.32 s
# Wall time: 1.31 s
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
plt.figure(figsize=[12, 9])
pl2 = pd.Series(model_cc.feature_importances_, index=df_cc.columns)
pl2=pl2.sort_values()
pd.Series(pl2).plot(kind='barh', color='grey',alpha=.7)

# %%
df_cc
# Out:
#               Hawaiian Population  Hispanic.Population  Air_Temp_Min (degF)  \
# City
# Aaronsburg               1.000000             5.000000            26.000000
# Abbeville                4.117647           112.647059            32.948667
# Abbotsford               0.000000           604.000000            46.600000
# Abbottstown             12.000000           164.000000            27.775000
# Abbyville                0.000000             3.000000            28.333333
# Abercrombie              0.000000             0.000000            20.333333
# Aberdeen                90.566038          1125.528302            23.366809
# Abilene                  5.000000           414.000000            41.001765
# Abingdon                27.655914           519.000000            34.843375
# Abington                16.883495           604.504854            30.062364
# Abrams                   3.000000            31.000000            21.857143
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
model_lin=LinearRegression()

# %%
# %%time
model_lin.fit(df_cc, y_c)
# Out:
# CPU times: user 20 ms, sys: 0 ns, total: 20 ms
# Wall time: 41 ms
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# keep

# %% [markdown]
# ### nomalized + selection

# %%
keep=[
'Households Per Zipcode',
'Income Per Household',
'Avarage House Value',
'Air_Temp_Max (degF)',
'Persons Per Household',
'Air_Temp_Min (degF)',
'Avg_Temp_F',
'Precipitation Increment (in)']

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
df_n = df_cc[keep]

# %%
sc = MinMaxScaler()

# %%
n_data = sc.fit_transform(df_n)

# %%
n_data.shape
# Out:
# (10386, 8)

# %%
df_cc[keep]
# Out:
#               Households Per Zipcode  Income Per Household  \
# City
# Aaronsburg                431.000000          55947.000000
# Abbeville                4935.470588          33572.294118
# Abbotsford               1118.000000          45609.000000
# Abbottstown              1515.000000          61607.000000
# Abbyville                 119.000000          32232.000000
# Abercrombie                20.000000          82500.000000
# Aberdeen                 9361.584906          49193.528302
# Abilene                  4212.000000          51416.000000
# Abingdon                 7175.333333          58197.075269
# Abington                 6260.087379          71760.048544
# Abrams                   1067.000000          64450.000000
# Absecon                  9133.735849          61811.207547
# Accokeek                 3317.000000         123851.000000
# Accomac                   642.000000          41944.000000
# Accord                   1378.000000          67639.000000
# ...

# %%
n_data
# Out:
# array([[ 0.01324239,  0.223788  ,  0.1678    , ...,  0.54      ,
#          0.66060975,  0.09175589],
#        [ 0.15164134,  0.13428918,  0.0983    , ...,  0.60948667,
#          0.81795992,  0.08401791],
#        [ 0.03435032,  0.182436  ,  0.1069    , ...,  0.746     ,
#          0.69613133,  0.12805139],
#        ...,
#        [ 0.03920484,  0.192984  ,  0.1793    , ...,  0.82333333,
#          0.92431937,  0.11441827],
#        [ 0.01861923,  0.260768  ,  0.2277    , ...,  0.67333333,
#          0.16330269,  0.10670949],
#        [ 0.05825422,  0.23      ,  0.1859    , ...,  0.57571429,
#          0.58360224,  0.10342612]])

# %%
model2=LinearRegression()
model2
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# %%time
model2.fit(n_data, y_c)
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 2.11 ms
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
model2.coef_
# Out:
# array([ 345.96511529,  165.08542692,  -84.93936207,   46.40322092,
#        -166.28867771,  -54.6856027 ,   13.31072542,   23.70891588])

# %%
plt.figure(figsize=[10, 7])
pl3 = pd.Series(model2.coef_, index=df_n.columns)
pl3=pl3.sort_values()
pd.Series(pl3).plot(kind='barh', color='#CED8F6',alpha=1)

# %%
# bill_data

# %%
# pd.DataFrame(bill_train, columns=bill_data.columns)

# %%
bill_train
# Out:
# array([[ 0.1039116 ,  0.263024  ,  0.2703    , ...,  0.66818182,
#          0.81428816,  0.        ],
#        [ 0.08446615,  0.468508  ,  0.435     , ...,  0.66818182,
#          0.81428816,  0.        ],
#        [ 0.07420328,  0.42182   ,  0.3827    , ...,  0.66818182,
#          0.81428816,  0.        ],
#        ...,
#        [ 0.27628736,  0.255232  ,  0.2361    , ...,  0.84545455,
#          0.1489676 ,  0.01970803],
#        [ 0.17343356,  0.224688  ,  0.2266    , ...,  0.84545455,
#          0.1489676 ,  0.01970803],
#        [ 0.17343356,  0.224688  ,  0.2266    , ...,  0.84545455,
#          0.1489676 ,  0.01970803]])

# %%
keep2=[
'Households Per Zipcode',
'Income Per Household',
'Avarage House Value',
'Air_Temp_Max (degF)',
'Persons Per Household',
'Air_Temp_Min (degF)',
'Avg_Temp_F',
'Precipitation Increment (in)',
'Status']

# %%
bill_data = df[keep2]
bill_data.shape
# Out:
# (361135, 9)

# %%
bill_data['Status'] = bill_data['Status'].map({'Billable Lead':1, 'No Charge':0})
# Out:
# /home/saya/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
model2_y=bill_data.pop('Status')

# %%
sc2=MinMaxScaler()
sc2
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
bill_data = bill_data.fillna(-1)

# %%
bill_train=sc2.fit_transform(bill_data)
bill_train.shape
# Out:
# (361135, 8)

# %%
from sklearn.linear_model import LogisticRegression

# %%
    bill_model = LogisticRegression()
bill_model
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
# cross_val_score?

# %%
# %%time
cross_val_score(bill_model, bill_train, model2_y, cv=5)
# Out:
# CPU times: user 4.53 s, sys: 1.23 s, total: 5.76 s
# Wall time: 4.52 s
# array([ 0.61392554,  0.60759827,  0.59595442,  0.48188351,  0.44955488])

# %%
# %%time
bill_model.fit(bill_train, model2_y)
# Out:
# CPU times: user 992 ms, sys: 228 ms, total: 1.22 s
# Wall time: 978 ms
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
bill_model.coef_
# Out:
# array([[-0.23435038, -2.61522461,  1.97591388,  0.21603432,  3.1541153 ,
#         -0.78480549,  2.04299937,  0.48948079]])

# %%
plt.figure(figsize=[10, 7])
pl3 = pd.Series(bill_model.coef_[0], index=bill_data.columns)
pl3=pl3.sort_values()
pd.Series(pl3).plot(kind='barh', color='#819FF7',alpha=.7)

# %%
bill_model.classes_
# Out:
# array([0, 1])

# %%
model_lin.coef_
# Out:
# array([ -2.10570311e-02,  -9.27911984e-03,  -2.74573858e-01,
#          4.68398061e-01,   7.24328838e-03,   3.63331038e-01,
#          3.10366655e-02,  -1.11358743e-02,   1.15873380e-01,
#         -1.35062259e+00,  -5.87866105e-05,  -1.82257529e-01,
#         -2.82175768e-03,  -3.94019106e-03,  -1.88427580e-03,
#          4.77291626e-01,  -1.45230605e+01,  -3.87887489e-02,
#          1.71884071e-02,   5.07715373e-04,  -4.70603349e-03])

# %%
len(model_lin.coef_)
# Out:
# 21

# %%
plt.figure(figsize=[10, 7])
pl3 = pd.Series(model_lin.coef_, index=df_cc.columns)
pl3=pl3.sort_values()
pd.Series(pl3).plot(kind='barh', color='b',alpha=.7)

# %%
model_lin.intercept_
# Out:
# -3.4032462536999759

# %%
# pd.concat([y_c, df_cc] ,axis=1).to_csv('cityLevel.csv')

# %%
df666 = pd.concat([y_c, df_cc] ,axis=1)

# %%
df666 = df666[df666['Count']>=10]
df666.shape
# Out:
# (4036, 22)

# %%
df666.to_csv('city10.csv')

# %%
df_cc['Income Per Household'].describe()
# Out:
# count     10386.000000
# mean      56029.499702
# std       23655.554694
# min           0.000000
# 25%       42173.437500
# 50%       51718.000000
# 75%       65292.500000
# max      250000.000000
# Name: Income Per Household, dtype: float64

# %%
def helper(x):
    if x<30000:
        return 'low'
    elif x<45000:
        return 'med'
    elif x<60000:
        return 'med_high'
    else:
        return 'high'

# %%
df_cc['Income Per Household'].hist(bins=50)

# %%
df_cc['Income_Cut']=df_cc['Income Per Household'].apply(helper)
# Out:
# /home/saya/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
pd.concat([y_c, df_cc] ,axis=1).to_csv('city_incomeCut.csv')
