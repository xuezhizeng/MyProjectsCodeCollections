# %%
type(hash('100'))
# Out:
# int

# %%
hash('100')
# Out:
# 163512108406620378

# %%
testcode=[  1641,    393,   8629,   8491,  26086,   2296,    663,   1588,
        25764,   8533,   4981,   6187,   3268,   4237,    343,   3078,
         6643, 106002,    338,   3554]

# %%
import os
import pandas as pd
import math
import findspark

findspark.init('/usr/hdp/2.6.0.3-8/spark')

# %%
from pyspark.mllib.recommendation import ALS, MatrixFactorizationModel, Rating
from pyspark import rdd, SparkContext, SparkFiles
sc=SparkContext()

# %%
def single_test0(userID, codes):
    results=[]
#     userID = np.random.randint(1000,2000)
    for i in codes:
        results.append((u"{},{},1".format(userID,i)))
    print len(results)
    return results

# %%
new = sc.parallelize(single_test0(2000, testcode))
type(new)
# Out:
# 20
# pyspark.rdd.RDD

# %%
new.take(3)
# Out:
# [u'2000,1641,1', u'2000,393,1', u'2000,8629,1']

# %%
# %%time
fl = sc.textFile('file:///home/soyoung/HackerInsurTech/midsample.csv')
print type(fl)
header = fl.first() #extract header
fl = fl.filter(lambda x: x!=header)
# Out:
# <class 'pyspark.rdd.RDD'>
# CPU times: user 4 ms, sys: 0 ns, total: 4 ms
# Wall time: 205 ms

# %%
fl.take(3)
# Out:
# [u'1,110,0', u'1,147,1', u'1,858,1']

# %%
data = sc.union([fl,new])
data.take(3)
# Out:
# [u'1,110,0', u'1,147,1', u'1,858,1']

# %% [markdown]
# ___

# %%
# Rating??

# %%
ratings = data.map(lambda l: l.split(',')).map(lambda l: Rating(int(l[0]), int(str(l[1])), float(l[2])))

# %%
rank = 10
numIterations = 10

# %%
# %%time
model = ALS.train(ratings, rank, numIterations)
# Out:
# CPU times: user 16 ms, sys: 4 ms, total: 20 ms
# Wall time: 15.2 s

# %%
ratings.take(1)
# Out:
# [Rating(user=1, product=110, rating=0.0)]

# %%
ratings.take(1)[0][0:2]
# Out:
# (1, 110)

# %% [markdown]
# ___

# %%
def single_test(userID, codes):
    results=[]
#     userID = np.random.randint(1000,2000)
    for i in codes:
        results.append((userID, i))
    print len(results)
    return results

# %%
ratings.filter(lambda x: x[0] == 2000).map(lambda p: (p[0], p[1]))
# Out:
# PythonRDD[222] at RDD at PythonRDD.scala:43

# %%
# %%time
results = model.predictAll(ratings.filter(lambda x: x[0] == 2000).map(lambda p: (p[0], p[1])))
# Out:
# CPU times: user 12 ms, sys: 0 ns, total: 12 ms
# Wall time: 4.43 s

# %%
from pyspark.sql.types import StructType
from pyspark.sql.types import StructField
from pyspark.sql.types import StringType, IntegerType, FloatType

from pyspark.sql import SQLContext
sqlContext = SQLContext(sc)

schema = StructType([StructField('userID', IntegerType(), True), 
                     StructField('codeID', IntegerType(), True), 
                     StructField('valid_prob', FloatType(), True)])

# %%
# %%time
results = model.predictAll(sc.parallelize(single_test(2000, testcode)))
# Out:
# 20
# CPU times: user 8 ms, sys: 0 ns, total: 8 ms
# Wall time: 140 ms

# %%
df = sqlContext.createDataFrame(results, schema)
df
# Out:
# DataFrame[userID: int, codeID: int, valid_prob: float]

# %%
df.toPandas()
# Out:
#     userID  codeID  valid_prob
# 0     2000    2296    0.639720
# 1     2000    3268    0.247785
# 2     2000   25764    0.962311
# 3     2000    1588    0.317930
# 4     2000    1641    0.779639
# 5     2000    8629    0.996244
# 6     2000    4237    0.898537
# 7     2000    4981    1.001502
# 8     2000     393    0.404499
# 9     2000    8533    0.712773
# 10    2000    3078    0.877030
# 11    2000  106002    0.680610
# 12    2000     338    0.495683
# 13    2000    3554    1.199219
# 14    2000   26086    0.924305
# 15    2000     663    0.363423
# 16    2000    6643    0.693366
# 17    2000    6187    0.561305
# 18    2000     343    0.416329
# 19    2000    8491    0.965511

# %% [markdown]
# ___

# %%
# %%time
codes = pd.read_csv('./sample.csv', usecols=['codeID'])['codeID'].unique()
# Out:
# CPU times: user 16 ms, sys: 12 ms, total: 28 ms
# Wall time: 36.1 ms

# %%
sc.parallelize([(1, 2), (3, 4)]).collect()
# Out:
# [(1, 2), (3, 4)]

# %%
# %%time
results = model.predictAll(sc.parallelize(single_test(2000, codes)))
# Out:
# 9066
# CPU times: user 80 ms, sys: 0 ns, total: 80 ms
# Wall time: 182 ms

# %%
df = sqlContext.createDataFrame(results, schema)
dfp =df.toPandas()
dfp
# Out:
#       userID  codeID  valid_prob
# 0       2000    1084    0.857796
# 1       2000    6400    0.915096
# 2       2000   81132   -0.258463
# 3       2000    6308    0.902392
# 4       2000   44828   -0.280645
# 5       2000    7020    1.082411
# 6       2000    5384    1.039434
# 7       2000    7136    0.340912
# 8       2000     140    0.480365
# 9       2000     204    0.259831
# 10      2000     956    0.287236
# 11      2000    4992    0.798336
# 12      2000   62912   -0.638719
# 13      2000    4224    0.957423
# 14      2000   73168   -1.018394
# 15      2000     160    0.154647
# 16      2000   72176    0.169465
# 17      2000    7456    0.427022
# 18      2000    1596   -0.197832
# 19      2000    3932    0.838738
# 20      2000    2904    0.064529
# 21      2000    6840    0.101855
# 22      2000    4628    1.039195
# 23      2000    1500    0.694591
# 24      2000   55276    0.432878
# 25      2000     548    0.365079
# 26      2000   46772   -1.021271
# 27      2000    1732    0.611547
# 28      2000   78544    0.746295
# 29      2000   94780   -0.557438
# ...      ...     ...         ...
# 8712    2000    6731    0.269998
# 8713    2000   78499    0.345339
# 8714    2000    8999    0.543735
# 8715    2000   71823    0.962777
# 8716    2000    5315   -0.040456
# 8717    2000    6195    0.891068
# 8718    2000    6091    0.000000
# 8719    2000    2983    0.921133
# 8720    2000    5799    1.154091
# 8721    2000     183    0.923599
# 8722    2000    3699    0.433168
# 8723    2000   37211    0.772243
# 8724    2000    2395    0.288860
# 8725    2000    3431    0.760098
# 8726    2000   91199    1.184335
# 8727    2000    3299   -0.176165
# 8728    2000    7171    1.661003
# 8729    2000    1103    0.994193
# 8730    2000   59387    0.542575
# 8731    2000    4487    0.738706
# 8732    2000    3503    0.841356
# 8733    2000    2003   -0.067979
# 8734    2000   32139    1.253565
# 8735    2000   93831   -0.613048
# 8736    2000  120799   -0.307632
# 8737    2000   95199    0.426948
# 8738    2000    3203    0.994690
# 8739    2000    5203    0.193379
# 8740    2000    7147    0.822179
# 8741    2000   96691   -0.059531
#
# [8742 rows x 3 columns]

# %%
dfp[dfp['valid_prob']<0]
# Out:
#       userID  codeID  valid_prob
# 2       2000   81132   -0.258463
