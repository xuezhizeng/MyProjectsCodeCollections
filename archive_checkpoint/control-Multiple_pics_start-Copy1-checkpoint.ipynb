# %%
import pandas as pd

# %%
import os
import cv2
from IPython.core.display import Image  
import matplotlib.pyplot as plt


def showpic(lists):
    n=len(lists)
    print 'viewing ',n, 'pics'
    
    f=0
    for i in lists:
        f+=1
        name=path+i
        if f%2==1:
            print f, '-', f+1
            plt.figure(figsize=((10,7)))
            plt.subplot(1,2,1)
            plt.imshow(plt.imread(name))
        else:

            plt.subplot(1,2,2)
            plt.imshow(plt.imread(name))
            plt.show()

# %%
# %%time
# !python rude-carnie/guess.py --class_type gender --model_type inception --model_dir 21936 \
--filename /home/soyoung/face/Freelancer/Tensorflow/boss1.txt --target /home/soyoung/face/Freelancer/Tensorflow/boss1_gender_predict.csv
# Out:
# 2017-09-30 21:10:55.366638: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-09-30 21:10:55.366663: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-09-30 21:10:55.366669: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2017-09-30 21:10:55.366673: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %% [markdown]
# CPU times: user 2min 18s, sys: 17 s, total: 2min 35s
# Wall time: 1h 34min 33s

# %%
df = pd.read_csv('boss1_gender_predict.csv')
df.shape
# Out:
# (869, 3)

# %%
df.head()
# Out:
#                                                 file label  score
# 0  /home/soyoung/face/Freelancer/headPics/bossPic...     M   0.60
# 1  /home/soyoung/face/Freelancer/headPics/bossPic...     F   0.55
# 2  /home/soyoung/face/Freelancer/headPics/bossPic...     F   0.59
# 3  /home/soyoung/face/Freelancer/headPics/bossPic...     F   0.98
# 4  /home/soyoung/face/Freelancer/headPics/bossPic...     M   0.92

# %%
done = df['file']
len(done)
# Out:
# 869

# %%
should = pd.read_fwf('boss1.txt',names =['url'])
should.head()
# Out:
#                                                  url
# 0  /home/soyoung/face/Freelancer/headPics/bossPic...
# 1  /home/soyoung/face/Freelancer/headPics/bossPic...
# 2  /home/soyoung/face/Freelancer/headPics/bossPic...
# 3  /home/soyoung/face/Freelancer/headPics/bossPic...
# 4  /home/soyoung/face/Freelancer/headPics/bossPic...

# %%
wanted=should['url']
len(wanted)
# Out:
# 1368

# %%
len(set(wanted)-set(done))
# Out:
# 500

# %%
diff = set(wanted)-set(done)
type(diff)
# Out:
# set

# %%
# %%time
with open('boss1_diff.txt','w+') as fl:
    for i in diff:
        fl.writelines(i+'\n')
# Out:
# CPU times: user 4 ms, sys: 0 ns, total: 4 ms
# Wall time: 3.8 ms

# %%
# %%time
# !python rude-carnie/guess.py --class_type gender --model_type inception --model_dir 21936 \
--filename /home/soyoung/face/Freelancer/Tensorflow/boss1_diff.txt --target /home/soyoung/face/Freelancer/Tensorflow/boss1_gender_diff_predict.csv
# Out:
# 2017-09-30 23:10:02.724373: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-09-30 23:10:02.724396: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-09-30 23:10:02.724404: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2017-09-30 23:10:02.724411: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# ...
