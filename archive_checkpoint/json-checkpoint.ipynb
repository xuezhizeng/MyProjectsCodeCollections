# %%
import json
import requests

# %%
r = requests.get('http://www.soyoung.com/live/list?page=2&limit=10&is_json=1')
r
# Out:
# <Response [200]>

# %%
r_end = requests.get('http://www.soyoung.com/live/list?page=158&limit=10&is_json=1')

# %%
json.loads(r.text)
# Out:
# {u'_host': True,
#  u'business_first_menu': [],
#  u'default_user_img': u'/images/default_head.png',
#  u'has_more': 1,
#  u'list': [{u'city_name': u'\u4e0a\u6d77\u5e02',
#    u'cover_img': u'http://img2.soyoung.com/message/ios/20180117/0/20180117185603240.jpg',
#    u'create_date': u'2018-01-17 18:56:23',
#    u'create_user_info': {u'age': u'5',
#     u'avatar': {u'h': 57,
#      u'ident': u'lnimage',
#      u'u': u'http://img2.soyoung.com/doctor/20171227/4/20171227164849762_100_100.jpg',
#      u'w': 57,
#      u'zoom': u'89%'},
#     u'certified_id': u'847',
#     u'certified_type': u'2',
#     u'city_id': u'145',
#     u'city_name': u'\u4e0a\u6d77\u5e02',
#     u'district_id': u'0',
#     u'district_name': u'',
#     u'gender': u'0',
# ...

# %%
json.loads(r_end.text)
# Out:
# {u'_host': True,
#  u'business_first_menu': [],
#  u'default_user_img': u'/images/default_head.png',
#  u'has_more': 0,
#  u'list': [{u'city_name': u'\u5c71\u4e1c\u7701',
#    u'cover_img': u'http://img2.soyoung.com/message/ios/20161102/6/20161102201613837.jpg',
#    u'create_date': u'2016-11-02 20:16:14',
#    u'create_user_info': {u'age': u'3',
#     u'avatar': {u'h': 57,
#      u'ident': u'lnimage',
#      u'u': u'http://img2.soyoung.com/user/20170918/5/20170918115848498_100_100.jpg',
#      u'w': 57,
#      u'zoom': u'89%'},
#     u'certified_id': u'0',
#     u'certified_type': u'0',
#     u'city_id': u'0',
#     u'city_name': u'',
#     u'create_group_yn': 1,
#     u'district_id': u'0',
#     u'district_name': u'',
#     u'experience': u'20631',
#     u'gender': u'1',
#     u'intro': u'\u4f60\u53c8\u6765\u5077\u5077\u770b\u6211\u3001\u7231\u6211\u5c31\u544a\u8bc9\u6211\u597d\u561b',
#     u'level': 20,
#     u'money': u'22912',
#     u'province_id': u'1',
# ...
