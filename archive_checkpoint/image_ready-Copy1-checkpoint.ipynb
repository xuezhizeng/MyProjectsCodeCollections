# %%
import concurrent.futures
import requests
import os

from time import time, ctime
import pandas as pd

fail=[]

# %%
def download_image(img_url):
    global direct
    
    try:
        ID, url = img_url.split('__')
        cont = url.split('/')
        name= str(ID)+'_'+str(cont[-4])+str(cont[-1]).replace('_570','')
        
    except Exception as e:
        fail.append(img_url)
        print e

        
        
    try:
        img_request = requests.request(
            'get', url, stream=True, timeout=300)
        if img_request.status_code != 200:
            fail.append(img_url)
            print 'X2'
    except Exception as e:
        fail.append(img_url)
        print e

    try:
        img_content = img_request.content
        with open(os.path.join(direct,  name), 'wb') as f:
            byte_image = bytes(img_content)
            f.write(byte_image)
            
    except Exception as e:
        fail.append(img_url)
        print e

# %%
def batch(subber):
    start=time()
    with concurrent.futures.ThreadPoolExecutor(max_workers=8) as executor:
        executor.map(download_image, subber)
    past='{:.2f}'.format(time()-start)
    now=ctime()[4:]

    print 'imges ',len(subber),'  used ',past,'s', now

# %%
def spl(lists, n):
    return  [lists[i:i + n] for i in range(0, len(lists), n)]

# %%
if __name__=='__main__':
    
    choose=raw_input('which set (1-24)?: ')
    try:
        os.mkdir('img_'+str(choose))
    except:
        print 'dir img_'+str(choose)+' exists'
    
    direct='img_'+str(choose)
    df=pd.read_csv('img_'+str(choose)+'.csv')
    nn=df.shape[0]
    print nn,' pics'
    
    
    urls=[]
    for i in df.itertuples():
        urls.append(str(i[1])+'__'+str(i[2]))
    print len(urls)==nn
    
    many=int(raw_input('how many IDs a batch?: '))
      
    
    p=0
    q=0
    for i in spl(urls, many):
        q+=1
        batch(i)
        p+=many/float(nn)
        print p*100,'%', nn, many*q 

    fl = pd.DataFrame(fail, columns=['fail_url'])
    fl.to_csv('failed_img_'+str(choose)+'.csv', index=False)
# Out:
# which set (1-24)?: 4
# 10000  pics
# True
# how many IDs a batch?: 100
# list index out of range
# Invalid URL '(null)': No schema supplied. Perhaps you meant http://(null)?
# local variable 'img_request' referenced before assignment
# imges  100   used  39.53 s Aug 31 00:32:51 2017
# 1.0 % 10000 100
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20160922/4/20160922102210781_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145fe990>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20160922/2/20160922102217214_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145fea10>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20160925/3/20160925204611877_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145fef10>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20160925/8/20160925204613855_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145fe710>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20160925/6/20160925204610470_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f3014596350>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20160925/8/20160925204611582_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f301459dc10>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20160925/1/20160925204612175_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145963d0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20160925/6/20160925204614413_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145fefd0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20160925/4/20160925204613884_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145fe990>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20160925/2/20160925204614795_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145fe9d0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20160922/3/20160922113951151_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145c0790>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20160922/1/20160922113958738_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f3014596290>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20160922/7/20160922114004578_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f3014596550>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20160922/1/20160922114028214_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f301459d050>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20160922/2/20160922100554683_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f3014596550>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20160922/7/20160922100601591_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f301459df90>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20160922/6/20160922100609230_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145c03d0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20160922/7/20160922100617437_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f3016c58410>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20160922/9/20160922100627999_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145e4e10>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20160921/6/20160921145801761_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f3016c58410>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20160921/8/20160921145810589_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f3014596a90>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20160921/3/20160921145758440_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145e4b10>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20160921/6/20160921145808115_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145e4d50>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20160921/6/20160921145759150_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f3016c58f10>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20160919/4/20160919162731550_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145e4090>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20160919/0/20160919162731172_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145e4e90>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20160919/4/20160919162731823_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f301459df90>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20160919/1/20160919162731723_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145e4690>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20160920/4/20160920234119259_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f301459df50>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20160920/9/20160920234117575_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145e4610>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20160920/4/20160920234119805_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f301459de90>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20160920/7/20160920234115730_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145e4690>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20160920/2/20160920234119463_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f301459d490>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img1.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20150423/5/20150423135221630_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145e4c90>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20150604/1/20150604171115376_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f301
570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145e46d0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img1.soyoung.com', port=80): Max retries exceeded with url: /tieba/android/20150321/6/20150321081758933_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145e4e90>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img1.soyoung.com', port=80): Max retries exceeded with url: /tieba/android/20150321/6/20150321081807256_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145e4f10>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img1.soyoung.com', port=80): Max retries exceeded with url: /tieba/android/20150322/6/20150322105202868_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145e4490>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img1.soyoung.com', port=80): Max retries exceeded with url: /tieba/android/20150322/9/20150322105203452_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f3016c58b90>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img1.soyoung.com', port=80): Max retries exceeded with url: /tieba/android/20150322/0/20150322105205224_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f3016c58bd0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# ...
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20151025/1/20151025152603990_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145c0410>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20151025/6/20151025152603337_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145c2d50>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20151025/4/20151025152604678_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145c0a50>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20151021/8/20151021133525706_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145c2290>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20151021/4/20151021133525244_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145c0a50>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20151021/9/20151021133520184_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f3014592b50>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20151018/8/20151018165709898_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f3014592c50>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20151017/9/20151017201727515_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145a8750>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/android/20170526/2/20170526153836225_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f3014592a50>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/android/20170526/7/20170526153837976_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f3014592e90>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/android/20170526/4/20170526153837761_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f3014592510>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/android/20170526/5/20170526153842192_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145929d0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/android/20160118/1/20160118173142649_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145920d0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/android/20160118/8/20160118173142234_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145927d0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20160427/1/20160427152530355_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f3014592a10>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/android/20170526/0/20170526152757420_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145e27d0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/android/20170526/3/20170526152757518_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f3014592490>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/android/20170526/6/20170526152802928_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145e2ed0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/android/20170526/2/20170526152814226_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145e2d10>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/android/20160118/5/20160118211120900_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145c2cd0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/android/20160118/2/20160118211125257_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145e2690>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20160504/4/20160504150340463_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145e2490>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20160504/2/20160504150341367_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145c2950>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/ios/20160504/5/20160504150340567_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145e2b90>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/android/20160117/3/20160117235114245_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145c2c10>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/android/20160127/5/20160127200905690_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145c2350>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/android/20160127/1/20160127200907624_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145e2690>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/android/20160115/5/20160115190319298_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145c2090>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/android/20160115/9/20160115190322460_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145ad8d0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/android/20160115/9/20160115204108109_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145c29d0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/android/20160115/8/20160115204108120_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145adfd0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/android/20160115/8/20160115204109510_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145ad510>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/android/20160115/7/20160115204109424_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145add10>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170514/4/20170514104626276_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145ad450>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170514/5/20170514104608772_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145adf90>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170514/8/20170514104617446_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145adc50>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170514/1/20170514104636551_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145ad150>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# HTTPConnectionPool(host='img2.soyoung.com', port=80): Max retries exceeded with url: /tieba/web/20170514/6/20170514104644417_570.jpg (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x7f30145ad0d0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# local variable 'img_request' referenced before assignment
# imges  100   used  40.27 s Aug 31 02:18:25 2017
# 89.0 % 10000 8900
# imges  100   used  55.17 s Aug 31 02:19:20 2017
# 90.0 % 10000 9000
# imges  100   used  42.23 s Aug 31 02:20:02 2017
# 91.0 % 10000 9100
# imges  100   used  32.92 s Aug 31 02:20:35 2017
# 92.0 % 10000 9200
# imges  100   used  61.07 s Aug 31 02:21:36 2017
# 93.0 % 10000 9300
# imges  100   used  89.60 s Aug 31 02:23:06 2017
# 94.0 % 10000 9400
# imges  100   used  32.91 s Aug 31 02:23:39 2017
# 95.0 % 10000 9500
# X2
# imges  100   used  34.75 s Aug 31 02:24:13 2017
# 96.0 % 10000 9600
# imges  100   used  35.87 s Aug 31 02:24:49 2017
# 97.0 % 10000 9700
# X2
# imges  100   used  30.25 s Aug 31 02:25:19 2017
# 98.0 % 10000 9800
# imges  100   used  36.70 s Aug 31 02:25:56 2017
# 99.0 % 10000 9900
# imges  100   used  59.08 s Aug 31 02:26:55 2017
# 100.0 % 10000 10000
# AttributeErrorTraceback (most recent call last)
# <ipython-input-6-4946006f5b1d> in <module>()
#      30
#      31     fl = pd.DataFrame(fail, columns=['fail_url'])
# ---> 32     fl.save('failed_img_'+str(choose)+'.csv')
#
# /home/saya/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'save'
